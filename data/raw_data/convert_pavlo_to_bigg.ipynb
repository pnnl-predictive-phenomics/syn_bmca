# %%
import pandas as pd
from copy import deepcopy

# %%
# from rtoru import model as rt
# from syn_elong import model as syn
import sys
sys.path.append('/Users/mahs128/Repos/CONCERTO')

from concerto.helpers.load_model_from_git import load_model_from_git
syn = load_model_from_git('Synechococcus')
rt = load_model_from_git('Rhodosporidium')

# %%
# Create mtnx mapper
mtnx_mapper = {}

# Collect metabolites from Rt model
for i in rt.metabolites:
    this_i = i.annotation.get('kegg.compound')
    if this_i is not None:
        # Check if this_i is a list with multiple KEGG-IDs
        if isinstance(this_i, list):
            print(f"NOTE: identified multiple KEGG-IDs for this metabolite in Rt, {this_i} = {i.id}")
            for ii in this_i:
                mtnx_mapper[ii] = i.id[:-2]
        else:
            mtnx_mapper[this_i] = i.id[:-2]
print(len(mtnx_mapper))

# Collect metabolites from Syn model (if not already found in Rt model)
for i in syn.metabolites:
    this_i = i.annotation.get('kegg.compound')
    if this_i is not None:
        # Check if this_i is a list with multiple KEGG-IDs
        if isinstance(this_i, list):
            print(f"NOTE: identified multiple KEGG-IDs for this metabolite in Syn, {this_i} = {i.id}")
            for ii in this_i:
                mtnx_mapper[ii] = i.id[:-2]
        else:
            if not (this_i in mtnx_mapper.keys()):
                mtnx_mapper[this_i] = i.id[:-2]
print(len(mtnx_mapper))

# Correct metabolites using id-mapper file 
df = pd.read_json('id-mapper.json').T
for i,j in df['xrefs'].items():
    for item in j:
        if 'bigg.metabolite' in item:
            mtnx_mapper[i] = item.replace('bigg.metabolite:', '')
print(len(mtnx_mapper))
# Out:
# 767
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00047', 'C16440'] = lys__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01401', 'C00041'] = ala__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16439', 'C00123'] = leu__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01353', 'C00288'] = hco3_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00049', 'C16433'] = asp__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00001', 'C01328'] = h2o_cx
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00001', 'C01328'] = h2o_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16688', 'C02591'] = suc6p_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01353', 'C00288'] = hco3_cx
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00094', 'C11481'] = so3_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00137', 'C19891'] = inost_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00716', 'C00065'] = ser__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00025', 'C00302'] = glu__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C03912', 'C04322'] = 1pyr5c_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00082', 'C01536'] = tyr__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00001', 'C01328'] = h2o_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00768', 'C00135'] = his__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00661', 'C00118'] = g3p_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00736', 'C00097'] = cys__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01496', 'C05003', 'C00095', 'C10906'] = fru_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00148', 'C16435'] = pro__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00014', 'C01342'] = nh4_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01733', 'C00073'] = met__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00077', 'C01602'] = orn_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C03651', 'C01157'] = 4hpro_LT_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00064', 'C00303'] = gln__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00001', 'C01328'] = h2o_u
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00806', 'C00078'] = trp__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16438', 'C00152'] = asn__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C05330', 'C00155'] = hcys__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C02385', 'C00062'] = arg__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00079', 'C02057'] = phe__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16436', 'C00183'] = val__L_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00001', 'C01328'] = h2o_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00768', 'C00135'] = his__L_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00014', 'C01342'] = nh4_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C02385', 'C00062'] = arg__L_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00064', 'C00303'] = gln__L_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01353', 'C00288'] = hco3_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00014', 'C01342'] = nh4_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C02385', 'C00062'] = arg__L_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00064', 'C00303'] = gln__L_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01353', 'C00288'] = hco3_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16241', 'C00725'] = lipoate_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16439', 'C00123'] = leu__L_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C16439', 'C00123'] = leu__L_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00698', 'C01327'] = cl_p
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00698', 'C01327'] = cl_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00698', 'C01327'] = cl_e
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01159', 'C03339'] = 23dpg_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C01157', 'C03651'] = 4hpro__LT_c
# NOTE: identified multiple KEGG-IDs for this metabolite in Syn, ['C00988', 'C00258', 'C02979', 'C00160', 'C00116', 'C00093', 'C03189', 'C00182', 'C16699', 'C11544', 'C03459', 'C00344', 'C05432', 'C00603', 'C02766', 'C00513'] = lyc_c
# 959
# 976

# %%
mtnx_mapper
# Out:
# {'C00008': 'adp',
#  'C00002': 'atp',
#  'C00080': 'h',
#  'C05853': '2phetoh',
#  'C00006': 'nadp',
#  'C00005': 'nadph',
#  'C00601': 'pacald',
#  'C00234': '10fthf',
#  'C01328': 'h2o',
#  'C00445': 'methf',
#  'C00147': 'ade',
#  'C00020': 'amp',
#  'C03736': 'r5p',
#  'C01180': '2kmb',
#  'C15606': 'dhmtp',
#  'C00058': 'for',
#  'C00007': 'o2',
#  'C00307': 'cdpchol',
#  'C00055': 'cmp',
#  'C00003': 'nad',
#  'C00004': 'nadh',
#  'C00042': 'succ',
#  'C00232': 'sucsal',
#  'C00022': 'pyr',
#  'C00011': 'co2',
#  'C01185': 'nicrnt',
#  'C00013': 'ppi',
#  'C00119': 'prpp',
#  'C03722': 'quln',
#  'C00332': 'aacoa',
#  'C00024': 'accoa',
#  'C00010': 'coa',
#  'C00026': 'akg',
#  'C00302': 'glu__L',
#  'C00942': '35cgmp',
#  'C00144': 'gmp',
#  'C00054': 'pap',
#  'C00053': 'paps',
#  'C11481': 'so3',
#  'C00343': 'trdox',
#  'C00342': 'trdrd',
#  'C00009': 'pi',
#  'C00101': 'thf',
#  'C01944': 'occoa',
#  'C06423': 'octa',
#  'C21057': 'rib__D',
#  'C00106': 'ura',
#  'C00299': 'uri',
#  'C00084': 'acald',
#  'C05275': 'dc2coa',
#  'C00027': 'h2o2',
#  'C04411': '3c2hmp',
#  'C00021': 'ahcys',
#  'C00019': 'amet',
#  'C00229': 'ACP',
#  'C01209': 'malACP',
#  'C00029': 'udpg',
#  'C00167': 'udpglcur',
#  'C00475': 'cytd',
#  'C00035': 'gdp',
#  'C00044': 'gtp',
#  'C00120': 'btn',
#  'C00956': 'L2aadp',
#  'C05265': '3odcoa',
#  'C00048': 'glx',
#  'C00037': 'gly',
#  'C00168': 'hpyr',
#  'C00716': 'ser__L',
#  'C00033': 'ac',
#  'C00083': 'malcoa',
#  'C05259': '3ohdcoa',
#  'C02593': 'tdcoa',
#  'C00979': 'acser',
#  'C00736': 'cys__L',
#  'C05529': 'tsul',
#  'C00131': 'datp',
#  'C00612': 'N1aspmd',
#  'C02714': 'aprut',
#  'C01107': '5pmev',
#  'C00418': 'mev__R',
#  'C01401': 'ala__L',
#  'C00206': 'dadp',
#  'C00105': 'ump',
#  'C00303': 'gln__L',
#  'C01342': 'nh4',
#  'C00249': 'hdca',
#  'C01530': 'ocdca',
#  'C00712': 'ocdcea',
#  'C05437': 'zymst',
#  'C06735': 'aacald',
#  'C00245': 'taur',
#  'C00158': 'cit',
#  'C00036': 'oaa',
#  'C03232': '3php',
#  'C01005': 'pser__L',
#  'C04322': '1pyr5c',
#  'C16435': 'pro__L',
#  'C16218': 'od2coa',
#  'C00346': 'ethamp',
#  'C00670': 'g3pc',
#  'C15583': 'pac',
#  'C04895': 'ahdt',
#  'C04874': 'dhnpt',
#  'C01419': 'cgly',
#  'C00051': 'gthrd',
#  'C00705': 'dcdp',
#  'C00458': 'dctp',
#  'C02912': '12ppd__R',
#  'C00937': 'lald__D',
#  'C00160': 'glyclt',
#  'C00361': 'dgdp',
#  'C00362': 'dgmp',
#  'C00751': 'sql',
#  'C00836': 'sphgn',
#  'C00235': 'dmpp',
#  'C00341': 'grdp',
#  'C00129': 'ipdp',
#  'C04752': '2mahmp',
#  'C03451': 'lgt__S',
#  'C00546': 'mthgxl',
#  'C00387': 'gsn',
#  'C00242': 'gua',
#  'C00620': 'r1p',
#  'C00166': 'phpyr',
#  'C00254': 'pphn',
#  'C02412': 'glytrna',
#  'C01642': 'trnagly',
#  'C05264': '3hdcoa',
#  'C01832': 'ddcacoa',
#  'C00111': 'dhap',
#  'C00154': 'pmtcoa',
#  'C00412': 'stcoa',
#  'C00063': 'ctp',
#  'C03069': '3mb2coa',
#  'C00016': 'fad',
#  'C01352': 'fadh2',
#  'C02939': 'ivcoa',
#  'C01144': '3hbcoa',
#  'C00877': 'b2coa',
#  'C00328': 'Lkynr',
#  'C00108': 'anth',
#  'C01100': 'hisp',
#  'C01267': 'imacp',
#  'C14818': 'fe2',
#  'C02223': '2mbald',
#  'C00671': '3mop',
#  'C15605': 'Lfmkynr',
#  'C02987': 'glutrna',
#  'C01641': 'trnaglu',
#  'C04677': 'aicar',
#  'C04734': 'fprica',
#  'C01120': 'sph1p',
#  'C04043': '34dhpac',
#  'C03758': 'dopa',
#  'C05345': 'f6p',
#  'C00236': '13dpg',
#  'C03339': '23dpg',
#  'C00661': 'g3p',
#  'C00857': 'dnad',
#  'C00555': '4abutn',
#  'C00315': 'spmd',
#  'C00096': 'gdpmann',
#  'C00768': 'his__L',
#  'C02988': 'histrna',
#  'C01643': 'trnahis',
#  'C02057': 'phe__L',
#  'C03511': 'phetrna',
#  'C01648': 'trnaphe',
#  'C00068': 'thmpp',
#  'C00031': 'glc__D',
#  'C00074': 'pep',
#  'C04236': '3c4mop',
#  'C00233': '4mop',
#  'C00015': 'udp',
#  'C00075': 'utp',
#  'C16439': 'leu__L',
#  'C00363': 'dtdp',
#  'C00364': 'dtmp',
#  'C14710': 'ibutoh',
#  'C00345': '6pgc',
#  'C01236': '6pgl',
#  'C00109': '2obut',
#  'C00188': 'thr__L',
#  'C06422': 'cellb',
#  'C01165': 'glu5sa',
#  'C01652': 'trnatrp',
#  'C00806': 'trp__L',
#  'C03512': 'trptrna',
#  'C02291': 'cyst__L',
#  'C01118': 'suchms',
#  'C01077': 'achms',
#  'C00409': 'ch4s',
#  'C01733': 'met__L',
#  'C15650': 'dkmpp',
#  'C01724': 'lanost',
#  'C03345': '2mb2coa',
#  'C01033': '2mbcoa',
#  'C00672': '2dr1p',
#  'C00178': 'thym',
#  'C00214': 'thymd',
#  'C19891': 'inost',
#  'C01177': 'mi1p__D',
#  'C00460': 'dutp',
#  'C00311': 'icit',
#  'C10906': 'fru',
#  'C05662': 'hicit',
#  'C00149': 'mal__L',
#  'C03078': '4gudbd',
#  'C01035': '4gudbutn',
#  'C02225': '2mcit',
#  'C00100': 'ppcoa',
#  'C03492': '4ppan',
#  'C00864': 'pnto__R',
#  'C00212': 'adn',
#  'C00294': 'ins',
#  'C01070': 'ficytc',
#  'C00924': 'focytc',
#  'C00186': 'lac__L',
#  'C00099': 'ala_B',
#  'C00222': 'msa',
#  'C02505': 'pad',
#  'C01694': 'ergst',
#  'C02571': 'acrn',
#  'C00487': 'crn',
#  'C00052': 'udpgal',
#  'C02637': '3dhsk',
#  'C00493': 'skm',
#  'C00283': 'h2s',
#  'C00091': 'succoa',
#  'C00966': '2dhp',
#  'C00141': '3mob',
#  'C00143': 'mlthf',
#  'C04376': 'fgam',
#  'C03838': 'gar',
#  'C00647': 'pyam5p',
#  'C00534': 'pydam',
#  'C00632': '3hanthrn',
#  'C03227': 'hLkynr',
#  'C02430': 'mettrna',
#  'C01647': 'trnamet',
#  'C01031': 'Sfglutth',
#  'C00061': 'fmn',
#  'C00255': 'ribflv',
#  'C03082': '4pasp',
#  'C00441': 'aspsa',
#  'C05258': '3hhdcoa',
#  'C05272': 'hdd2coa',
#  'C04405': '3hmbcoa',
#  'C00093': 'lyc',
#  'C00104': 'idp',
#  'C00081': 'itp',
#  'C00262': 'hxan',
#  'C00130': 'imp',
#  'C02504': '3c3hmp',
#  'C05714': 'aprop',
#  'C06007': '23dhmp',
#  'C01330': 'na1',
#  'C00415': 'dhf',
#  'C01344': 'didp',
#  'C01345': 'ditp',
#  'C00224': 'aps',
#  'C00156': '4hbz',
#  'C00112': 'cdp',
#  'C03263': 'cpppg3',
#  'C01079': 'pppg9',
#  'C00134': 'ptrc',
#  'C00253': 'nac',
#  'C00469': 'etoh',
#  'C05262': '3hddcoa',
#  'C03221': 'dd2coa',
#  'C04076': 'L2aadp6sa',
#  'C00449': 'saccrp__L',
#  'C00114': 'chol',
#  'C01346': 'dudp',
#  'C00365': 'dump',
#  'C01010': 'allphn',
#  'C00526': 'duri',
#  'C00263': 'hom__L',
#  'C00787': 'trnatyr',
#  'C01536': 'tyr__L',
#  'C02839': 'tyrtrna',
#  'C05715': 'acybut',
#  'C00407': 'ile__L',
#  'C03127': 'iletrna',
#  'C01644': 'trnaile',
#  'C16433': 'asp__L',
#  'C04692': 'cmaphis',
#  'C03862': 'dolmanp',
#  'C05999': 'lald__L',
#  'C01102': 'phom',
#  'C04352': '4ppcys',
#  'C01134': 'pan4p',
#  'C01260': 'ap4a',
#  'C02741': 'prbamp',
#  'C02739': 'prbatp',
#  'C02984': 'asptrna',
#  'C01638': 'trnaasp',
#  'C00286': 'dgtp',
#  'C00089': 'sucr',
#  'C00199': 'ru5p__D',
#  'C00231': 'xu5p__D',
#  'C01353': 'hco3',
#  'C00275': 'man6p',
#  'C00159': 'man',
#  'C02917': '12ppd__S',
#  'C00944': '3dhq',
#  'C01602': 'orn',
#  'C05260': '3htdcoa',
#  'C05273': 'td2coa',
#  'C00588': 'cholp',
#  'C00043': 'uacgam',
#  'C00704': 'o2s',
#  'C00894': 'prpncoa',
#  'C00190': 'udpxyl',
#  'C05263': '3oddcoa',
#  'C00499': 'alltt',
#  'C02766': 'lyc',
#  'C00086': 'urea',
#  'C06156': 'gam1p',
#  'C00352': 'gam6p',
#  'C01143': '5dpmev',
#  'C00921': 'dhpt',
#  'C04133': 'acg5p',
#  'C00624': 'acglu',
#  'C00197': '3pg',
#  'C00430': '5aop',
#  'C00931': 'ppbng',
#  'C04896': 'prfp',
#  'C04916': 'prlp',
#  'C00153': 'ncam',
#  'C00810': 'actn__R',
#  'C00631': '2pg',
#  'C00239': 'dcmp',
#  'C00103': 'g1p',
#  'C00092': 'g6p',
#  'C00360': 'damp',
#  'C00459': 'dttp',
#  'C00575': 'camp',
#  'C00438': 'cbasp',
#  'C00169': 'cbp',
#  'C03125': 'cystrna',
#  'C01639': 'trnacys',
#  'C02385': 'arg__L',
#  'C01097': 'tag6p__D',
#  'C03785': 'tagdp__D',
#  'C00334': '4abut',
#  'C05332': 'peamn',
#  'C00184': 'dha',
#  'C01013': '3hpp',
#  'C00984': 'gal',
#  'C16438': 'asn__L',
#  'C04256': 'acgam1p',
#  'C00357': 'acgam6p',
#  'C00329': 'gam',
#  'C09332': 'thfglu',
#  'C00164': 'acac',
#  'C01222': 'gdpddman',
#  'C02047': 'leutrna',
#  'C01645': 'trnaleu',
#  'C02038': 'glp',
#  'C03881': 'tglp',
#  'C00461': 'chtn',
#  'C00673': '2dr5p',
#  'C01801': 'drib',
#  'C03794': 'dcamp',
#  'C00122': 'fum',
#  'C00279': 'e4p',
#  'C04525': 'fecost',
#  'C00127': 'gthox',
#  'C16436': 'val__L',
#  'C02989': 'metsox_S__L',
#  'C00627': 'pdx5p',
#  'C00314': 'pydxn',
#  'C04666': 'eig3p',
#  'C03460': '2mp2coa',
#  'C06000': '3hibutcoa',
#  'C00506': 'Lcyst',
#  'C00448': 'frdp',
#  'C00250': 'pydx',
#  'C00606': '3sala',
#  'C01179': '34hpp',
#  'C00182': 'lyc',
#  'C00794': 'sbt__D',
#  'C04732': '4r5au',
#  'C15556': 'db4p',
#  'C04332': 'dmlz',
#  'C00636': 'man1p',
#  'C00256': 'lac__D',
#  'C04454': '5aprbu',
#  'C07329': '3mbald',
#  'C07328': 'iamoh',
#  'C05261': '3otdcoa',
#  'C02553': 'sertrna',
#  'C01650': 'trnaser',
#  'C05382': 's7p',
#  'C04079': 'ptcys',
#  'C00327': 'citr__L',
#  'C15777': 'epist',
#  'C02463': 'dscl',
#  'C05778': 'scl',
#  'C03384': 'gal1p',
#  'C00417': 'acon_C',
#  'C05841': 'nicrns',
#  'C00882': 'dpcoa',
#  'C01302': '2cpr5p',
#  'C03506': '3ig3p',
#  'C00637': 'id3acald',
#  'C00954': 'ind3ac',
#  'C16440': 'lys__L',
#  'C00440': '5mthf',
#  'C05330': 'hcys__L',
#  'C00860': 'histd',
#  'C00655': 'xmp',
#  'C00140': 'acgam',
#  'C11355': '4adcho',
#  'C00251': 'chor',
#  'C00331': 'indpyr',
#  'C00437': 'acorn',
#  'C05440': 'ergtetrol',
#  'C02191': 'ppp9',
#  'C00897': 'malt',
#  'C06010': 'alac__S',
#  'C12144': 'psphings',
#  'C04281': '1p3h5c',
#  'C03651': '4hpro__LT',
#  'C00669': 'glucys',
#  'C02218': '2amac',
#  'C00665': 'f26bp',
#  'C01635': 'trnaala',
#  'C02282': 'glntrna',
#  'C01640': 'trnagln',
#  'C00322': '2oxoadp',
#  'C01083': 'tre',
#  'C16688': 'suc6p',
#  'C04691': '2dda7p',
#  'C04327': '4mpetz',
#  'C01081': 'thmmp',
#  'C00354': 'fdp',
#  'C03406': 'argsuc',
#  'C01269': '3psme',
#  'C04823': '25aics',
#  'C04751': '5aizc',
#  'C00689': 'tre6p',
#  'C03090': 'pram',
#  'C02934': '3dsphgn',
#  'C03287': 'glu5p',
#  'C04188': '5mdr1p',
#  'C04582': '5mdru1p',
#  'C03508': '2aobut',
#  'C05519': 'athr__L',
#  'C03011': 'apep',
#  'C00012': 'pepd',
#  'C00957': 'mercppyr',
#  'C00067': 'fald',
#  'C00630': 'ibcoa',
#  'C00116': 'glyc',
#  'C06196': 'dimp',
#  'C00559': 'dad_2',
#  'C15672': 'hemeO',
#  'C00032': 'pheme',
#  'C00380': 'csn',
#  'C04272': '23dhmb',
#  'C00337': 'dhor__S',
#  'C00295': 'orot',
#  'C02163': 'argtrna',
#  'C01636': 'trnaarg',
#  'C01094': 'f1p',
#  'C00577': 'glyald',
#  'C03402': 'asntrna',
#  'C01637': 'trnaasn',
#  'C01882': 'adprib',
#  'C02938': 'ind3acnl',
#  'C06006': '2ahbut',
#  'C00353': 'ggdp',
#  'C00522': 'pant__R',
#  'C14180': 'hmgth',
#  'C00059': 'so4',
#  'C01137': 'ametam',
#  'C00652': 'Dara14lac',
#  'C01051': 'uppg3',
#  'C11822': '2amsa',
#  'C04294': '4mhetz',
#  'C01024': 'hmbil',
#  'C00379': 'xylt',
#  'C00310': 'xylu__D',
#  'C01653': 'trnaval',
#  'C02554': 'valtrna',
#  'C03150': 'rnam',
#  'C00018': 'pydx5p',
#  'C00203': 'udpacgal',
#  'C03344': '2maacoa',
#  'C00586': '2dglc',
#  'C06369': '2doxg6p',
#  'C00568': '4abz',
#  'C00257': 'glcn',
#  'C01054': 'Ssq23epx',
#  'C02693': 'iad',
#  'C03294': 'fmettrna',
#  'C03546': 'mi4p__D',
#  'C01883': 'aces',
#  'C00968': '35cdamp',
#  'C02631': '2ippm',
#  'C01225': 'g3pi',
#  'C00831': 'ptth',
#  'C00385': 'xan',
#  'C01762': 'xtsn',
#  'C01879': '5oxpro',
#  'C00447': 's17bp',
#  'C02702': 'protrna',
#  'C01649': 'trnapro',
#  'C00455': 'nmn',
#  'C00955': 'ind3eth',
#  'C00748': 'sheme',
#  'C00330': 'dgsn',
#  'C01551': 'alltn',
#  'C00700': 'xtp',
#  'C00491': 'cysi__L',
#  'C05235': 'acetol',
#  'C05122': 'tchola',
#  'C01931': 'lystrna',
#  'C01646': 'trnalys',
#  'C03231': '3mgcoa',
#  'C05938': '4hglusa',
#  'C05947': 'e4hglu',
#  'C04006': 'mi3p__D',
#  'C05512': 'din',
#  'C02341': 'acon_T',
#  'C16216': '3ohodcoa',
#  'C01326': 'cyan',
#  'C01755': 'tcynt',
#  'C04051': 'C04051',
#  'C01250': 'acg5sa',
#  'C02918': '1mncam',
#  'C00132': 'meoh',
#  'C01722': 'sbt__L',
#  'C08356': 'srb__L',
#  'C00258': 'glyc__R',
#  'C05925': 'dhpmp',
#  'C01103': 'orot5p',
#  'C02835': 'im4ac',
#  'C05130': 'im4act',
#  'C02992': 'thrtrna',
#  'C01651': 'trnathr',
#  'C04409': 'cmusa',
#  'C00750': 'sprm',
#  'C00333': 'galur',
#  'C01279': '4ahmmp',
#  'C00189': 'etham',
#  'C00527': 'glutcoa',
#  'C00218': 'mma',
#  'C00170': '5mta',
#  'C01261': 'gp4g',
#  'C00881': 'dcyt',
#  'C04302': 'pran',
#  'C12296': 'iamac',
#  'C15670': 'hemeA',
#  'C04593': 'micit',
#  'C02567': 'N1sprm',
#  'C01152': 'NPmehis',
#  'C00366': 'urate',
#  'C05668': '3hpcoa',
#  'C05528': '3spyr',
#  'C01036': '4mlacac',
#  'C00544': 'hgentis',
#  'C01061': '4fumacac',
#  'C15998': 'metsox_R__L',
#  'C00919': 'chols',
#  'C01233': 'g3pe',
#  'C00244': 'no3',
#  'C01170': 'uacmam',
#  'C06240': 'uacmamu',
#  'C04421': 'sl26da',
#  'C04462': 'sl2a6o',
#  'C04494': 'gdptp',
#  'C00755': 'vanln',
#  'C06672': 'vanlt',
#  'C01936': 'malthx',
#  'C00267': 'Glc_aD',
#  'C16155': 'udpLa4o',
#  'C07648': 'tgua',
#  'C05266': '3hocoa',
#  'C05267': '3oocoa',
#  'C00238': 'k',
#  'C00504': 'fol',
#  'C16699': 'lyc',
#  'C16154': 'udpLa4fn',
#  'C16153': 'udpLa4n',
#  'C06142': '1btol',
#  'C01412': 'btal',
#  'C00088': 'no2',
#  'C20253': '3amac',
#  'C00388': 'hista',
#  'C06332': 'acanth',
#  'C00479': 'ppal',
#  'C00227': 'actp',
#  'C06197': 'apppa',
#  'C01262': 'ans',
#  'C02967': 'dna5mtc',
#  'C00039': 'dna',
#  'C00695': 'cholate',
#  'C00536': 'pppi',
#  'C16630': '56dh5flura',
#  'C16631': 'aflburppa',
#  'C02780': '25dkglcn',
#  'C01161': '34dhpha',
#  'C16700': '34dhbald',
#  'C00230': '34dhbz',
#  'C12621': '3hcinnm',
#  'C12623': 'dhcinnm',
#  'C04807': '6hmhptpp',
#  'C00133': 'ala__D',
#  'C05768': 'cpppg1',
#  'C05766': 'uppg1',
#  'C02248': 'apocytc',
#  'C00524': 'cytc',
#  'C00488': 'frmd',
#  'C00688': 'dtdp4d6dm',
#  'C03319': 'dtdprmn',
#  'C01228': 'ppgpp',
#  'C00325': 'gdpfuc',
#  'C00209': 'oxa',
#  'C00313': 'oxalcoa',
#  'C06244': 'ad',
#  'C00070': 'cu2',
#  'C06232': 'mobd',
#  'C19848': 'mptamp',
#  'C02380': '6mpur',
#  'C04646': '6tins5mp',
#  'C01327': 'cl',
#  'C00181': 'xyl__D',
#  'C00436': 'Ncbmpts',
#  'C01062': '5dglcn',
#  'C05276': 'oc2coa',
#  'C01278': '4cml',
#  'C01163': 'CCbuttc',
#  'C00463': 'indole',
#  'C00666': '26dap_LL',
#  'C02655': 'acglc__D',
#  'C05268': '3hhcoa',
#  'C05271': 'hx2coa',
#  'C16618': '6txan5mp',
#  'C01089': 'bhb',
#  'C00136': 'btcoa',
#  'C01417': 'cynt',
#  'C01112': 'ara5p',
#  'C02666': 'conialdh',
#  'C01494': 'fer',
#  'C07649': '5flura',
#  'C00617': 'udpgalur',
#  'C00740': 'ser__D',
#  'C01099': 'fc1p',
#  'C01234': '1acpc',
#  'C00266': 'gcald',
#  'C14145': '3hadpcoa',
#  'C16698': 'acmum6p',
#  'C00429': '56dura',
#  'C02642': 'cala',
#  'C02130': 'acmalt',
#  'C00309': 'rbl__D',
#  'C01204': 'minohp',
#  'C01585': 'hxa',
#  'C00846': '3oxoadp',
#  'C03586': '5odhf2a',
#  'C03274': 'g3pg',
#  'C02052': 'maltttr',
#  'C11821': '5hiu',
#  'C00621': 'doldp',
#  'C14819': 'fe3',
#  'C00935': 'udparab',
#  'C16619': '6tgsnmp',
#  'C15584': 'phenol',
#  'C05269': '3ohcoa',
#  'C16632': 'aflbala',
#  'C02232': 'oxadpcoa',
#  'C03172': 'mmet',
#  'C00076': 'ca2',
#  'C00576': 'betald',
#  'C05820': 'seramp',
#  'C01029': 'n8aspmd',
#  'C12673': 'tega',
#  'C02979': 'lyc',
#  'C15571': 'catechol',
#  'C02480': 'ccmuac',
#  'C02876': 'ppap',
#  'C11476': 'arab__L',
#  'C03393': '4per',
#  'C11457': '3hpppn',
#  'C04044': 'dhpppn',
#  'C00348': 'udcpp',
#  'C00633': '4hbald',
#  'C20679': 'tungs',
#  'C05636': '3hxkynam',
#  'C00780': 'srtn',
#  'C06178': '1mpyr',
#  'C02723': 'nmptrc',
#  'C00179': 'agm',
#  'C01888': 'aact',
#  'C00532': 'abt',
#  'C00349': '2mop',
#  'C01188': '3hmp',
#  'C01835': 'malttr',
#  'C01996': 'ach',
#  'C01127': '4h2oglt',
#  'C03684': '6pthp',
#  'C00483': 'tym',
#  'C05337': 'dcholcoa',
#  'C11526': 'ppmi12346p',
#  'C06425': 'arach',
#  'C01904': 'abt__D',
#  'C01205': '3aib',
#  'C01953': 'prgnlone',
#  'C00909': 'leuktrA4',
#  'C02166': 'leuktrC4',
#  'C00498': 'adpglc',
#  'C20364': 'ascb__L',
#  'C05422': 'dhdascb',
#  'C05697': 'sel',
#  'C00398': 'trypta',
#  'C00517': 'hxdcal',
#  'C05638': '5hxkynam',
#  'C00402': 'asp__D',
#  'C05127': 'mhista',
#  'C03824': 'am6sa',
#  'C01697': 'galt',
#  'C05589': 'normete__L',
#  'C00547': 'nrpphr',
#  'C03765': '4hoxpacd',
#  'C13636': '4hphac',
#  'C01227': 'dhea',
#  'C15651': 'hkmpp',
#  'C01092': '8aonn',
#  'C04425': 'amob',
#  'C01037': 'dann',
#  'C01909': 'dtbt',
#  'C05198': 'dad_5',
#  'C03479': '5fthf',
#  'C03793': 'tmlys',
#  'C01181': 'gbbtn',
#  'C00811': 'T4hcinnm',
#  'C00223': 'coucoa',
#  'C16238': 'lipoamp',
#  'C16241': 'lipoate',
#  'C02470': 'C02470',
#  'C02220': 'amuco',
#  'C01300': '6hmhpt',
#  'C00296': 'quin',
#  'C10438': 'cinnm',
#  'C00323': 'caffcoa',
#  'C00406': 'ferulcoa',
#  'C16528': 'docoscoa',
#  'C00305': 'mg2',
#  'C19610': 'mn2',
#  'C00038': 'zn2',
#  'C00582': 'phaccoa',
#  'C01481': '34dhcinm',
#  'C00539': 'bz',
#  'C00312': 'xylu__L',
#  'C00216': 'arab__D',
#  'C01508': 'lyx__L',
#  'C18170': '3aap',
#  'C02862': 'c4crn',
#  'C01991': 'ghb',
#  'C00474': 'rbt',
#  'C06186': 'arbt',
#  'C00530': 'hqn',
#  'C01451': 'salcn',
#  'C02323': '2hxmp',
#  'C05759': '3omrsACP',
#  'C06320': 'pre6a',
#  'C05747': '3hhexACP',
#  'C00680': '26dap__M',
#  'C05431': 'neuspn',
#  'C05744': 'actACP',
#  'C01563': 'cbm',
#  'C06098': 'zeax',
#  'C05754': 'tdec2eACP',
#  'C01182': 'rb15bp_',
#  'C08591': 'bcryptox',
#  'C11521': 'udpsq',
#  'C00282': 'h2',
#  'C06509': 'adocbip',
#  'C05748': 'thex2eACP',
#  'C15667': '5caiz',
#  'C03939': 'acACP',
#  'C01212': 'uama',
#  'C05753': '3odecACP',
#  'C06503': 'hgbam',
#  'C05840': 'iasp',
#  'C00047': 'lys__L',
#  'C02880': 'pchlld',
#  'C00041': 'ala__L',
#  'C06032': 'r3mmal',
#  'C00123': 'leu__L',
#  'C00288': 'hco3',
#  'C01268': '5apru',
#  'C02226': 'citac',
#  'C11829': 'hmppp9',
#  'C00049': 'asp__L',
#  'C00001': 'h2o',
#  'C04619': '3hdecACP',
#  'C16519': '2sephchc',
#  'C04882': 'ugmda',
#  'C00988': 'lyc',
#  'C06399': 'hgbyr',
#  'C00175': 'cobalt2',
#  'C02591': 'suc6p',
#  'C05756': '3oddecACP',
#  'C11436': '2p4c2me',
#  'C01146': '2h3oppan',
#  'C00217': 'glu__D',
#  'C11830': 'omppp9',
#  'C04688': '3hmrsACP',
#  'C11435': '4c2me',
#  'C05762': '3opalmACP',
#  'C11437': 'dxyl5p',
#  'C05757': '3hddecACP',
#  'C03972': 'thdp',
#  'C00194': 'adocbl',
#  'C00094': 'so3',
#  'C03771': '5g2oxpt',
#  'C00137': 'inost',
#  'C03516': 'mppp9',
#  'C04122': 'applp',
#  'C02059': 'phllqne',
#  'C05751': 'toct2eACP',
#  'C11434': '2me4p',
#  'C04633': '3hpalmACP',
#  'C04631': 'uaccg',
#  'C00692': 'uamag',
#  'C02094': 'caro',
#  'C05435': 'gcarote',
#  'C00065': 'ser__L',
#  'C00025': 'glu__L',
#  'C03912': '1pyr5c',
#  'C00082': 'tyr__L',
#  'C14463': '3hmop',
#  'C05817': '2shchc',
#  'C03657': 'dhna',
#  'C06408': 'pre8',
#  'C05430': 'zcarote',
#  'C00135': 'his__L',
#  'C06406': 'pre3b',
#  'C06510': 'agdpcbi',
#  'C19609': 'ni2',
#  'C11907': 'dtdp4d6dg',
#  'C05125': '2ahethmpp',
#  'C00118': 'g3p',
#  'C00097': 'cys__L',
#  'C01847': 'fmnh2',
#  'C05432': 'lyc',
#  'C05775': 'rdmbzi',
#  'C04620': '3hoctACP',
#  'C05760': 'tmrs2eACP',
#  'C01496': 'fru',
#  'C05003': 'fru',
#  'C00095': 'fru',
#  'C11453': '2mecdp',
#  'C13309': 'dmtphllqne',
#  'C16221': 'toctd2eACP',
#  'C05306': 'cholphya',
#  'C03175': 'skm5p',
#  'C00500': 'biliverd',
#  'C06407': 'pre4',
#  'C00815': 'citm',
#  'C05772': 'pre3a',
#  'C04618': '3hbutACP',
#  'C00148': 'pro__L',
#  'C11811': 'h2mb4p',
#  'C00501': 'cdpglc',
#  'C00014': 'nh4',
#  'C06504': 'co2dam',
#  'C05897': 'uagmda',
#  'C06416': 'pre5',
#  'C00139': 'fdxox',
#  'C00073': 'met__L',
#  'C00077': 'orn',
#  'C00138': 'fdxrd',
#  'C02730': 'sucbz',
#  'C01157': '4hpro__LT',
#  'C06319': 'pre6b',
#  'C00064': 'gln__L',
#  'C05746': '3ohexACP',
#  'C04246': 'but2eACP',
#  'C06507': 'adcobhex',
#  'C06505': 'co1dam',
#  'C00237': 'co',
#  'C03160': 'sbzcoa',
#  'C01050': 'uamr',
#  'C00078': 'trp__L',
#  'C03427': 'prephytedp',
#  'C00152': 'asn__L',
#  'C00155': 'hcys__L',
#  'C03741': 'glu1sa',
#  'C00885': 'ichor',
#  'C05427': 'phdp',
#  'C06054': 'ohpb',
#  'C16220': '3hoctaACP',
#  'C00062': 'arg__L',
#  'C00079': 'phe__L',
#  'C12147': 'thrp',
#  'C00183': 'val__L',
#  'C00842': 'dtdpglu',
#  'C03114': 'dmbzid',
#  'C05672': '2a3pp',
#  'C05763': 'tpalm2eACP',
#  'C00993': 'alaala',
#  'C04778': '5prdmbz',
#  'C05758': 'tddec2eACP',
#  'C05750': '3ooctACP',
#  'C01219': 'cdp4dh6doglc',
#  'C01838': 'ocdcal',
#  'C06055': 'phthr',
#  'C18021': 'phphbda',
#  'C01389': 'phytol',
#  'C00272': 'thbpt',
#  'C04478': 'kdo8p',
#  'C20373': 'hgmeACP',
#  'C04121': 'ckdo',
#  'C20374': 'egmeACP',
#  'C20375': 'gmeACP',
#  'C20377': 'hpmeACP',
#  'C01289': 'unaga',
#  'C20378': 'epmeACP',
#  'C19846': 'pmeACP',
#  'C19845': 'pimACP',
#  'C05898': 'uaagmda',
#  'C06250': 'btnCCP',
#  'C00725': 'lipoate',
#  'C20239': 'cph4',
#  'C20248': 'cdg',
#  'C15996': 'preq0',
#  'C16675': 'preq1',
#  'C20957': 'LalaDglu',
#  'C20958': 'LalaLglu',
#  'C02869': 'fldox',
#  'C02745': 'fldrd',
#  'C04257': 'acmanap',
#  'C00698': 'cl',
#  'C02679': 'ddca',
#  'C18237': 'moco',
#  'C19928': 'mocogdp',
#  'C01571': 'dca',
#  'C05274': 'dcacoa',
#  'C01159': '23dpg',
#  'C06424': 'ttdca',
#  'C17017': 'cdhgtp',
#  'C18239': 'cpmp',
#  'C03189': 'lyc',
#  'C11544': 'lyc',
#  'C03459': 'lyc',
#  'C00344': 'lyc',
#  'C00603': 'lyc',
#  'C00513': 'lyc',
#  'C02713': 'acmam',
#  'C02999': 'acmama',
#  'C05924': 'mpt',
#  'C00198': 'g15lac',
#  'C00435': 'rdxo',
#  'C00340': 'rdxr',
#  'C00117': 'r5p',
#  'C10164': 'C10164',
#  'C02923': '3mcat',
#  'C00645': 'acmana',
#  'C20827': 'CE2028',
#  'C01019': 'fuc__L',
#  'C00383': 'HC00319',
#  'C01607': 'phyt',
#  'C00208': 'malt',
#  'C00121': 'rib__D',
#  'C05984': '2hb',
#  'C05642': 'fna5moxam',
#  'C06001': '3hmp',
#  'C00392': 'mnl',
#  'C02656': 'pime',
#  'C00248': 'lpam',
#  'C11735': 'egly'}

# %%
# Manually add a few more metabolites into the mapper
# Added by James
mtnx_mapper['C06186'] = 'arbt'
mtnx_mapper['C00095'] = 'fru'
mtnx_mapper['C00197'] = '3pg'
mtnx_mapper['C01970'] = 'lcts'
mtnx_mapper['C00247'] = 'srb__L'

# Added by Andrew & Shant
mtnx_mapper['C02457'] = '13ppd'
mtnx_mapper['C00587'] = '3hbz'
mtnx_mapper['C00180'] = 'bz'

# Can't find BIGG IDs for these KEGG IDs (Included in Pavlo's experiment)
# mtnx_mapper['C02502'] = ''
# mtnx_mapper['C10447'] = ''
# mtnx_mapper['C00852'] = ''
C02502 not found in any mappings
C10447 not found in any mappings
C00852 not found in any mappings
C16884 not found in any mappings
C00503 not found in any mappings
D01947 not found in any mappings
C01384 not found in any mappings
C01601 not found in any mappings
C02497 not found in any mappings
c06578 not found in any mappings
C16884 not found in any mappings
C03461 not found in any mappings
C03619 not found in any mappings
C00124 not found in any mappings
C05660 not found in any mappings
C16536 not found in any mappings
C07064 not found in any mappings
C07064 not found in any mappings
D08266 not found in any mappings
C07044 not found in any mappings
C01384 not found in any mappings
C05113 not found in any mappings
C08060 not found in any mappings
C12026 not found in any mappings
C16536 not found in any mappings
C01479 not found in any mappings
C07064 not found in any mappings
C05905 not found in any mappings
C01432 not found in any mappings
C00711 not found in any mappings

# %%
for k,v in mtnx_mapper.items():
    if 'nan' in v:
        print(k,v)

# %%
# Save the mapper to json
import json
mapper_fname = "KEGG_to_BIGG_mapper_for_Syn_Rt.json"
with open(mapper_fname, "w") as f:
    json.dump(mtnx_mapper, f, indent=4)

# %%
from_pavlo = pd.read_excel('Metabolites_IDs_short_clean.xlsx', skiprows=1)
from_pavlo['KEGG'] = from_pavlo['KEGG ']
del from_pavlo['KEGG ']
from_pavlo['short_name'] = from_pavlo['Metabolite abbreviation (* - score < 0.75; ** - no direct but best spectral match)']
from_pavlo = from_pavlo.loc[from_pavlo['Original metabolite from EMSL or JHU']!='Unknown'].copy()
from_pavlo = from_pavlo.loc[from_pavlo['Original metabolite from EMSL or JHU']!='No direct match'].copy()
from_pavlo = from_pavlo.loc[from_pavlo['Original metabolite from EMSL or JHU']!='not available'].copy()
from_pavlo['bigg_id'] = from_pavlo.KEGG.map(mtnx_mapper)

# %%
# Out:
# 21

# %%
for_ids = from_pavlo[['short_name', 'bigg_id']].copy()
for_ids_map = for_ids.set_index('short_name').to_dict()['bigg_id']

# %%
syn_list = pd.read_csv('secreted_by_synechococcus.txt')
syn_list['bigg_id'] = syn_list.metab.replace(for_ids_map)
syn_list = syn_list.loc[syn_list.bigg_id.notnull()].copy()
syn_list.bigg_id.to_csv('..\excreted_syn.csv')

# %%
rt_list = pd.read_csv('secreted_by_rhodosporidium.txt')
rt_list['bigg_id'] = rt_list.metab.replace(for_ids_map)
rt_list = rt_list.loc[rt_list.bigg_id.notnull()].copy()
rt_list.bigg_id.to_csv('..\excreted_rt.csv')
