# %% [markdown]
# ## This notebook handles the pre-processing needed to modify thereaction bounds in a cobra model to facilitate running Eflux2

# %%
import sys
sys.path.append('../src')
sys.path.append('/Users/mahs128/Repos/CONCERTO')
from concerto.helpers.load_model_from_git import load_model_from_git
from eflux2 import EFlux2
import cobra
import pandas as pd
import numpy as np
import gurobipy

# %% [markdown]
# ### 1. Run flux variability analysis on the reference strain to get (reasonably) tight bounds on the fluxes.

# %%
# Load SBML model
syn_model = cobra.io.read_sbml_model('../models/iJB785_w_sucrose_transport.xml')
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"

# %%
print(syn_model.objective)
# Out:
# Maximize
# 1.0*BIOMASS__1 - 1.0*BIOMASS__1_reverse_063c7

# %%
# Incorporate reference strain information into the model

# Get metabolic rates
rates_fname = "processed_data/cleaned_metabolomic_abundance_rates.csv"
rates_df = pd.read_csv(rates_fname, index_col="Sample")

# Get transcriptomics
transcriptomics_fname = "processed_data/cleaned_transcriptomics.csv"
transcriptomics_df = pd.read_csv(transcriptomics_fname, index_col="Label")

# Define reference strain
ref_rep = transcriptomics_df.columns[4] # 'Se_axen_d6_2'
ref_rep
# Out:
# 'Se_axen_d6_2'

# %%
# Run optimization on cobra model to get fluxes for reactions of interest
# sucrose production ('EX_sucr_e') and CO2 uptake ('EX_co2_e') and biomass ('BIOMASS__1')
opt_df = syn_model.optimize().to_frame()
display(opt_df)
display(opt_df.loc['EX_sucr_e'])
display(opt_df.loc['EX_co2_e'])
display(opt_df.loc['BIOMASS__1'])
# Out:
#               fluxes  reduced_costs
# EX_gln__L_e  0.00000   0.000000e+00
# EX_hco3_e   -1.99000   0.000000e+00
# EX_mn2_e     0.00000   0.000000e+00
# EX_arg__L_e  0.00000   0.000000e+00
# ADPT         0.00001  -3.108624e-14
# ...              ...            ...
# MDDEP3pp     0.00000   0.000000e+00
# MDDEP4pp     0.00000   0.000000e+00
# MNHNAtpp     0.00000   0.000000e+00
# EX_sucr_e    0.01100   0.000000e+00
# SUCRt2      -0.01100   0.000000e+00
#
# [851 rows x 2 columns]
# fluxes           0.011
# reduced_costs    0.000
# Name: EX_sucr_e, dtype: float64
# fluxes          -0.316958
# reduced_costs    0.000000
# Name: EX_co2_e, dtype: float64
# fluxes           5.390187e-02
# reduced_costs   -8.526513e-14
# Name: BIOMASS__1, dtype: float64

# %%
# Specify upper/lower bounds of model for excluded reactions
for rxn in ['EX_sucr_e', 'EX_co2_e', 'BIOMASS__1']:
   syn_model.reactions.get_by_id(rxn).lower_bound = opt_df.loc[rxn, 'fluxes']

   print(rxn, ": ", syn_model.reactions.get_by_id(rxn).lower_bound, ";  ", syn_model.reactions.get_by_id(rxn).upper_bound)
# Out:
# EX_sucr_e :  0.011 ;   1000.0
# EX_co2_e :  -0.3169581181768563 ;   1000.0
# BIOMASS__1 :  0.05390186774577897 ;   2.0

# %%
# Create reactions list exclude reactions of interest: sucrose production ('EX_sucr_e') and CO2 uptake ('EX_co2_e') and biomass ('BIOMASS__1') 
rxn_list = [r.id for r in syn_model.reactions if (r.id not in ['EX_sucr_e', 'EX_co2_e', 'BIOMASS__1'])]

# %%
# Compared optimized fluxes to calculated rates of observed metabolic abundances
rates_df.loc['sucr'][ref_rep]
# Out:
# 1327111.5

# %%
# Run FVA (~30-40 seconds)
FVA_object = cobra.flux_analysis.flux_variability_analysis(model=syn_model, reaction_list=rxn_list, 
                                                           fraction_of_optimum=0.85, processes=8)
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpmyv46l2d.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmptturazn8.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpvpvtw8b6.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp217ttvo_.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpp2dkhdpw.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpk874_6o_.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpqhlj2ete.lp
# Reading time = 0.14 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp6znn73na.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp_71lhu3a.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpchcqaiej.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmptsmt4le4.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpusvwu2mh.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpf9lyuzpt.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpw3y6m98f.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp1o51he3k.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpffhcvhsp.lp
# Reading time = 0.01 seconds
# : 770 rows, 1703 columns, 7655 nonzeros

# %%
FVA_object
# Out:
#              minimum     maximum
# EX_gln__L_e  0.00000    0.000000
# EX_hco3_e   -1.99000   -1.989283
# EX_mn2_e     0.00000    0.000000
# EX_arg__L_e  0.00000    0.000000
# ADPT         0.00001    0.000010
# ...              ...         ...
# MDDEP2pp     0.00000    0.000000
# MDDEP3pp     0.00000   71.169417
# MDDEP4pp     0.00000   47.446278
# MNHNAtpp     0.00000  388.340298
# SUCRt2      -0.01106   -0.011000
#
# [848 rows x 2 columns]

# %% [markdown]
#  ### 2. Next, convert the transcriptomics data to enzyme data (Take the min of subunits, take the sum of isozymes)

# %%
# Load transciptomics data
transcriptomics_fname = "processed_data/cleaned_transcriptomics.csv"
transcriptomics_df = pd.read_csv(transcriptomics_fname, index_col="Label")
transcriptomics_df.head()
# Out:
#                     Se_axen_d4_1  Se_axen_d4_2  Se_axen_d4_3  Se_axen_d6_1  \
# Label
# SYNPCC7942_RS00005         16290         17761         15101         14567
# SYNPCC7942_RS00010          7185          7502          6565         10086
# SYNPCC7942_RS00015         24176         26304         22781         23926
# SYNPCC7942_RS00020         35119         35145         25895         37701
# SYNPCC7942_RS00025          6891          7803          6607          6347
#
#                     Se_axen_d6_2  Se_axen_d6_3  Se_axen_d8_1  Se_axen_d8_2  \
# Label
# SYNPCC7942_RS00005         13967         12653          7016          8855
# SYNPCC7942_RS00010          7546          7705          3747          6670
# SYNPCC7942_RS00015         21306         20412         13440         17253
# SYNPCC7942_RS00020         34175         30569         24835         39769
# SYNPCC7942_RS00025          6284          6844          3326          4146
#
#                     Se_axen_d8_3
# Label
# SYNPCC7942_RS00005          8689
# SYNPCC7942_RS00010          6960
# SYNPCC7942_RS00015         17053
# SYNPCC7942_RS00020         30280
# SYNPCC7942_RS00025          3180

# %%
# Set reference strain
ref_rep = transcriptomics_df.columns[4] # 'Se_axen_d6_2'
ref_rep
# Out:
# 'Se_axen_d6_2'

# %%
# Normalize transcriptomics data w.r.t. reference strain
normalized_transcriptomics_df = transcriptomics_df.div(transcriptomics_df[ref_rep], axis=0)
normalized_transcriptomics_df.head()
# Out:
#                     Se_axen_d4_1  Se_axen_d4_2  Se_axen_d4_3  Se_axen_d6_1  \
# Label
# SYNPCC7942_RS00005      1.166321      1.271640      1.081191      1.042958
# SYNPCC7942_RS00010      0.952160      0.994169      0.869997      1.336602
# SYNPCC7942_RS00015      1.134704      1.234582      1.069229      1.122970
# SYNPCC7942_RS00020      1.027623      1.028383      0.757718      1.103175
# SYNPCC7942_RS00025      1.096595      1.241725      1.051400      1.010025
#
#                     Se_axen_d6_2  Se_axen_d6_3  Se_axen_d8_1  Se_axen_d8_2  \
# Label
# SYNPCC7942_RS00005           1.0      0.905921      0.502327      0.633994
# SYNPCC7942_RS00010           1.0      1.021071      0.496554      0.883912
# SYNPCC7942_RS00015           1.0      0.958040      0.630808      0.809772
# SYNPCC7942_RS00020           1.0      0.894484      0.726701      1.163687
# SYNPCC7942_RS00025           1.0      1.089115      0.529281      0.659771
#
#                     Se_axen_d8_3
# Label
# SYNPCC7942_RS00005      0.622109
# SYNPCC7942_RS00010      0.922343
# SYNPCC7942_RS00015      0.800385
# SYNPCC7942_RS00020      0.886028
# SYNPCC7942_RS00025      0.506047

# %%
# Snippet of code borrowed from eflux2.py to populate the first inpur argument of the gene_expression_to_enzyme_activity() function

# Parse GPR into a dict containing isozymes (separated by 'or')
# Each isozyme has a set of subunits (separated by 'and')
gpr_dict = dict()
for r in syn_model.reactions:
    if r.gene_reaction_rule:
        temp = set()
        for x in [x.strip('() ') for x in r.gene_reaction_rule.split(' or ')]:
            temp.add(frozenset(y.strip('() ') for y in x.split(' and ')))
        gpr_dict[r] = temp

gpr_dict
# Out:
# {<Reaction ADPT at 0x2b3b99f90>: {frozenset({'Synpcc7942_2454'})},
#  <Reaction DTMPK at 0x2b3ba3390>: {frozenset({'SYNPCC7942_RS00470'})},
#  <Reaction ORNTA at 0x2b3b9b950>: {frozenset({'Synpcc7942_0034'})},
#  <Reaction ACOATA at 0x2b3badd10>: {frozenset({'SYNPCC7942_RS07445'})},
#  <Reaction 3HAD160 at 0x2b3ba6a50>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction RNDR3 at 0x2b3bb9190>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction G5SD at 0x2b3ba56d0>: {frozenset({'SYNPCC7942_RS11385'}),
#   frozenset({'SYNPCC7942_RS11510'})},
#  <Reaction HISTDa at 0x2b3bbbdd0>: {frozenset({'SYNPCC7942_RS07765'})},
#  <Reaction TRPS3 at 0x2b3bc6590>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction DMBZIDS2 at 0x2b3bb9290>: {frozenset({'SYNPCC7942_RS08460'}),
#   frozenset({'SYNPCC7942_RS10185'})},
#  <Reaction HSTPT at 0x2b3bc6550>: {frozenset({'SYNPCC7942_RS05290'})},
#  <Reaction ZCAROTDH2 at 0x2b3bc7710>: {frozenset({'SYNPCC7942_RS06385',
#              'SYNPCC7942_RS07730'})},
#  <Reaction ORNDC at 0x2b3bbbe50>: {frozenset({'SYNPCC7942_RS03625'})},
#  <Reaction GND at 0x2b3bcde90>: {frozenset({'SYNPCC7942_RS00195'})},
#  <Reaction CMPA_1 at 0x2b3bcf190>: {frozenset({'SYNPCC7942_RS10895'})},
#  <Reaction U23GAAT2 at 0x2b3bd8350>: {frozenset({'SYNPCC7942_RS07415'})},
#  <Reaction HOXGfx at 0x2b3bd9cd0>: {frozenset({'SYNPCC7942_RS09425'})},
#  <Reaction PGK at 0x2b3bdb350>: {frozenset({'SYNPCC7942_RS05720'})},
#  <Reaction IMPD at 0x2b3be8610>: {frozenset({'SYNPCC7942_RS09290'})},
#  <Reaction LPOR at 0x2b3be8fd0>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction CHRPL at 0x2b3be92d0>: {frozenset({'SYNPCC7942_RS00460'})},
#  <Reaction GCALDDy at 0x2b3bebd10>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction MSBENZMT at 0x2b3bf1690>: {frozenset({'SYNPCC7942_RS03055'})},
#  <Reaction DESAT18a at 0x2b3bd8550>: {frozenset({'SYNPCC7942_RS13015'})},
#  <Reaction FUM at 0x2b3bf2f10>: {frozenset({'SYNPCC7942_RS05170'})},
#  <Reaction PHYFXOR at 0x2b3be8650>: {frozenset({'SYNPCC7942_RS06275'})},
#  <Reaction TMPPP_1 at 0x2b3bc6710>: {frozenset({'SYNPCC7942_RS05420'})},
#  <Reaction VPAMTr at 0x2b3bf5c50>: {frozenset({'SYNPCC7942_RS11475'})},
#  <Reaction RNDR1 at 0x2b3bf7410>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction TALA at 0x2b3bf7e90>: {frozenset({'SYNPCC7942_RS11675'})},
#  <Reaction GLYCL at 0x2b3c08cd0>: {frozenset({'SYNPCC7942_RS10380',
#              'SYNPCC7942_RS10385',
#              'SYNPCC7942_RS11730'})},
#  <Reaction ACONT at 0x2b3c09dd0>: {frozenset({'SYNPCC7942_RS04655'})},
#  <Reaction NDPK7 at 0x2b3bd8950>: {frozenset({'SYNPCC7942_RS12670'})},
#  <Reaction GTPCI at 0x2b3c0bb90>: {frozenset({'SYNPCC7942_RS08155'})},
#  <Reaction AIRC2 at 0x2b3c0d310>: {frozenset({'SYNPCC7942_RS07305'})},
#  <Reaction IGPS at 0x2b3c0e390>: {frozenset({'SYNPCC7942_RS06130'})},
#  <Reaction MTAP at 0x2b3c0f190>: {frozenset({'SYNPCC7942_RS04750'})},
#  <Reaction HEMEAS_1 at 0x2b3c14b50>: {frozenset({'SYNPCC7942_RS13250'})},
#  <Reaction DHORD3um at 0x2b3c16090>: {frozenset({'SYNPCC7942_RS01475'})},
#  <Reaction MTHFC at 0x2b3c17210>: {frozenset({'SYNPCC7942_RS04030'})},
#  <Reaction HBZNPT at 0x2b3c08d90>: {frozenset({'SYNPCC7942_RS09965'})},
#  <Reaction GCATENEC at 0x2b3c0d990>: {frozenset({'SYNPCC7942_RS10460'})},
#  <Reaction COCHL_1 at 0x2b3c2a5d0>: {frozenset({'SYNPCC7942_RS00495',
#              'SYNPCC7942_RS04275'})},
#  <Reaction HSDy at 0x2b3c2b990>: {frozenset({'SYNPCC7942_RS10595'})},
#  <Reaction TRPS1 at 0x2b3c36390>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction HISTDb at 0x2b3be9010>: {frozenset({'SYNPCC7942_RS07765'})},
#  <Reaction UPPDC1 at 0x2b3c36310>: {frozenset({'SYNPCC7942_RS05575'})},
#  <Reaction GARFT at 0x2b3bf7f50>: {frozenset({'SYNPCC7942_RS04925'})},
#  <Reaction H4THDPR at 0x2b3c3c9d0>: {frozenset({'SYNPCC7942_RS10835'})},
#  <Reaction UDPG4E at 0x2b3c3dad0>: {frozenset({'SYNPCC7942_RS01630'})},
#  <Reaction GLCS3 at 0x2b3c3ec90>: {frozenset({'SYNPCC7942_RS12785'})},
#  <Reaction AICART at 0x2b3c3fb90>: {frozenset({'SYNPCC7942_RS02020'})},
#  <Reaction ASPTA at 0x2b3c0d3d0>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction GLYOX at 0x2b3c0f250>: {frozenset({'SYNPCC7942_RS04820'}),
#   frozenset({'SYNPCC7942_RS07180'})},
#  <Reaction PRAGSr at 0x2b3c4a850>: {frozenset({'SYNPCC7942_RS04760'})},
#  <Reaction SQD1 at 0x2b3c4b9d0>: {frozenset({'SYNPCC7942_RS02940'})},
#  <Reaction ACKr at 0x2b3c55e10>: {frozenset({'SYNPCC7942_RS10540'})},
#  <Reaction UDCPDPS at 0x2b3c57310>: {frozenset({'SYNPCC7942_RS01345'})},
#  <Reaction GK1 at 0x2b3c58a50>: {frozenset({'SYNPCC7942_RS06100'})},
#  <Reaction SHKK at 0x2b3bd8590>: {frozenset({'SYNPCC7942_RS04605'})},
#  <Reaction OXADC at 0x2b3c5abd0>: {frozenset({'SYNPCC7942_RS12135'})},
#  <Reaction G1PACT at 0x2b3c5ba50>: {frozenset({'SYNPCC7942_RS01465'})},
#  <Reaction 3HAD60 at 0x2b3c368d0>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction PGI at 0x2b3c37750>: {frozenset({'SYNPCC7942_RS10295'})},
#  <Reaction KAS14 at 0x2b3c28650>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction OHPBAT at 0x2b3bf74d0>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction 3HAD80 at 0x2b3c7ae50>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction 3OAR160 at 0x2b3c7c7d0>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction NMNS at 0x2b3c57590>: {frozenset({'SYNPCC7942_RS01045'})},
#  <Reaction PPK at 0x2b3c648d0>: {frozenset({'SYNPCC7942_RS08000'})},
#  <Reaction GALUi at 0x2b3c668d0>: {frozenset({'SYNPCC7942_RS10005'})},
#  <Reaction PHYTES2_1 at 0x2b3c7e290>: {frozenset({'SYNPCC7942_RS10060'})},
#  <Reaction IGPDH at 0x2b3c7f350>: {frozenset({'SYNPCC7942_RS00635'})},
#  <Reaction OMPDC at 0x2b3c7fe90>: {frozenset({'SYNPCC7942_RS13055'})},
#  <Reaction DCTPD at 0x2b3c5acd0>: {frozenset({'SYNPCC7942_RS03695'})},
#  <Reaction GLUSfx at 0x2b3c89e50>: {frozenset({'SYNPCC7942_RS04585'})},
#  <Reaction NADS2 at 0x2b3c8ab50>: {frozenset({'SYNPCC7942_RS00535'})},
#  <Reaction GLUTRR at 0x2b3c8bf50>: {frozenset({'SYNPCC7942_RS02560'})},
#  <Reaction G1PTT at 0x2b3c95250>: {frozenset({'SYNPCC7942_RS10650'})},
#  <Reaction UAMAGS at 0x2b3c8bf90>: {frozenset({'SYNPCC7942_RS08500'})},
#  <Reaction SPS at 0x2b3ca4310>: {frozenset({'SYNPCC7942_RS04180'})},
#  <Reaction ADCL at 0x2b3ca5150>: {frozenset({'SYNPCC7942_RS06825'})},
#  <Reaction CYTK1 at 0x2b3c3ed50>: {frozenset({'SYNPCC7942_RS05900'})},
#  <Reaction DAPDC at 0x2b3ca7790>: {frozenset({'SYNPCC7942_RS01335'})},
#  <Reaction PSIum at 0x2b3c96250>: {frozenset({'SYNPCC7942_RS02075',
#              'SYNPCC7942_RS02720',
#              'SYNPCC7942_RS03350',
#              'SYNPCC7942_RS04735',
#              'SYNPCC7942_RS05140',
#              'SYNPCC7942_RS06400',
#              'SYNPCC7942_RS06405',
#              'SYNPCC7942_RS06760',
#              'SYNPCC7942_RS09705',
#              'SYNPCC7942_RS10390',
#              'SYNPCC7942_RS10395',
#              'SYNPCC7942_RS11800',
#              'SYNPCC7942_RS11900',
#              'SYNPCC7942_RS11905',
#              'SYNPCC7942_RS12755'})},
#  <Reaction R05219 at 0x2b3cb1550>: {frozenset({'SYNPCC7942_RS00965'})},
#  <Reaction Cobalt2abcppI at 0x2b3c0da50>: {frozenset({'SYNPCC7942_RS02850',
#              'SYNPCC7942_RS08360',
#              'SYNPCC7942_RS11895'})},
#  <Reaction PFK_3 at 0x2b3cb1610>: {frozenset({'SYNPCC7942_RS03035'})},
#  <Reaction THRS at 0x2b3cbc3d0>: {frozenset({'SYNPCC7942_RS13305'}),
#   frozenset({'SYNPCC7942_RS09055'})},
#  <Reaction NAMNPP at 0x2b3c5bb10>: {frozenset({'SYNPCC7942_RS01045'})},
#  <Reaction FOLD3 at 0x2b3c89790>: {frozenset({'SYNPCC7942_RS11705'})},
#  <Reaction P5CR at 0x2b3ccd990>: {frozenset({'SYNPCC7942_RS10440'})},
#  <Reaction MEHLER_1 at 0x2b3cce9d0>: {frozenset({'SYNPCC7942_RS09190',
#              'SYNPCC7942_RS09195'})},
#  <Reaction ICHORS at 0x2b3ccc490>: {frozenset({'SYNPCC7942_RS11120'})},
#  <Reaction 3OAS140 at 0x2b3c89710>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction PPK2 at 0x2b3ccc910>: {frozenset({'SYNPCC7942_RS08000'})},
#  <Reaction IPDPS_syn at 0x2b3ccc890>: {frozenset({'SYNPCC7942_RS00360'})},
#  <Reaction GLYDHDA at 0x2b3c3dbd0>: {frozenset({'SYNPCC7942_RS08945'})},
#  <Reaction SBP at 0x2b3c3db50>: {frozenset({'SYNPCC7942_RS02565'})},
#  <Reaction H4THDPS at 0x2b3ce1890>: {frozenset({'SYNPCC7942_RS09370'})},
#  <Reaction EAR60y at 0x2b3ce2990>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction ZNabcpp at 0x2b3c659d0>: {frozenset({'SYNPCC7942_RS06730',
#              'SYNPCC7942_RS06735',
#              'SYNPCC7942_RS06740'}),
#   frozenset({'SYNPCC7942_RS13075',
#              'SYNPCC7942_RS13080',
#              'SYNPCC7942_RS13085'})},
#  <Reaction UAPGR at 0x2b3cd26d0>: {frozenset({'SYNPCC7942_RS08855'})},
#  <Reaction DHAD1 at 0x2b3cebe10>: {frozenset({'SYNPCC7942_RS03210'})},
#  <Reaction IPPS at 0x2b3cea590>: {frozenset({'SYNPCC7942_RS02185'})},
#  <Reaction ANS at 0x2b3cebcd0>: {frozenset({'SYNPCC7942_RS02040',
#              'SYNPCC7942_RS05145'})},
#  <Reaction SUCBZL at 0x2b3c7ff50>: {frozenset({'SYNPCC7942_RS05250'})},
#  <Reaction ADSL1r at 0x2b3cf6950>: {frozenset({'SYNPCC7942_RS01605'})},
#  <Reaction NNATr at 0x2b3c953d0>: {frozenset({'SYNPCC7942_RS00540'}),
#   frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction PERD at 0x2b3d011d0>: {frozenset({'SYNPCC7942_RS08150'})},
#  <Reaction PPBNGS at 0x2b3d02890>: {frozenset({'SYNPCC7942_RS09105'})},
#  <Reaction ADOCBLS at 0x2b3c95310>: {frozenset({'SYNPCC7942_RS02320'})},
#  <Reaction LTHRK at 0x2b3cf4090>: {frozenset({'SYNPCC7942_RS06620'}),
#   frozenset({'SYNPCC7942_RS03080'}),
#   frozenset({'SYNPCC7942_RS05695'}),
#   frozenset({'SYNPCC7942_RS05745'}),
#   frozenset({'SYNPCC7942_RS04045'})},
#  <Reaction PPS at 0x2b3d0e7d0>: {frozenset({'SYNPCC7942_RS04050'})},
#  <Reaction PDS2_1 at 0x2b3d10650>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction ALAALAr at 0x2b3c96390>: {frozenset({'SYNPCC7942_RS12070'})},
#  <Reaction ADCPS2 at 0x2b3d20dd0>: {frozenset({'SYNPCC7942_RS07370'})},
#  <Reaction GF6PTA at 0x2b3cbca90>: {frozenset({'SYNPCC7942_RS02715'})},
#  <Reaction PGMT at 0x2b3c0e450>: {frozenset({'SYNPCC7942_RS00790'})},
#  <Reaction GLCP2_1 at 0x2b3d0d750>: {frozenset({'SYNPCC7942_RS01245'})},
#  <Reaction AGDI_1 at 0x2b3d01790>: {frozenset({'SYNPCC7942_RS12205'})},
#  <Reaction LPADSS2 at 0x2b3c367d0>: {frozenset({'SYNPCC7942_RS04795'})},
#  <Reaction GLYCK at 0x2b3d0d5d0>: {frozenset({'SYNPCC7942_RS05115'})},
#  <Reaction DPR at 0x2b3d2fd10>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction EAR120y at 0x2b3d31410>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction MAN1PT at 0x2b3d33650>: {frozenset({'SYNPCC7942_RS08205'})},
#  <Reaction NMNAT at 0x2b3d32650>: {frozenset({'SYNPCC7942_RS00540'}),
#   frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction TKT2 at 0x2b3d0d990>: {frozenset({'SYNPCC7942_RS02735'})},
#  <Reaction PSP_L at 0x2b3d30a50>: {frozenset({'SYNPCC7942_RS02470'})},
#  <Reaction HEX7 at 0x2b3d0fb50>: {frozenset({'SYNPCC7942_RS00585'})},
#  <Reaction PPNCL2 at 0x2b3c58b50>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction CHORS at 0x2b3d47e50>: {frozenset({'SYNPCC7942_RS01075'})},
#  <Reaction CYTBD4cm at 0x2b3cf7dd0>: {frozenset({'SYNPCC7942_RS08975',
#              'SYNPCC7942_RS08980'})},
#  <Reaction PPNCL3 at 0x2b3d4a350>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction CS at 0x2b3d4b8d0>: {frozenset({'SYNPCC7942_RS03140'})},
#  <Reaction PPCDC at 0x2b3d505d0>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction LDH_D at 0x2b3d51350>: {frozenset({'SYNPCC7942_RS06885'})},
#  <Reaction HPYRRy at 0x2b3cf7f50>: {frozenset({'SYNPCC7942_RS09420'})},
#  <Reaction ADMDC at 0x2b3d58a10>: {frozenset({'SYNPCC7942_RS10365'}),
#   frozenset({'SYNPCC7942_RS11425'})},
#  <Reaction PRE3BS at 0x2b3d59d90>: {frozenset({'SYNPCC7942_RS09390'})},
#  <Reaction PPPGO2_1 at 0x2b3d471d0>: {frozenset({'SYNPCC7942_RS04385'})},
#  <Reaction BIOMASS_DNA at 0x2b3d640d0>: {frozenset({'SYNPCC7942_RS00005',
#              'SYNPCC7942_RS00475',
#              'SYNPCC7942_RS00985',
#              'SYNPCC7942_RS02065',
#              'SYNPCC7942_RS02900',
#              'SYNPCC7942_RS04690',
#              'SYNPCC7942_RS11170'})},
#  <Reaction DMATT at 0x2b3d64fd0>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction DNAMTn2r at 0x2b3d67b50>: {frozenset({'SYNPCC7942_RS12505'})},
#  <Reaction G3PD2 at 0x2b3d66dd0>: {frozenset({'SYNPCC7942_RS12805'})},
#  <Reaction PHYTES at 0x2b3d67a90>: {frozenset({'SYNPCC7942_RS10060'})},
#  <Reaction MI3PP at 0x2b3d76710>: {frozenset({'SYNPCC7942_RS13150'})},
#  <Reaction MOHMT at 0x2b3ce0190>: {frozenset({'SYNPCC7942_RS12100'})},
#  <Reaction FBA at 0x2b3d747d0>: {frozenset({'SYNPCC7942_RS07385'})},
#  <Reaction PROAKGOX1 at 0x2b3c37790>: {frozenset({'SYNPCC7942_RS12600'})},
#  <Reaction ASAD at 0x2b3d4a490>: {frozenset({'SYNPCC7942_RS09375'})},
#  <Reaction CYSS_2 at 0x2b3d8d790>: {frozenset({'SYNPCC7942_RS13425'}),
#   frozenset({'SYNPCC7942_RS00870'}),
#   frozenset({'SYNPCC7942_RS07500'}),
#   frozenset({'SYNPCC7942_RS13380'})},
#  <Reaction LYCOPC at 0x2b3d8d8d0>: {frozenset({'SYNPCC7942_RS10460'})},
#  <Reaction ACOTA at 0x2b3d74550>: {frozenset({'SYNPCC7942_RS04850'})},
#  <Reaction 3HAD180 at 0x2b3d8fad0>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction FTHFD at 0x2b3d95f10>: {frozenset({'SYNPCC7942_RS05175'})},
#  <Reaction ALDD2y at 0x2b3d96d50>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction 3OAS80 at 0x2b3d2c8d0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction PSCVT at 0x2b3d7cb50>: {frozenset({'SYNPCC7942_RS01180'})},
#  <Reaction CBPS at 0x2b3d77850>: {frozenset({'SYNPCC7942_RS03645',
#              'SYNPCC7942_RS10760'})},
#  <Reaction NTPP8 at 0x2b3cbca50>: {frozenset({'SYNPCC7942_RS07630'})},
#  <Reaction MEPCT at 0x2b3d11950>: {frozenset({'SYNPCC7942_RS03490'})},
#  <Reaction PDX5POi at 0x2b3dacc10>: {frozenset({'SYNPCC7942_RS00345'})},
#  <Reaction DHAD2 at 0x2b3daee50>: {frozenset({'SYNPCC7942_RS03210'})},
#  <Reaction DHFS at 0x2b3dacc50>: {frozenset({'SYNPCC7942_RS04855'})},
#  <Reaction PGCD at 0x2b3d11f50>: {frozenset({'SYNPCC7942_RS07670'})},
#  <Reaction SPMDabcpp at 0x2b3db6450>: {frozenset({'SYNPCC7942_RS11515'})},
#  <Reaction NTD6 at 0x2b3db7010>: {frozenset({'SYNPCC7942_RS10465'})},
#  <Reaction NNDMBRT at 0x2b3d67e10>: {frozenset({'SYNPCC7942_RS11525'})},
#  <Reaction PRATPP at 0x2b3daefd0>: {frozenset({'SYNPCC7942_RS10115'})},
#  <Reaction ASNN at 0x2b3dbf1d0>: {frozenset({'SYNPCC7942_RS00840'})},
#  <Reaction SERAT at 0x2b3d96450>: {frozenset({'SYNPCC7942_RS13375'}),
#   frozenset({'SYNPCC7942_RS12295'})},
#  <Reaction PRAIS at 0x2b3dbf250>: {frozenset({'SYNPCC7942_RS04395'})},
#  <Reaction PRAMPC at 0x2b3daf410>: {frozenset({'SYNPCC7942_RS10115'})},
#  <Reaction AMPMS3 at 0x2b3dc7a50>: {frozenset({'SYNPCC7942_RS05625'})},
#  <Reaction G1PCTYT at 0x2b3dd0b10>: {frozenset({'SYNPCC7942_RS00310'})},
#  <Reaction ACBIPGT at 0x2b3db7090>: {frozenset({'SYNPCC7942_RS13875'})},
#  <Reaction SEPHCHCS at 0x2b3dd2cd0>: {frozenset({'SYNPCC7942_RS07340'})},
#  <Reaction NMNDA at 0x2b3d46d50>: {frozenset({'SYNPCC7942_RS01425'})},
#  <Reaction CA2abcpp at 0x2b3d01210>: {frozenset({'SYNPCC7942_RS05555'})},
#  <Reaction ORNTAC at 0x2b3dddd50>: {frozenset({'SYNPCC7942_RS09615'})},
#  <Reaction SUCBZS at 0x2b3ddee90>: {frozenset({'SYNPCC7942_RS05245'})},
#  <Reaction UHGADA2 at 0x2b3dbc750>: {frozenset({'SYNPCC7942_RS04780'})},
#  <Reaction DHNANT at 0x2b3de5850>: {frozenset({'SYNPCC7942_RS06990',
#              'SYNPCC7942_RS12725'})},
#  <Reaction ASPO6 at 0x2b3d44750>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction HGYDAS at 0x2b3dbc650>: {frozenset({'SYNPCC7942_RS09410'})},
#  <Reaction GGDPR at 0x2b3dc7b10>: {frozenset({'SYNPCC7942_RS01965'})},
#  <Reaction ASP1DC at 0x2b3df5010>: {frozenset({'SYNPCC7942_RS11740'})},
#  <Reaction PPNDH at 0x2b3df6190>: {frozenset({'SYNPCC7942_RS04540'})},
#  <Reaction ASPK at 0x2b3df7850>: {frozenset({'SYNPCC7942_RS05135'})},
#  <Reaction DXPS at 0x2b3d58b50>: {frozenset({'SYNPCC7942_RS02195'})},
#  <Reaction ME2 at 0x2b3df97d0>: {frozenset({'SYNPCC7942_RS06635'})},
#  <Reaction DDPGA at 0x2b3dbda90>: {frozenset({'SYNPCC7942_RS00090'})},
#  <Reaction PAPSR at 0x2b3e05a50>: {frozenset({'SYNPCC7942_RS12715'})},
#  <Reaction SADT at 0x2b3e048d0>: {frozenset({'SYNPCC7942_RS01505'})},
#  <Reaction DPCOAK at 0x2b3e06c90>: {frozenset({'SYNPCC7942_RS01390'})},
#  <Reaction NH4tpp at 0x2b3e0d350>: {frozenset({'SYNPCC7942_RS02260'}),
#   frozenset({'SYNPCC7942_RS11585'})},
#  <Reaction PC11M at 0x2b3cf5fd0>: {frozenset({'SYNPCC7942_RS06300'})},
#  <Reaction DPOR at 0x2b3e12a10>: {frozenset({'SYNPCC7942_RS07260',
#              'SYNPCC7942_RS07265',
#              'SYNPCC7942_RS09325'})},
#  <Reaction ARGSL at 0x2b3ddffd0>: {frozenset({'SYNPCC7942_RS12575'})},
#  <Reaction HSK at 0x2b3dc6310>: {frozenset({'SYNPCC7942_RS07365'})},
#  <Reaction MTHFD at 0x2b3dfab90>: {frozenset({'SYNPCC7942_RS04030'})},
#  <Reaction PMDPHT at 0x2b3e21610>: {frozenset({'SYNPCC7942_RS05155'})},
#  <Reaction ARGabcpp at 0x2b3e22a90>: {frozenset({'SYNPCC7942_RS01255',
#              'SYNPCC7942_RS01260',
#              'SYNPCC7942_RS01265',
#              'SYNPCC7942_RS01270'})},
#  <Reaction 3HAD140 at 0x2b3d65110>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ARGOXRum at 0x2b3e31490>: {frozenset({'SYNPCC7942_RS01880'})},
#  <Reaction DAPE at 0x2b3df5390>: {frozenset({'SYNPCC7942_RS09780'})},
#  <Reaction BCAROHX2 at 0x2b3e32d50>: {frozenset({'SYNPCC7942_RS12395'})},
#  <Reaction HPPK at 0x2b3e20210>: {frozenset({'SYNPCC7942_RS11545'})},
#  <Reaction PANTS at 0x2b3d8fdd0>: {frozenset({'SYNPCC7942_RS05900'})},
#  <Reaction AHCi at 0x2b3e3d8d0>: {frozenset({'SYNPCC7942_RS03170'})},
#  <Reaction G6PDH2r at 0x2b3de6810>: {frozenset({'SYNPCC7942_RS11865'})},
#  <Reaction ALAD_L at 0x2b3d7e790>: {frozenset({'SYNPCC7942_RS08945'})},
#  <Reaction GTPCII at 0x2b3df8810>: {frozenset({'SYNPCC7942_RS07325'})},
#  <Reaction GLCBRAN3 at 0x2b3e49e10>: {frozenset({'SYNPCC7942_RS09580'}),
#   frozenset({'SYNPCC7942_RS05570'})},
#  <Reaction DB4PS at 0x2b3e3ea50>: {frozenset({'SYNPCC7942_RS07325'})},
#  <Reaction DXPRIi at 0x2b3e3ead0>: {frozenset({'SYNPCC7942_RS07735'})},
#  <Reaction FBA3 at 0x2b3e51ad0>: {frozenset({'SYNPCC7942_RS07385'})},
#  <Reaction RBFSa at 0x2b3e52490>: {frozenset({'SYNPCC7942_RS11395'})},
#  <Reaction GLUTRS at 0x2b3e53690>: {frozenset({'SYNPCC7942_RS12160'})},
#  <Reaction MPOMMM at 0x2b3e58590>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction METAT at 0x2b3e528d0>: {frozenset({'SYNPCC7942_RS12520'})},
#  <Reaction EAR160y at 0x2b3e48a90>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DHORTS at 0x2b3e5b8d0>: {frozenset({'SYNPCC7942_RS02485'})},
#  <Reaction PDX5PS2 at 0x2b3e64c50>: {frozenset({'SYNPCC7942_RS06115'})},
#  <Reaction KARI_23dhmp_1 at 0x2b3e66990>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction ARGDC at 0x2b3e3d9d0>: {frozenset({'SYNPCC7942_RS05325'})},
#  <Reaction GAPDi_nadp at 0x2b3dd2010>: {frozenset({'SYNPCC7942_RS08865'})},
#  <Reaction NTD7 at 0x2b3e71750>: {frozenset({'SYNPCC7942_RS10465'})},
#  <Reaction AIRC3 at 0x2b3e72250>: {frozenset({'SYNPCC7942_RS02255'})},
#  <Reaction UMPK at 0x2b3e73590>: {frozenset({'SYNPCC7942_RS02570'})},
#  <Reaction ASPOb at 0x2b3e33010>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction RBFSb_1 at 0x2b3e75f10>: {frozenset({'SYNPCC7942_RS08285'})},
#  <Reaction SUCDum at 0x2b3e769d0>: {frozenset({'SYNPCC7942_RS01600',
#              'SYNPCC7942_RS03290',
#              'SYNPCC7942_RS07835'})},
#  <Reaction FBP at 0x2b3e77b10>: {frozenset({'SYNPCC7942_RS02565'}),
#   frozenset({'SYNPCC7942_RS11870'})},
#  <Reaction CITCIb at 0x2b3e84990>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction MNabc_1 at 0x2b3e74ad0>: {frozenset({'SYNPCC7942_RS06730',
#              'SYNPCC7942_RS06735',
#              'SYNPCC7942_RS06740'}),
#   frozenset({'SYNPCC7942_RS13075',
#              'SYNPCC7942_RS13080',
#              'SYNPCC7942_RS13085'})},
#  <Reaction TMPK at 0x2b3dd2050>: {frozenset({'SYNPCC7942_RS13045'})},
#  <Reaction AGPR at 0x2b3e33390>: {frozenset({'SYNPCC7942_RS07330'})},
#  <Reaction IPMD at 0x2b3e853d0>: {frozenset({'SYNPCC7942_RS07690'})},
#  <Reaction CDPMEK at 0x2b3e89c10>: {frozenset({'SYNPCC7942_RS01580'})},
#  <Reaction DVOCHR_1 at 0x2b3e8b950>: {frozenset({'SYNPCC7942_RS06950'})},
#  <Reaction H2CO3_NAt_syn at 0x2b3e908d0>: {frozenset({'SYNPCC7942_RS07540'})},
#  <Reaction HEMEOS at 0x2b3e4b190>: {frozenset({'SYNPCC7942_RS13245'})},
#  <Reaction PMANM at 0x2b3e92610>: {frozenset({'SYNPCC7942_RS06495'})},
#  <Reaction RPE at 0x2b3e8a510>: {frozenset({'SYNPCC7942_RS03100'})},
#  <Reaction MPOMT_1 at 0x2b3e93d50>: {frozenset({'SYNPCC7942_RS02245'})},
#  <Reaction CPPPGO2 at 0x2b3e8a7d0>: {frozenset({'SYNPCC7942_RS12105'})},
#  <Reaction PC17M_1 at 0x2b3e52650>: {frozenset({'SYNPCC7942_RS09405'})},
#  <Reaction UAMAS at 0x2b3d4b950>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction GLUCYS at 0x2b3de75d0>: {frozenset({'SYNPCC7942_RS11455'})},
#  <Reaction NDHPQRum at 0x2b3e70890>: {frozenset({'SYNPCC7942_RS01005'}),
#   frozenset({'SYNPCC7942_RS00515'})},
#  <Reaction CYNL at 0x2b3eadc90>: {frozenset({'SYNPCC7942_RS10665'})},
#  <Reaction DCTPD2 at 0x2b3d038d0>: {frozenset({'SYNPCC7942_RS09635'})},
#  <Reaction CYOOum at 0x2b3ebca90>: {frozenset({'SYNPCC7942_RS13255',
#              'SYNPCC7942_RS13260',
#              'SYNPCC7942_RS13265'})},
#  <Reaction BPNT2 at 0x2b3ebd350>: {frozenset({'SYNPCC7942_RS04960'}),
#   frozenset({'SYNPCC7942_RS00880'})},
#  <Reaction METS_1 at 0x2b3e04a10>: {frozenset({'SYNPCC7942_RS07020'})},
#  <Reaction PRUK at 0x2b3ebf590>: {frozenset({'SYNPCC7942_RS05015'})},
#  <Reaction FNOR_1 at 0x2b3ec4390>: {frozenset({'SYNPCC7942_RS05020'})},
#  <Reaction GART at 0x2b3e669d0>: {frozenset({'SYNPCC7942_RS03015'})},
#  <Reaction IPPMIb at 0x2b3ec6b90>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction DMTPHT at 0x2b3ec7a50>: {frozenset({'SYNPCC7942_RS05635'})},
#  <Reaction PC6YM_1 at 0x2b3ec6c50>: {frozenset({'SYNPCC7942_RS09385'})},
#  <Reaction PGL at 0x2b3e88410>: {frozenset({'SYNPCC7942_RS02690'})},
#  <Reaction DDPA at 0x2b3ed2910>: {frozenset({'SYNPCC7942_RS12690'})},
#  <Reaction ASPCT at 0x2b3d9b150>: {frozenset({'SYNPCC7942_RS02475',
#              'SYNPCC7942_RS03430'})},
#  <Reaction HSERTA at 0x2b3e4b1d0>: {frozenset({'SYNPCC7942_RS08720'}),
#   frozenset({'SYNPCC7942_RS01890'})},
#  <Reaction CYRDAAT at 0x2b3ed6fd0>: {frozenset({'SYNPCC7942_RS07095'}),
#   frozenset({'SYNPCC7942_RS04920'}),
#   frozenset({'SYNPCC7942_RS05500'})},
#  <Reaction MECDPDHf at 0x2b3ee5590>: {frozenset({'SYNPCC7942_RS03655'})},
#  <Reaction MTHFR3_1 at 0x2b3e332d0>: {frozenset({'SYNPCC7942_RS06695'})},
#  <Reaction 3HAD40_2 at 0x2b3e33590>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ZCAROTDH1 at 0x2b3ef0ad0>: {frozenset({'SYNPCC7942_RS07730'})},
#  <Reaction GLYALDDy at 0x2b3ef7010>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction IMPC at 0x2b3ef74d0>: {frozenset({'SYNPCC7942_RS02020'})},
#  <Reaction LDAPAT at 0x2b3f08350>: {frozenset({'SYNPCC7942_RS04400'})},
#  <Reaction 3OAR40_2 at 0x2b3f08310>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction RNDR2 at 0x2b3f18450>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction GRTT at 0x2b3f18490>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction NPDPS at 0x2b3ed2a50>: {frozenset({'SYNPCC7942_RS12000'})},
#  <Reaction 3OAS100 at 0x2b3f19c50>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction ADSL2r at 0x2b3f1abd0>: {frozenset({'SYNPCC7942_RS01605'})},
#  <Reaction MAN6PI at 0x2b3f1bfd0>: {frozenset({'SYNPCC7942_RS08205'})},
#  <Reaction HPROb at 0x2b3f20b90>: {frozenset({'SYNPCC7942_RS10440'})},
#  <Reaction 3OAS120 at 0x2b3f21910>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction NTPP2 at 0x2b3ef0cd0>: {frozenset({'SYNPCC7942_RS07630'})},
#  <Reaction EAR180y at 0x2b3f23150>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DHQTi at 0x2b3eadcd0>: {frozenset({'SYNPCC7942_RS04705'})},
#  <Reaction 3OAS60 at 0x2b3f34e50>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR40y at 0x2b3ec7bd0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction MG2uabcpp at 0x2b3f36c90>: {frozenset({'SYNPCC7942_RS06500'})},
#  <Reaction KARA1 at 0x2b3f37a90>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction TKT1 at 0x2b3f38850>: {frozenset({'SYNPCC7942_RS02735'})},
#  <Reaction PTRCabcpp at 0x2b3f392d0>: {frozenset({'SYNPCC7942_RS11515'})},
#  <Reaction IPDDI at 0x2b3f3ab50>: {frozenset({'SYNPCC7942_RS09810'})},
#  <Reaction PKETF at 0x2b3f3ba10>: {frozenset({'SYNPCC7942_RS10545'})},
#  <Reaction ACODA at 0x2b3f444d0>: {frozenset({'SYNPCC7942_RS01305'}),
#   frozenset({'Synpcc7942_1971'})},
#  <Reaction ENO at 0x2b3f45dd0>: {frozenset({'SYNPCC7942_RS03280'})},
#  <Reaction NDHPQRcm at 0x2b3f46c10>: {frozenset({'SYNPCC7942_RS01005'}),
#   frozenset({'SYNPCC7942_RS00515'})},
#  <Reaction NI2uabcpp at 0x2b3f47a50>: {frozenset({'SYNPCC7942_RS11780'}),
#   frozenset({'SYNPCC7942_RS08020'})},
#  <Reaction Kabcpp at 0x2b3f53290>: {frozenset({'SYNPCC7942_RS08505',
#              'SYNPCC7942_RS08510',
#              'SYNPCC7942_RS08515',
#              'SYNPCC7942_RS08800'})},
#  <Reaction TDPDRR at 0x2b3e8ab10>: {frozenset({'SYNPCC7942_RS10640'})},
#  <Reaction UAGCVT at 0x2b3f53250>: {frozenset({'SYNPCC7942_RS03670'})},
#  <Reaction TDPGDH at 0x2b3f60c10>: {frozenset({'SYNPCC7942_RS10645'})},
#  <Reaction PRASCSi at 0x2b3f62610>: {frozenset({'SYNPCC7942_RS04770'})},
#  <Reaction PRFGS at 0x2b3f18690>: {frozenset({'SYNPCC7942_RS00015',
#              'SYNPCC7942_RS04230',
#              'SYNPCC7942_RS04235'})},
#  <Reaction MG2tex at 0x2b3f688d0>: {frozenset({'SYNPCC7942_RS07015'})},
#  <Reaction GLU5K at 0x2b3e58710>: {frozenset({'SYNPCC7942_RS11160'})},
#  <Reaction TRDR at 0x2b3f53850>: {frozenset({'SYNPCC7942_RS03195'})},
#  <Reaction GLUPRT at 0x2b3f70d10>: {frozenset({'SYNPCC7942_RS00020'})},
#  <Reaction PSERT at 0x2b3f72a90>: {frozenset({'SYNPCC7942_RS00970'})},
#  <Reaction PC8XM at 0x2b3f62bd0>: {frozenset({'SYNPCC7942_RS09395'})},
#  <Reaction GMPS2 at 0x2b3e74c10>: {frozenset({'SYNPCC7942_RS00960'})},
#  <Reaction RBFK at 0x2b3ed2ad0>: {frozenset({'SYNPCC7942_RS02505'})},
#  <Reaction NTRIRfx at 0x2b3f83610>: {frozenset({'SYNPCC7942_RS06355'})},
#  <Reaction UPP3MT at 0x2b3f6af10>: {frozenset({'SYNPCC7942_RS01380'})},
#  <Reaction ACS at 0x2b3e12c50>: {frozenset({'SYNPCC7942_RS06910'})},
#  <Reaction DHNCOAS at 0x2b3f87050>: {frozenset({'SYNPCC7942_RS03060'})},
#  <Reaction MCOATA at 0x2b3f87f90>: {frozenset({'SYNPCC7942_RS07450'})},
#  <Reaction GTHPi at 0x2b3f8ce50>: {frozenset({'SYNPCC7942_RS06220'})},
#  <Reaction ARGSS at 0x2b3f19e50>: {frozenset({'SYNPCC7942_RS00045'})},
#  <Reaction PKETX at 0x2b3f8f750>: {frozenset({'SYNPCC7942_RS10545'})},
#  <Reaction PMPK at 0x2b3e89e50>: {frozenset({'SYNPCC7942_RS12090'})},
#  <Reaction HMBS at 0x2b3f9a550>: {frozenset({'SYNPCC7942_RS04970'})},
#  <Reaction PTPATi at 0x2b3f9bcd0>: {frozenset({'SYNPCC7942_RS10180'})},
#  <Reaction PGLYCP at 0x2b3f9cb90>: {frozenset({'SYNPCC7942_RS13310'})},
#  <Reaction HTHRPDH at 0x2b3f9d5d0>: {frozenset({'SYNPCC7942_RS04160'})},
#  <Reaction UAGAAT2 at 0x2b3f82350>: {frozenset({'SYNPCC7942_RS12050'}),
#   frozenset({'SYNPCC7942_RS04790'})},
#  <Reaction SPTc at 0x2b3fa8210>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction GTHOr at 0x2b3f39390>: {frozenset({'SYNPCC7942_RS04355'})},
#  <Reaction TDPDRE at 0x2b3f39310>: {frozenset({'SYNPCC7942_RS10635'}),
#   frozenset({'SYNPCC7942_RS00290'})},
#  <Reaction SHK3Dr at 0x2b3faa790>: {frozenset({'SYNPCC7942_RS12540'})},
#  <Reaction ORPT at 0x2b3fabb50>: {frozenset({'SYNPCC7942_RS13200'})},
#  <Reaction PRPPS at 0x2b3fa9550>: {frozenset({'SYNPCC7942_RS10710'})},
#  <Reaction CITMS at 0x2b3fb1d50>: {frozenset({'SYNPCC7942_RS02185'}),
#   frozenset({'SYNPCC7942_RS07215'})},
#  <Reaction BCT1_syn at 0x2b3f39450>: {frozenset({'SYNPCC7942_RS07605',
#              'SYNPCC7942_RS07610',
#              'SYNPCC7942_RS07615',
#              'SYNPCC7942_RS07620'})},
#  <Reaction SPODM at 0x2b3f83710>: {frozenset({'SYNPCC7942_RS04145'})},
#  <Reaction TRDRf at 0x2b3f09690>: {frozenset({'SYNPCC7942_RS05790',
#              'SYNPCC7942_RS08825'})},
#  <Reaction AMPTASECG at 0x2b3fbe150>: {frozenset({'SYNPCC7942_RS05815'}),
#   frozenset({'SYNPCC7942_RS06095'})},
#  <Reaction SPRMS at 0x2b3faaad0>: {frozenset({'SYNPCC7942_RS03225'})},
#  <Reaction PGAMT at 0x2b3f44590>: {frozenset({'SYNPCC7942_RS10815'})},
#  <Reaction NNDPR at 0x2b3fc9610>: {frozenset({'SYNPCC7942_RS04890'})},
#  <Reaction ADSK at 0x2b3fcb0d0>: {frozenset({'SYNPCC7942_RS04830'})},
#  <Reaction MECDPS at 0x2b3fd04d0>: {frozenset({'SYNPCC7942_RS06000'})},
#  <Reaction FCLT at 0x2b3fd0d10>: {frozenset({'SYNPCC7942_RS00695'})},
#  <Reaction SHCHCS3 at 0x2b3fd2390>: {frozenset({'SYNPCC7942_RS12830'}),
#   frozenset({'SYNPCC7942_RS04015'})},
#  <Reaction PPA at 0x2b3fd3710>: {frozenset({'SYNPCC7942_RS07080'})},
#  <Reaction ADCYRS at 0x2b3f986d0>: {frozenset({'SYNPCC7942_RS01070'})},
#  <Reaction ATPPRT at 0x2b3fbfe50>: {frozenset({'SYNPCC7942_RS04060',
#              'SYNPCC7942_RS04205'})},
#  <Reaction CUabcpp at 0x2b3f85e90>: {frozenset({'SYNPCC7942_RS11780'}),
#   frozenset({'SYNPCC7942_RS08020'})},
#  <Reaction DHQS at 0x2b3f8ed10>: {frozenset({'SYNPCC7942_RS02670'})},
#  <Reaction GTHRDH_syn at 0x2b3fc8090>: {frozenset({'SYNPCC7942_RS00940'}),
#   frozenset({'SYNPCC7942_RS13430'})},
#  <Reaction ANPRT at 0x2b3fe2150>: {frozenset({'SYNPCC7942_RS10765'})},
#  <Reaction PC6AR_1 at 0x2b3f8efd0>: {frozenset({'SYNPCC7942_RS00110'})},
#  <Reaction ADK1 at 0x2b3fec990>: {frozenset({'SYNPCC7942_RS11240'})},
#  <Reaction PRAIi at 0x2b3fdfdd0>: {frozenset({'SYNPCC7942_RS02080'})},
#  <Reaction TRSARyr at 0x2b3fef210>: {frozenset({'SYNPCC7942_RS09420'})},
#  <Reaction CYNTtabcpp at 0x2b3fefc50>: {frozenset({'SYNPCC7942_RS10670',
#              'SYNPCC7942_RS10675',
#              'Synpcc7942_2107'})},
#  <Reaction RBPCcx at 0x2b3fdd110>: {frozenset({'SYNPCC7942_RS01445',
#              'SYNPCC7942_RS01450',
#              'SYNPCC7942_RS07270',
#              'SYNPCC7942_RS07275',
#              'SYNPCC7942_RS07280',
#              'SYNPCC7942_RS07285',
#              'SYNPCC7942_RS07290',
#              'SYNPCC7942_RS07295',
#              'SYNPCC7942_RS07300'})},
#  <Reaction UPP3S at 0x2b3f23290>: {frozenset({'SYNPCC7942_RS01385'})},
#  <Reaction DHNPA_1 at 0x2b3f45f50>: {frozenset({'SYNPCC7942_RS00200'})},
#  <Reaction MOBDabcpp at 0x2b3ff7bd0>: {frozenset({'SYNPCC7942_RS07820',
#              'SYNPCC7942_RS07825',
#              'SYNPCC7942_RS07830'})},
#  <Reaction NADK at 0x2b3fbe310>: {frozenset({'SYNPCC7942_RS11710'}),
#   frozenset({'SYNPCC7942_RS09465'})},
#  <Reaction NADTRHD at 0x2b3fbe610>: {frozenset({'SYNPCC7942_RS08215',
#              'SYNPCC7942_RS08220',
#              'SYNPCC7942_RS08225'})},
#  <Reaction PGM at 0x2b400de90>: {frozenset({'SYNPCC7942_RS10535'}),
#   frozenset({'SYNPCC7942_RS02390'})},
#  <Reaction FE3abcpp at 0x2b400c850>: {frozenset({'SYNPCC7942_RS07195',
#              'SYNPCC7942_RS07200',
#              'SYNPCC7942_RS11055'}),
#   frozenset({'SYNPCC7942_RS07195',
#              'SYNPCC7942_RS07200',
#              'SYNPCC7942_RS07210'})},
#  <Reaction DHNCOAT at 0x2b401d150>: {frozenset({'SYNPCC7942_RS08875'})},
#  <Reaction NPHBDC at 0x2b401da90>: {frozenset({'SYNPCC7942_RS00685',
#              'SYNPCC7942_RS10425',
#              'SYNPCC7942_RS13180'})},
#  <Reaction HCO3E_1_cx at 0x2b400e250>: {frozenset({'SYNPCC7942_RS07280',
#              'SYNPCC7942_RS07405'})},
#  <Reaction DESAT16a at 0x2b401f910>: {frozenset({'SYNPCC7942_RS13015'})},
#  <Reaction UAGDP at 0x2b3fbfb90>: {frozenset({'SYNPCC7942_RS01465'})},
#  <Reaction PDS1_1 at 0x2b4033c90>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction FRTT at 0x2b4030b50>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction 3OAS180 at 0x2b3f50f10>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR80y at 0x2b4038ad0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction EAR140y at 0x2b403bb50>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction ACGS at 0x2b403b090>: {frozenset({'SYNPCC7942_RS09615'})},
#  <Reaction CYTBD4um at 0x2b4040c10>: {frozenset({'SYNPCC7942_RS08975',
#              'SYNPCC7942_RS08980'})},
#  <Reaction DHPPDA at 0x2b4040c50>: {frozenset({'SYNPCC7942_RS01030'})},
#  <Reaction DHFR at 0x2b4017810>: {frozenset({'SYNPCC7942_RS06075'})},
#  <Reaction BCAROHX at 0x2b404e610>: {frozenset({'SYNPCC7942_RS12395'})},
#  <Reaction MPOMC1_1 at 0x2b405eb10>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction ERTHMMOR at 0x2b405f250>: {frozenset({'SYNPCC7942_RS07690'})},
#  <Reaction AFAT at 0x2b4017750>: {frozenset({'SYNPCC7942_RS02505'})},
#  <Reaction DADK at 0x2b4066fd0>: {frozenset({'SYNPCC7942_RS11240'})},
#  <Reaction G1SAT at 0x2b4067d90>: {frozenset({'SYNPCC7942_RS03310'})},
#  <Reaction UAAGDS at 0x2b403a5d0>: {frozenset({'SYNPCC7942_RS07585'})},
#  <Reaction HEX1 at 0x2b4075d90>: {frozenset({'SYNPCC7942_RS01125'})},
#  <Reaction URIDK2r at 0x2b4075310>: {frozenset({'SYNPCC7942_RS00470'})},
#  <Reaction CHPHYS at 0x2b40773d0>: {frozenset({'SYNPCC7942_RS10565'})},
#  <Reaction PIuabcpp at 0x2b404e810>: {frozenset({'SYNPCC7942_RS12405',
#              'SYNPCC7942_RS12410',
#              'SYNPCC7942_RS12415',
#              'SYNPCC7942_RS12420',
#              'SYNPCC7942_RS12425'})},
#  <Reaction ARGDHpp at 0x2b407a5d0>: {frozenset({'SYNPCC7942_RS04865'})},
#  <Reaction PHETA1 at 0x2b4081390>: {frozenset({'SYNPCC7942_RS05290'})},
#  <Reaction PFK at 0x2b4081210>: {frozenset({'SYNPCC7942_RS03035'})},
#  <Reaction DMPPS_syn at 0x2b40811d0>: {frozenset({'SYNPCC7942_RS00360'})},
#  <Reaction ANS2 at 0x2b40812d0>: {frozenset({'SYNPCC7942_RS02040',
#              'SYNPCC7942_RS05145'})},
#  <Reaction 3OAS160 at 0x2b408c090>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction ACHBSb at 0x2b408f390>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction PC20M at 0x2b408df90>: {frozenset({'SYNPCC7942_RS09400'})},
#  <Reaction ADSS at 0x2b408f310>: {frozenset({'SYNPCC7942_RS12245'})},
#  <Reaction THRPDC at 0x2b4081cd0>: {frozenset({'SYNPCC7942_RS05685'})},
#  <Reaction MPOMOR_1 at 0x2b4098c50>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction IPPMIa at 0x2b409b5d0>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction SPMS at 0x2b40a1290>: {frozenset({'SYNPCC7942_RS03225'})},
#  <Reaction BPNT at 0x2b40a22d0>: {frozenset({'SYNPCC7942_RS04960'}),
#   frozenset({'SYNPCC7942_RS00880'})},
#  <Reaction ICDHyr at 0x2b40a38d0>: {frozenset({'SYNPCC7942_RS08745'})},
#  <Reaction TMDS3 at 0x2b40ae110>: {frozenset({'SYNPCC7942_RS05355'})},
#  <Reaction GLYOX_1 at 0x2b40671d0>: {frozenset({'SYNPCC7942_RS03275'})},
#  <Reaction MTRI at 0x2b40ae090>: {frozenset({'SYNPCC7942_RS10100'})},
#  <Reaction CTPS2 at 0x2b40af7d0>: {frozenset({'SYNPCC7942_RS09920'})},
#  <Reaction GTHS at 0x2b3fdc490>: {frozenset({'SYNPCC7942_RS11815'})},
#  <Reaction AHSERL2_1 at 0x2b4079790>: {frozenset({'SYNPCC7942_RS01885'})},
#  <Reaction PEPC at 0x2b408f8d0>: {frozenset({'SYNPCC7942_RS11450'})},
#  <Reaction CHORM at 0x2b4077510>: {frozenset({'SYNPCC7942_RS09720'})},
#  <Reaction NTRARf2 at 0x2b40c7510>: {frozenset({'SYNPCC7942_RS06330'})},
#  <Reaction G6PDA at 0x2b4077590>: {frozenset({'SYNPCC7942_RS05655'})},
#  <Reaction MPML at 0x2b40d2610>: {frozenset({'SYNPCC7942_RS02965',
#              'SYNPCC7942_RS10840',
#              'SYNPCC7942_RS11555'})},
#  <Reaction Nat_Kpp at 0x2b40d1710>: {frozenset({'SYNPCC7942_RS05545',
#              'SYNPCC7942_RS05550'})},
#  <Reaction PDH at 0x2b40af850>: {frozenset({'SYNPCC7942_RS00725',
#              'SYNPCC7942_RS05480',
#              'SYNPCC7942_RS06135',
#              'SYNPCC7942_RS09865'})},
#  <Reaction TPI at 0x2b40d3ad0>: {frozenset({'SYNPCC7942_RS06460'})},
#  <Reaction E4PD at 0x2b40e14d0>: {frozenset({'SYNPCC7942_RS01250'}),
#   frozenset({'SYNPCC7942_RS09840'})},
#  <Reaction GAPD at 0x2b40e2310>: {frozenset({'SYNPCC7942_RS01250'}),
#   frozenset({'SYNPCC7942_RS09840'})},
#  <Reaction CPPPGO at 0x2b40b8850>: {frozenset({'SYNPCC7942_RS03450'})},
#  <Reaction PRMICI at 0x2b40ddcd0>: {frozenset({'SYNPCC7942_RS09280'})},
#  <Reaction CAT at 0x2b40deed0>: {frozenset({'SYNPCC7942_RS08445'})},
#  <Reaction GLUR at 0x2b4060e90>: {frozenset({'SYNPCC7942_RS11995'})},
#  <Reaction OCBT at 0x2b40ee550>: {frozenset({'SYNPCC7942_RS12760'})},
#  <Reaction GLGC at 0x2b40ae710>: {frozenset({'SYNPCC7942_RS03095'})},
#  <Reaction PYK at 0x2b40bad10>: {frozenset({'SYNPCC7942_RS00500'})},
#  <Reaction CA2t2pp at 0x2b40fcd90>: {frozenset({'SYNPCC7942_RS00120'})},
#  <Reaction ALAR at 0x2b40ffd50>: {frozenset({'SYNPCC7942_RS11185'})},
#  <Reaction SULR_2 at 0x2b40eed50>: {frozenset({'SYNPCC7942_RS00100'})},
#  <Reaction ADCS at 0x2b40fff50>: {frozenset({'SYNPCC7942_RS06820'})},
#  <Reaction UGMDDS at 0x2b4101b90>: {frozenset({'SYNPCC7942_RS09340'})},
#  <Reaction GLCDBRAN3 at 0x2b4102710>: {frozenset({'SYNPCC7942_RS00425',
#              'SYNPCC7942_RS05240'})},
#  <Reaction IG3PS at 0x2b4103690>: {frozenset({'SYNPCC7942_RS07570',
#              'SYNPCC7942_RS10580'})},
#  <Reaction RPI at 0x2b40dc110>: {frozenset({'SYNPCC7942_RS02970'})},
#  <Reaction NAt3pp at 0x2b410f850>: {frozenset({'SYNPCC7942_RS04195'}),
#   frozenset({'SYNPCC7942_RS12165'}),
#   frozenset({'SYNPCC7942_RS01565'}),
#   frozenset({'SYNPCC7942_RS11110'}),
#   frozenset({'SYNPCC7942_RS06475'}),
#   frozenset({'SYNPCC7942_RS11985'}),
#   frozenset({'SYNPCC7942_RS02780'})},
#  <Reaction GLYCLTDx at 0x2b40d01d0>: {frozenset({'SYNPCC7942_RS01405',
#              'SYNPCC7942_RS08735',
#              'SYNPCC7942_RS08740'}),
#   frozenset({'SYNPCC7942_RS02885'})},
#  <Reaction FMNRy_1 at 0x2b40ae610>: {frozenset({'SYNPCC7942_RS02765'})},
#  <Reaction GHMT2r at 0x2b4120690>: {frozenset({'SYNPCC7942_RS01435'})},
#  <Reaction OPMEACPD at 0x2b41323d0>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction OPMEACPR at 0x2b4133350>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction SPP at 0x2b413c890>: {frozenset({'SYNPCC7942_RS04180'})},
#  <Reaction AGPAT160 at 0x2b4133bd0>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_HDE_PALM at 0x2b413fa10>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction BTS6 at 0x2b413f2d0>: {frozenset({'SYNPCC7942_RS02140',
#              'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS08825',
#              'SYNPCC7942_RS08830',
#              'SYNPCC7942_RS08835',
#              'SYNPCC7942_RS08840',
#              'SYNPCC7942_RS08845'})},
#  <Reaction QUERT at 0x2b4148490>: {frozenset({'SYNPCC7942_RS02325'})},
#  <Reaction PMEACPE at 0x2b414be10>: {frozenset({'SYNPCC7942_RS00145'})},
#  <Reaction G3PAT160 at 0x2b41541d0>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction GLUDGE_HDE_HDE at 0x2b4155b10>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction G3PAT161 at 0x2b40df350>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction G3PAT1819Z_1 at 0x2b40e23d0>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction EPMEACPR at 0x2b4156950>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction GLUDGE_OLE_HDE at 0x2b41591d0>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction GLUDGE_OLE_PALM at 0x2b41596d0>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction GLUDGE_HDE_PALM at 0x2b4159d90>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction AGPAT161 at 0x2b41594d0>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_OLE_HDE at 0x2b4155810>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_OLE_PALM at 0x2b4148590>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction GLUDGS_OLE_HDE at 0x2b4168450>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_OLE_PALM at 0x2b41692d0>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_HDE_PALM at 0x2b4169d10>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_HDE_HDE at 0x2b416b250>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction TYRTRS at 0x2b416a690>: {frozenset({'SYNPCC7942_RS13060'})},
#  <Reaction DAGK160 at 0x2b4169c10>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK_HDE_PALM at 0x2b416bb90>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK161 at 0x2b4179a50>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction SQDGS_PALM_PALM at 0x2b411e990>: {frozenset({'SYNPCC7942_RS02945'})},
#  <Reaction SQDGS_HDE_PALM at 0x2b4181f90>: {frozenset({'SYNPCC7942_RS02945'})},
#  <Reaction PGPS_OLE_PALM at 0x2b41810d0>: {frozenset({'SYNPCC7942_RS09260'})},
#  <Reaction DGDGS_HDE_PALM at 0x2b4183490>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_HDE_HDE at 0x2b4182850>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_OLE_HDE at 0x2b4183310>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_OLE_PALM at 0x2b41926d0>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction CDPDAGS_OLE_PALM at 0x2b4017010>: {frozenset({'SYNPCC7942_RS02010'})},
#  <Reaction GLNTRS at 0x2b4120d90>: {frozenset({'SYNPCC7942_RS00590',
#              'SYNPCC7942_RS10735',
#              'SYNPCC7942_RS11805',
#              'SYNPCC7942_RS12160'})},
#  <Reaction METTRS at 0x2b4192450>: {frozenset({'SYNPCC7942_RS05845'})},
#  <Reaction SERTRS at 0x2b4198d10>: {frozenset({'SYNPCC7942_RS02295'})},
#  <Reaction PROTRS at 0x2b4191150>: {frozenset({'SYNPCC7942_RS09940'})},
#  <Reaction GLYTRS at 0x2b419b450>: {frozenset({'SYNPCC7942_RS00095',
#              'SYNPCC7942_RS12485'})},
#  <Reaction CYSTRS at 0x2b4198fd0>: {frozenset({'SYNPCC7942_RS08475'})},
#  <Reaction ARGTRS at 0x2b41a9a10>: {frozenset({'SYNPCC7942_RS08055'})},
#  <Reaction TRPTRS at 0x2b415b450>: {frozenset({'SYNPCC7942_RS06690'})},
#  <Reaction HISTRS at 0x2b419b4d0>: {frozenset({'SYNPCC7942_RS11500'})},
#  <Reaction PHETRS at 0x2b41b9b50>: {frozenset({'SYNPCC7942_RS06615',
#              'SYNPCC7942_RS10470'})},
#  <Reaction ASNTRS at 0x2b4155c10>: {frozenset({'SYNPCC7942_RS04290'})},
#  <Reaction ASPTRS at 0x2b41bd610>: {frozenset({'SYNPCC7942_RS06715'})},
#  <Reaction UDPGLDC at 0x2b41bd650>: {frozenset({'SYNPCC7942_RS05885'})},
#  <Reaction AGTi at 0x2b41bf510>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction DBTS at 0x2b41d1650>: {frozenset({'SYNPCC7942_RS00155'})},
#  <Reaction THRTRS at 0x2b41d09d0>: {frozenset({'SYNPCC7942_RS13275'})},
#  <Reaction LEUTRS at 0x2b41d3bd0>: {frozenset({'SYNPCC7942_RS09745'})},
#  <Reaction ILETRS at 0x2b41d3b90>: {frozenset({'SYNPCC7942_RS12380'})},
#  <Reaction LYSTRS at 0x2b41da310>: {frozenset({'SYNPCC7942_RS12270'})},
#  <Reaction AOXSr2 at 0x2b41e8790>: {frozenset({'SYNPCC7942_RS00140'})},
#  <Reaction AMAOTr at 0x2b4198e10>: {frozenset({'SYNPCC7942_RS00160'})},
#  <Reaction LIPOS2 at 0x2b41ea1d0>: {frozenset({'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS09790',
#              'SYNPCC7942_RS11955'})},
#  <Reaction ALATRS at 0x2b41ea190>: {frozenset({'SYNPCC7942_RS04515'})},
#  <Reaction VALTRS at 0x2b41aaed0>: {frozenset({'SYNPCC7942_RS03010'})},
#  <Reaction FMETTRS at 0x2b41ebe50>: {frozenset({'SYNPCC7942_RS10695'})},
#  <Reaction BACCL at 0x2b41ed2d0>: {frozenset({'SYNPCC7942_RS01760'})},
#  <Reaction BTNPL2 at 0x2b41ebd50>: {frozenset({'SYNPCC7942_RS01760'})},
#  <Reaction LIPAMPL_1 at 0x2b41fc4d0>: {frozenset({'SYNPCC7942_RS07220'})},
#  <Reaction LIPOCT at 0x2b41fd190>: {frozenset({'SYNPCC7942_RS07705'}),
#   frozenset({'SYNPCC7942_RS02760'})},
#  <Reaction LIPATPT_1 at 0x2b41fdf90>: {frozenset({'SYNPCC7942_RS07220'})},
#  <Reaction ZXANHX at 0x2b414af90>: {frozenset({'SYNPCC7942_RS03485'})},
#  <Reaction CPH4S at 0x2b4201990>: {frozenset({'SYNPCC7942_RS09915'})},
#  <Reaction OGMEACPR at 0x2b4202f90>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction CDGS at 0x2b41585d0>: {frozenset({'SYNPCC7942_RS06810'})},
#  <Reaction CCGS at 0x2b420edd0>: {frozenset({'SYNPCC7942_RS06815'})},
#  <Reaction CDGR at 0x2b420f5d0>: {frozenset({'SYNPCC7942_RS09355'})},
#  <Reaction PLYCOI at 0x2b4219c50>: {frozenset({'SYNPCC7942_RS08770'}),
#   frozenset({'SYNPCC7942_RS04985'}),
#   frozenset({'SYNPCC7942_RS06385'})},
#  <Reaction SAMTRI at 0x2b421af50>: {frozenset({'SYNPCC7942_RS11930'})},
#  <Reaction EPXQR at 0x2b421aed0>: {frozenset({'SYNPCC7942_RS02695'})},
#  <Reaction UPPRT at 0x2b421af10>: {frozenset({'SYNPCC7942_RS08725'})},
#  <Reaction ZCARDS at 0x2b422b110>: {frozenset({'SYNPCC7942_RS07730'})},
#  <Reaction UDPGD at 0x2b42309d0>: {frozenset({'SYNPCC7942_RS05000'})},
#  <Reaction GMAND at 0x2b4230ed0>: {frozenset({'SYNPCC7942_RS06860'})},
#  <Reaction GFUCS at 0x2b41aafd0>: {frozenset({'SYNPCC7942_RS08655'})},
#  <Reaction NADDP at 0x2b422bf10>: {frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction CDPGLC46DH at 0x2b424c2d0>: {frozenset({'SYNPCC7942_RS00305'})},
#  <Reaction AACPS6 at 0x2b41b4350>: {frozenset({'SYNPCC7942_RS04725'})},
#  <Reaction ALDR18 at 0x2b421b190>: {frozenset({'SYNPCC7942_RS08140'})},
#  <Reaction ALDDC17 at 0x2b424d590>: {frozenset({'SYNPCC7942_RS08135'})},
#  <Reaction ALCD19 at 0x2b424d550>: {frozenset({'SYNPCC7942_RS11615'}),
#   frozenset({'SYNPCC7942_RS08430'})},
#  <Reaction THZT at 0x2b421b250>: {frozenset({'SYNPCC7942_RS05420'})},
#  <Reaction PHYPQOX at 0x2b42502d0>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction LALGP at 0x2b4252bd0>: {frozenset({'Synpcc7942_1971'})},
#  <Reaction CXANHX at 0x2b425d050>: {frozenset({'SYNPCC7942_RS03485'})},
#  <Reaction OGMEACPS at 0x2b425e1d0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction A5PISO at 0x2b424f190>: {frozenset({'SYNPCC7942_RS11645'})},
#  <Reaction KDOPS at 0x2b41ed990>: {frozenset({'SYNPCC7942_RS11635'})},
#  <Reaction KDOPP at 0x2b425f010>: {frozenset({'SYNPCC7942_RS11630'})},
#  <Reaction KDOCT2 at 0x2b41ed910>: {frozenset({'SYNPCC7942_RS11640'})},
#  <Reaction EGMEACPR at 0x2b411eb50>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DXYTST at 0x2b4265ad0>: {frozenset({'SYNPCC7942_RS02935'})},
#  <Reaction UAG2E at 0x2b4274690>: {frozenset({'SYNPCC7942_RS02810'})},
#  <Reaction OANTS at 0x2b4274650>: {frozenset({'SYNPCC7942_RS01430',
#              'SYNPCC7942_RS09570',
#              'SYNPCC7942_RS09640',
#              'SYNPCC7942_RS09645',
#              'SYNPCC7942_RS09650'})},
#  <Reaction ACGAMT at 0x2b4275310>: {frozenset({'SYNPCC7942_RS01430'})},
#  <Reaction PFOR at 0x2b4282e10>: {frozenset({'SYNPCC7942_RS12115'})},
#  <Reaction ACMAMT at 0x2b4283250>: {frozenset({'SYNPCC7942_RS08420'})},
#  <Reaction ICLIPAabcpp at 0x2b4277cd0>: {frozenset({'SYNPCC7942_RS00405'})},
#  <Reaction ICLIPAS at 0x2b4288490>: {frozenset({'SYNPCC7942_RS09555',
#              'SYNPCC7942_RS10275',
#              'SYNPCC7942_RS10280',
#              'SYNPCC7942_RS10285',
#              'SYNPCC7942_RS10290',
#              'SYNPCC7942_RS11885'})},
#  <Reaction MOAT_1 at 0x2b4288450>: {frozenset({'SYNPCC7942_RS11620',
#              'SYNPCC7942_RS11625'})},
#  <Reaction MPTG at 0x2b421b510>: {frozenset({'SYNPCC7942_RS10140',
#              'SYNPCC7942_RS10355'})},
#  <Reaction MPTG2 at 0x2b425d250>: {frozenset({'SYNPCC7942_RS10140',
#              'SYNPCC7942_RS10355'})},
#  <Reaction UAGPT3 at 0x2b428ae10>: {frozenset({'SYNPCC7942_RS11755'})},
#  <Reaction GLYCOX1 at 0x2b4233290>: {frozenset({'SYNPCC7942_RS12230'})},
#  <Reaction UM4PL at 0x2b4290a90>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction UM3PL at 0x2b42917d0>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction PAPPT3 at 0x2b4292b10>: {frozenset({'SYNPCC7942_RS00770'})},
#  <Reaction OANTIabcpp at 0x2b4293350>: {frozenset({'SYNPCC7942_RS05765',
#              'SYNPCC7942_RS06375'})},
#  <Reaction OANTILpp at 0x2b42a4390>: {frozenset({'SYNPCC7942_RS05765',
#              'SYNPCC7942_RS06375'})},
#  <Reaction MDDCP1pp at 0x2b42a4450>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP2pp at 0x2b424d790>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction STACPSI at 0x2b42a6fd0>: {frozenset({'SYNPCC7942_RS01220'})},
#  <Reaction UDCPDP at 0x2b424e650>: {frozenset({'SYNPCC7942_RS09980'})},
#  <Reaction MLTGY1pp at 0x2b428b550>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction ETCPC at 0x2b420db10>: {frozenset({'SYNPCC7942_RS01655',
#              'SYNPCC7942_RS01660',
#              'SYNPCC7942_RS01665',
#              'SYNPCC7942_RS01670',
#              'SYNPCC7942_RS05370',
#              'SYNPCC7942_RS05375',
#              'SYNPCC7942_RS05380',
#              'SYNPCC7942_RS05385',
#              'SYNPCC7942_RS05390',
#              'SYNPCC7942_RS05395',
#              'SYNPCC7942_RS05400',
#              'SYNPCC7942_RS05410',
#              'SYNPCC7942_RS10300'})},
#  <Reaction GLYCOX2 at 0x2b42ae290>: {frozenset({'SYNPCC7942_RS12230'})},
#  <Reaction NO2tabcpp at 0x2b42ace50>: {frozenset({'SYNPCC7942_RS10670',
#              'SYNPCC7942_RS10675',
#              'Synpcc7942_2107'})},
#  <Reaction MLTGY2pp at 0x2b42af7d0>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction MLTGY3pp at 0x2b42a44d0>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction MLTGY4pp at 0x2b42a7b90>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction AGM4PA at 0x2b41eda90>: {frozenset({'SYNPCC7942_RS11990'})},
#  <Reaction AM3PA at 0x2b42cc690>: {frozenset({'SYNPCC7942_RS11990'})},
#  <Reaction AM4PA at 0x2b42ceb50>: {frozenset({'SYNPCC7942_RS11990'})},
# ...
#  <Reaction PAPA160 at 0x2b432f850>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PHEOASE at 0x2a62155d0>: {frozenset({'SYNPCC7942_RS12855'})},
#  <Reaction PAPA_HDE_PALM at 0x2a68351d0>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PAPA161 at 0x2a6857f10>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PAPA_OLE_HDE at 0x2b42fc250>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction ACGK at 0x2b42890d0>: {frozenset({'SYNPCC7942_RS07645'})},
#  <Reaction MCTP2App at 0x2b42b6d90>: {frozenset({'SYNPCC7942_RS02950'}),
#   frozenset({'SYNPCC7942_RS02455'})},
#  <Reaction MCTP1App at 0x2b433a950>: {frozenset({'SYNPCC7942_RS02950'}),
#   frozenset({'SYNPCC7942_RS02455'})},
#  <Reaction MCTP1Bpp at 0x2b42a5ed0>: {frozenset({'SYNPCC7942_RS02950'}),
#   frozenset({'SYNPCC7942_RS02455'})},
#  <Reaction LEUabcpp at 0x2b432e450>: {frozenset({'SYNPCC7942_RS04215',
#              'SYNPCC7942_RS09440',
#              'SYNPCC7942_RS09600',
#              'SYNPCC7942_RS09605',
#              'SYNPCC7942_RS11065'})},
#  <Reaction ACLSa at 0x2b432e5d0>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction SULabcpp at 0x2b4274750>: {frozenset({'SYNPCC7942_RS08585',
#              'SYNPCC7942_RS08590',
#              'SYNPCC7942_RS08595',
#              'SYNPCC7942_RS08600'}),
#   frozenset({'SYNPCC7942_RS08560',
#              'SYNPCC7942_RS08565',
#              'SYNPCC7942_RS08570',
#              'SYNPCC7942_RS08765'})},
#  <Reaction PAPA_OLE_PALM at 0x2b42e6910>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction TYRTA at 0x2b433b510>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction ACLSb at 0x2b432e590>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction PHEOX_1 at 0x2b435a510>: {frozenset({'SYNPCC7942_RS11000'})},
#  <Reaction OPMEACPS at 0x2b4328ad0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR100y at 0x2b4200bd0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction EHGLAT at 0x2b4361f10>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction KAS15 at 0x2b42e6850>: {frozenset({'SYNPCC7942_RS07445'})},
#  <Reaction FALDH2 at 0x2b4363710>: {frozenset({'SYNPCC7942_RS02340'})},
#  <Reaction PHYTK at 0x2b42dfbd0>: {frozenset({'SYNPCC7942_RS05350'})},
#  <Reaction NDH_1_4_um_copy2 at 0x2b4370d90>: {frozenset({'SYNPCC7942_RS01570',
#              'SYNPCC7942_RS01575',
#              'SYNPCC7942_RS03125',
#              'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413'})},
#  <Reaction KARI_1 at 0x2b4371ed0>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction 3HAD120 at 0x2b4379a10>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction OGMEACPD at 0x2b42fdc50>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ACCOAC at 0x2b43796d0>: {frozenset({'SYNPCC7942_RS07060',
#              'SYNPCC7942_RS08145',
#              'SYNPCC7942_RS09925',
#              'SYNPCC7942_RS13030'})},
#  <Reaction ASPO5 at 0x2b4308c50>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction PTHPS at 0x2b4382b90>: {frozenset({'SYNPCC7942_RS06065'})},
#  <Reaction CITCIa at 0x2b4380710>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction DAGK_OLE_HDE at 0x2b4382b10>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK_OLE_PALM at 0x2b432e290>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction 3HAD100 at 0x2b432e3d0>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction PNTK at 0x2b438d490>: {frozenset({'SYNPCC7942_RS09185'})},
#  <Reaction 3OAR120 at 0x2b42e5390>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR60 at 0x2b4250410>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR100 at 0x2b438f850>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR80 at 0x2b4394f50>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction ALCD1 at 0x2b4395a50>: {frozenset({'SYNPCC7942_RS11615'}),
#   frozenset({'SYNPCC7942_RS08430'})},
#  <Reaction NDH_1_1_um_copy1 at 0x2b4396750>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS07360',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10025',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413',
#              'Synpcc7942_0491',
#              'Synpcc7942_0668'})},
#  <Reaction NDH_1_4_um_copy1 at 0x2b42e5450>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS10600',
#              'SYNPCC7942_RS10605',
#              'SYNPCC7942_RS10610',
#              'SYNPCC7942_RS10615',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413'})},
#  <Reaction PCHLDA430 at 0x2b4397590>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction SFGTHi at 0x2b4378490>: {frozenset({'SYNPCC7942_RS02335'})},
#  <Reaction PCHLDA650 at 0x2b439de50>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction GGCLUT2 at 0x2b430bed0>: {frozenset({'SYNPCC7942_RS05810'})},
#  <Reaction SPR at 0x2b43aac50>: {frozenset({'SYNPCC7942_RS09235'})},
#  <Reaction OPAH at 0x2b435a890>: {frozenset({'SYNPCC7942_RS12145'})},
#  <Reaction ACGAMK at 0x2b4395a90>: {frozenset({'SYNPCC7942_RS10700'})},
#  <Reaction AMANAPEr at 0x2b4382c10>: {frozenset({'SYNPCC7942_RS12525'})},
#  <Reaction AGDC at 0x2b43ba090>: {frozenset({'SYNPCC7942_RS02250'})},
#  <Reaction ANHMK at 0x2b43bbb10>: {frozenset({'SYNPCC7942_RS05610'})},
#  <Reaction RNDR4 at 0x2b43aad50>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction TRPS2 at 0x2b438f950>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction PSICSum at 0x2b4309e50>: {frozenset({'SYNPCC7942_RS02075',
#              'SYNPCC7942_RS02720',
#              'SYNPCC7942_RS03350',
#              'SYNPCC7942_RS04735',
#              'SYNPCC7942_RS05140',
#              'SYNPCC7942_RS06400',
#              'SYNPCC7942_RS06405',
#              'SYNPCC7942_RS06760',
#              'SYNPCC7942_RS09705',
#              'SYNPCC7942_RS10390',
#              'SYNPCC7942_RS10395',
#              'SYNPCC7942_RS11800',
#              'SYNPCC7942_RS11900',
#              'SYNPCC7942_RS11905',
#              'SYNPCC7942_RS12755'})},
#  <Reaction NAD_H2 at 0x2b43a9090>: {frozenset({'SYNPCC7942_RS01415',
#              'SYNPCC7942_RS01420',
#              'SYNPCC7942_RS07025',
#              'SYNPCC7942_RS12970',
#              'SYNPCC7942_RS12975',
#              'SYNPCC7942_RS12980',
#              'SYNPCC7942_RS12985',
#              'SYNPCC7942_RS12990',
#              'SYNPCC7942_RS12995'})},
#  <Reaction PPND at 0x2b43d2050>: {frozenset({'SYNPCC7942_RS03380'})},
#  <Reaction CBFCum at 0x2b43a9c50>: {frozenset({'SYNPCC7942_RS00575',
#              'SYNPCC7942_RS01640',
#              'SYNPCC7942_RS01645',
#              'SYNPCC7942_RS02420',
#              'SYNPCC7942_RS02595',
#              'SYNPCC7942_RS06310',
#              'SYNPCC7942_RS06315',
#              'SYNPCC7942_RS07560',
#              'SYNPCC7942_RS11850',
#              'SYNPCC7942_RS11855',
#              'SYNPCC7942_RS12325',
#              'Synpcc7942_1478'})},
#  <Reaction ACM6PH at 0x2b43a9010>: {frozenset({'SYNPCC7942_RS13120'})},
#  <Reaction SUCR at 0x2b435b250>: {frozenset({'SYNPCC7942_RS02025'})},
#  <Reaction CLt3_1pp at 0x2b4362050>: {frozenset({'SYNPCC7942_RS06440',
#              'SYNPCC7942_RS08050',
#              'SYNPCC7942_RS08110'})},
#  <Reaction Ktu at 0x2b43ba0d0>: {frozenset({'SYNPCC7942_RS06320'})},
#  <Reaction THBTGT at 0x2b42ff2d0>: {frozenset({'SYNPCC7942_RS09735'})},
#  <Reaction FDH6 at 0x2b43dd250>: {frozenset({'SYNPCC7942_RS12130'})},
#  <Reaction PCXHtpp at 0x2b439f4d0>: {frozenset({'SYNPCC7942_RS05090'})},
#  <Reaction THISAT at 0x2b43d2290>: {frozenset({'SYNPCC7942_RS00800',
#              'SYNPCC7942_RS05425'})},
#  <Reaction PSIIum at 0x2b430a310>: {frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS07110',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'}),
#   frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS04600',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'})},
#  <Reaction ATPSum at 0x2b43a9150>: {frozenset({'SYNPCC7942_RS01680',
#              'SYNPCC7942_RS01685',
#              'SYNPCC7942_RS01690',
#              'SYNPCC7942_RS01695',
#              'SYNPCC7942_RS01700',
#              'SYNPCC7942_RS01705',
#              'SYNPCC7942_RS01710',
#              'SYNPCC7942_RS01715',
#              'SYNPCC7942_RS11770',
#              'SYNPCC7942_RS11775'})},
#  <Reaction CYSDES at 0x2b43ead50>: {frozenset({'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS09790'})},
#  <Reaction NO3abcpp at 0x2b4397490>: {frozenset({'SYNPCC7942_RS06335',
#              'SYNPCC7942_RS06340',
#              'SYNPCC7942_RS06345',
#              'SYNPCC7942_RS06350'})},
#  <Reaction GLNabcpp at 0x2b43d1550>: {frozenset({'SYNPCC7942_RS01255',
#              'SYNPCC7942_RS01260',
#              'SYNPCC7942_RS01265',
#              'SYNPCC7942_RS01270'})},
#  <Reaction GLNS at 0x2b4363850>: {frozenset({'SYNPCC7942_RS11670'}),
#   frozenset({'SYNPCC7942_RS10955'}),
#   frozenset({'SYNPCC7942_RS00860'})},
#  <Reaction MDDEP1pp at 0x2b43b8c10>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction THII at 0x2b43bbb90>: {frozenset({'SYNPCC7942_RS00800',
#              'SYNPCC7942_RS05425'})},
#  <Reaction SHS1 at 0x2b43f54d0>: {frozenset({'SYNPCC7942_RS13295',
#              'SYNPCC7942_RS13300'})},
#  <Reaction PSIICSum at 0x2b43bbc10>: {frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS07110',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'}),
#   frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS04600',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'})},
#  <Reaction NDH_1_1_um_copy2 at 0x2b4406910>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10020',
#              'SYNPCC7942_RS10025',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413',
#              'Synpcc7942_0491',
#              'Synpcc7942_0668'})},
#  <Reaction ASNS1 at 0x2b43f7450>: {frozenset({'SYNPCC7942_RS00590',
#              'SYNPCC7942_RS06715',
#              'SYNPCC7942_RS10735',
#              'SYNPCC7942_RS11805'})},
#  <Reaction MDDCP3pp at 0x2b440f6d0>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP4pp at 0x2b43eb190>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP5pp at 0x2b43e9110>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDEP2pp at 0x2b442b090>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MDDEP3pp at 0x2b441cd50>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MDDEP4pp at 0x2b4428390>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MNHNAtpp at 0x2b43eb390>: {frozenset({'SYNPCC7942_RS07510',
#              'SYNPCC7942_RS07515',
#              'SYNPCC7942_RS07520',
#              'SYNPCC7942_RS07525',
#              'SYNPCC7942_RS07530',
#              'SYNPCC7942_RS07535',
#              'SYNPCC7942_RS13760'})},
#  <Reaction SUCRt2 at 0x2b44327d0>: {frozenset({'ATCC_700927'})}}

# %%
# Check which genes (listed in observed transcriptomics data) are missing from the cobra model
# list_of_gprs_in_model = [str(syn_model.reactions.get_by_id(r.id).gpr).split(" and ") for r in syn_model.reactions]
list_of_gprs_in_model = [g.id for g in syn_model.genes]

genes_not_in_model = [g for g in transcriptomics_df.index if g not in list_of_gprs_in_model]
genes_not_in_data = [g for g in list_of_gprs_in_model if g not in transcriptomics_df.index]
genes_in_model_and_data = [g for g in list_of_gprs_in_model if g in transcriptomics_df.index]


print('# of genes in model:', len(list_of_gprs_in_model))
print('# of genes in data:', len(transcriptomics_df.index))
print('# of genes_not_in_model:', len(genes_not_in_model))
print('# of genes_not_in_data:', len(genes_not_in_data))
print('# of genes_in_model_and_data:', len(genes_in_model_and_data))

print('# of reactions in model:', len([r.id for r in syn_model.reactions]))

genes_not_in_data
# Out:
# # of genes in model: 786
# # of genes in data: 2761
# # of genes_not_in_model: 1986
# # of genes_not_in_data: 11
# # of genes_in_model_and_data: 775
# # of reactions in model: 851
# ['Synpcc7942_2454',
#  'Synpcc7942_0034',
#  'Synpcc7942_0413',
#  'Synpcc7942_1971',
#  'Synpcc7942_2107',
#  'Synpcc7942_2010',
#  'SYNPCC7942_RS05000',
#  'Synpcc7942_1478',
#  'Synpcc7942_0491',
#  'Synpcc7942_0668',
#  'ATCC_700927']

# %%
# Code shared by Jeremy in Teams chat...
from cobra import Reaction, Gene

def gene_expression_to_enzyme_activity(gpr: dict[Reaction, list[list[Gene]]], expression: dict[Gene, float]):
    """Map gene expression to enzyme activity
    inputs:
        gpr: dictionary of reactions (keys) to list of list of genes (values) for the correpsonding gene reaction rule
        expression: dictionary of gene names (keys) to values from [likely] observed transcriptomics data
    outputs:
        enzyme_activity: dictionary of reactions (keys) to corresponding isozyme activity from observed data (value)
    """
    
    enzyme_activity = {}
    for rxn in syn_model.reactions:
      enzyme_activity[rxn] = 0.0

      if rxn in gpr: # temporary fix: ensure rxn has a gene_reaction_rule defined

        for isozyme in gpr[rxn]:
          isozyme_activity = np.inf
          for gene in isozyme:

            if gene in expression: # temporary fix: ensure gene is included in observed data

              # Old code
              # isozyme_activity = np.min([enzyme_activity, expression[gene]])
              # enzyme_activity[rxn] += isozyme_activity

              # Correction to old code
              isozyme_activity = np.min([isozyme_activity, expression[gene]])
          enzyme_activity[rxn] += isozyme_activity
    return enzyme_activity

# %%
# Create dict of genes and corresponding float values using trancsciptomics data
this_strain = ref_rep # use reference strain

expression_dict = {g: transcriptomics_df.loc[g][this_strain] for g in transcriptomics_df.index}
expr_dict_keys = [kz for kz in expression_dict.keys()]
{k: expression_dict[k] for k in expr_dict_keys[0:5]}
# Out:
# {'SYNPCC7942_RS00005': 13967,
#  'SYNPCC7942_RS00010': 7546,
#  'SYNPCC7942_RS00015': 21306,
#  'SYNPCC7942_RS00020': 34175,
#  'SYNPCC7942_RS00025': 6284}

# %%
# Run the gene expression to enzyme activity converter
enzymze_activity_dict = gene_expression_to_enzyme_activity(gpr_dict, expression_dict)
enzymze_activity_dict
# Out:
# {<Reaction EX_gln__L_e at 0x2b3b98410>: 0.0,
#  <Reaction EX_hco3_e at 0x2b3b983d0>: 0.0,
#  <Reaction EX_mn2_e at 0x2b3b98ed0>: 0.0,
#  <Reaction EX_arg__L_e at 0x2b3b99810>: 0.0,
#  <Reaction ADPT at 0x2b3b99f90>: inf,
#  <Reaction O2tcx at 0x2b3b9a750>: 0.0,
#  <Reaction AOXPBDC at 0x2b3b9b9d0>: 0.0,
#  <Reaction DNTPPA at 0x2b3b9b910>: 0.0,
#  <Reaction CBMD at 0x2b3ba0890>: 0.0,
#  <Reaction BIOMASS_PIGMENTS at 0x2b3ba1590>: 0.0,
#  <Reaction H2Otu_syn at 0x2b3ba23d0>: 0.0,
#  <Reaction DTMPK at 0x2b3ba3390>: 1758.0,
#  <Reaction BIOMASS__1 at 0x2b3ba5a10>: 0.0,
#  <Reaction ORNTA at 0x2b3b9b950>: inf,
#  <Reaction ATPM at 0x2b3ba6950>: 0.0,
#  <Reaction ACOATA at 0x2b3badd10>: 4716.0,
#  <Reaction 5DOAN at 0x2b3badcd0>: 0.0,
#  <Reaction 3HAD160 at 0x2b3ba6a50>: 1476.0,
#  <Reaction RNDR3 at 0x2b3bb9190>: 17817.0,
#  <Reaction Htex at 0x2b3b9ba90>: 0.0,
#  <Reaction G5SD at 0x2b3ba56d0>: 20047.0,
#  <Reaction HISTDa at 0x2b3bbbdd0>: 24686.0,
#  <Reaction TRPS3 at 0x2b3bc6590>: 3584.0,
#  <Reaction DMBZIDS2 at 0x2b3bb9290>: 10167.0,
#  <Reaction HSTPT at 0x2b3bc6550>: 14256.0,
#  <Reaction ZCAROTDH2 at 0x2b3bc7710>: 7304.0,
#  <Reaction ORNDC at 0x2b3bbbe50>: 2042.0,
#  <Reaction GND at 0x2b3bcde90>: 43195.0,
#  <Reaction CMPA_1 at 0x2b3bcf190>: 1312.0,
#  <Reaction U23GAAT2 at 0x2b3bd8350>: 5728.0,
#  <Reaction HOXGfx at 0x2b3bd9cd0>: 46482.0,
#  <Reaction PGK at 0x2b3bdb350>: 12568.0,
#  <Reaction IMPD at 0x2b3be8610>: 46846.0,
#  <Reaction LPOR at 0x2b3be8fd0>: 10733.0,
#  <Reaction CHRPL at 0x2b3be92d0>: 4852.0,
#  <Reaction GCALDDy at 0x2b3bebd10>: 11507.0,
#  <Reaction MSBENZMT at 0x2b3bf1690>: 2438.0,
#  <Reaction DESAT18a at 0x2b3bd8550>: 43013.0,
#  <Reaction FUM at 0x2b3bf2f10>: 3913.0,
#  <Reaction PHYFXOR at 0x2b3be8650>: 5413.0,
#  <Reaction TMPPP_1 at 0x2b3bc6710>: 14474.0,
#  <Reaction VPAMTr at 0x2b3bf5c50>: 12729.0,
#  <Reaction RNDR1 at 0x2b3bf7410>: 17817.0,
#  <Reaction TALA at 0x2b3bf7e90>: 97158.0,
#  <Reaction GLYCL at 0x2b3c08cd0>: 1859.0,
#  <Reaction ACONT at 0x2b3c09dd0>: 43013.0,
#  <Reaction NDPK7 at 0x2b3bd8950>: 15072.0,
#  <Reaction GTPCI at 0x2b3c0bb90>: 13002.0,
#  <Reaction AIRC2 at 0x2b3c0d310>: 1900.0,
#  <Reaction IGPS at 0x2b3c0e390>: 7475.0,
#  <Reaction MTAP at 0x2b3c0f190>: 2444.0,
#  <Reaction HEMEAS_1 at 0x2b3c14b50>: 1660.0,
#  <Reaction DHORD3um at 0x2b3c16090>: 2810.0,
#  <Reaction MTHFC at 0x2b3c17210>: 6340.0,
#  <Reaction HBZNPT at 0x2b3c08d90>: 7222.0,
#  <Reaction GCATENEC at 0x2b3c0d990>: 4539.0,
#  <Reaction COCHL_1 at 0x2b3c2a5d0>: 5482.0,
#  <Reaction HSDy at 0x2b3c2b990>: 10988.0,
#  <Reaction TRPS1 at 0x2b3c36390>: 3584.0,
#  <Reaction HISTDb at 0x2b3be9010>: 24686.0,
#  <Reaction UPPDC1 at 0x2b3c36310>: 10566.0,
#  <Reaction GARFT at 0x2b3bf7f50>: 1662.0,
#  <Reaction H4THDPR at 0x2b3c3c9d0>: 3787.0,
#  <Reaction UDPG4E at 0x2b3c3dad0>: 1248.0,
#  <Reaction GLCS3 at 0x2b3c3ec90>: 7288.0,
#  <Reaction AICART at 0x2b3c3fb90>: 8959.0,
#  <Reaction ASPTA at 0x2b3c0d3d0>: 4668.0,
#  <Reaction GLYOX at 0x2b3c0f250>: 2690.0,
#  <Reaction PRAGSr at 0x2b3c4a850>: 5710.0,
#  <Reaction SQD1 at 0x2b3c4b9d0>: 118539.0,
#  <Reaction ACKr at 0x2b3c55e10>: 11581.0,
#  <Reaction UDCPDPS at 0x2b3c57310>: 3406.0,
#  <Reaction GK1 at 0x2b3c58a50>: 1082.0,
#  <Reaction SHKK at 0x2b3bd8590>: 1345.0,
#  <Reaction OXADC at 0x2b3c5abd0>: 11201.0,
#  <Reaction G1PACT at 0x2b3c5ba50>: 3010.0,
#  <Reaction 3HAD60 at 0x2b3c368d0>: 1476.0,
#  <Reaction PGI at 0x2b3c37750>: 21535.0,
#  <Reaction KAS14 at 0x2b3c28650>: 31799.0,
#  <Reaction OHPBAT at 0x2b3bf74d0>: 9779.0,
#  <Reaction PQH2tum at 0x2b3c74250>: 0.0,
#  <Reaction O2tu at 0x2b3c749d0>: 0.0,
#  <Reaction O2tpp at 0x2b3bc6b10>: 0.0,
#  <Reaction H2Otex at 0x2b3c76a50>: 0.0,
#  <Reaction SK_for_c at 0x2b3c77c10>: 0.0,
#  <Reaction EX_mg2_e at 0x2b3c7a550>: 0.0,
#  <Reaction 3HAD80 at 0x2b3c7ae50>: 1476.0,
#  <Reaction 3OAR160 at 0x2b3c7c7d0>: 1828.0,
#  <Reaction NMNS at 0x2b3c57590>: 406.0,
#  <Reaction PPK at 0x2b3c648d0>: 9431.0,
#  <Reaction GALUi at 0x2b3c668d0>: 4692.0,
#  <Reaction PHYTES2_1 at 0x2b3c7e290>: 10931.0,
#  <Reaction IGPDH at 0x2b3c7f350>: 14861.0,
#  <Reaction OMPDC at 0x2b3c7fe90>: 3156.0,
#  <Reaction DCTPD at 0x2b3c5acd0>: 96.0,
#  <Reaction GLUSfx at 0x2b3c89e50>: 233941.0,
#  <Reaction NADS2 at 0x2b3c8ab50>: 5595.0,
#  <Reaction GLUTRR at 0x2b3c8bf50>: 10669.0,
#  <Reaction G1PTT at 0x2b3c95250>: 2938.0,
#  <Reaction UAMAGS at 0x2b3c8bf90>: 2602.0,
#  <Reaction SPS at 0x2b3ca4310>: 20297.0,
#  <Reaction ADCL at 0x2b3ca5150>: 1138.0,
#  <Reaction CYTK1 at 0x2b3c3ed50>: 2570.0,
#  <Reaction DAPDC at 0x2b3ca7790>: 30162.0,
#  <Reaction PSIum at 0x2b3c96250>: 4361.0,
#  <Reaction R05219 at 0x2b3cb1550>: 894.0,
#  <Reaction Cobalt2abcppI at 0x2b3c0da50>: 838.0,
#  <Reaction PFK_3 at 0x2b3cb1610>: 2502.0,
#  <Reaction THRS at 0x2b3cbc3d0>: 68100.0,
#  <Reaction NAMNPP at 0x2b3c5bb10>: 406.0,
#  <Reaction FOLD3 at 0x2b3c89790>: 1419.0,
#  <Reaction P5CR at 0x2b3ccd990>: 1498.0,
#  <Reaction MEHLER_1 at 0x2b3cce9d0>: 18344.0,
#  <Reaction ICHORS at 0x2b3ccc490>: 7859.0,
#  <Reaction 3OAS140 at 0x2b3c89710>: 31799.0,
#  <Reaction PPK2 at 0x2b3ccc910>: 9431.0,
#  <Reaction IPDPS_syn at 0x2b3ccc890>: 13647.0,
#  <Reaction GLYDHDA at 0x2b3c3dbd0>: 5378.0,
#  <Reaction SBP at 0x2b3c3db50>: 15502.0,
#  <Reaction H4THDPS at 0x2b3ce1890>: 22290.0,
#  <Reaction EAR60y at 0x2b3ce2990>: 3064.0,
#  <Reaction ZNabcpp at 0x2b3c659d0>: 1276.0,
#  <Reaction UAPGR at 0x2b3cd26d0>: 2278.0,
#  <Reaction DHAD1 at 0x2b3cebe10>: 11545.0,
#  <Reaction IPPS at 0x2b3cea590>: 9513.0,
#  <Reaction ANS at 0x2b3cebcd0>: 9684.0,
#  <Reaction SUCBZL at 0x2b3c7ff50>: 2336.0,
#  <Reaction ADSL1r at 0x2b3cf6950>: 18748.0,
#  <Reaction NNATr at 0x2b3c953d0>: 5102.0,
#  <Reaction PERD at 0x2b3d011d0>: 8485.0,
#  <Reaction PPBNGS at 0x2b3d02890>: 29075.0,
#  <Reaction ADOCBLS at 0x2b3c95310>: 628.0,
#  <Reaction LTHRK at 0x2b3cf4090>: 79360.0,
#  <Reaction PPS at 0x2b3d0e7d0>: 11441.0,
#  <Reaction APRAUR at 0x2b3d11650>: 0.0,
#  <Reaction PDS2_1 at 0x2b3d10650>: 14073.0,
#  <Reaction O2tex at 0x2b3c95390>: 0.0,
#  <Reaction ALAALAr at 0x2b3c96390>: 5191.0,
#  <Reaction ADCPS2 at 0x2b3d20dd0>: 768.0,
#  <Reaction GF6PTA at 0x2b3cbca90>: 10226.0,
#  <Reaction DNMPPA at 0x2b3cbd690>: 0.0,
#  <Reaction PGMT at 0x2b3c0e450>: 21186.0,
#  <Reaction G5SADs at 0x2b3d2c810>: 0.0,
#  <Reaction GLCP2_1 at 0x2b3d0d750>: 178236.0,
#  <Reaction AGDI_1 at 0x2b3d01790>: 4280.0,
#  <Reaction LPADSS2 at 0x2b3c367d0>: 3620.0,
#  <Reaction GLYCK at 0x2b3d0d5d0>: 5454.0,
#  <Reaction DPR at 0x2b3d2fd10>: 15033.0,
#  <Reaction EX_ptrc_e at 0x2b3d309d0>: 0.0,
#  <Reaction EAR120y at 0x2b3d31410>: 3064.0,
#  <Reaction MAN1PT at 0x2b3d33650>: 9560.0,
#  <Reaction NMNAT at 0x2b3d32650>: 5102.0,
#  <Reaction TKT2 at 0x2b3d0d990>: 87361.0,
#  <Reaction PSP_L at 0x2b3d30a50>: 3202.0,
#  <Reaction HEX7 at 0x2b3d0fb50>: 2890.0,
#  <Reaction PPNCL2 at 0x2b3c58b50>: 3941.0,
#  <Reaction CHORS at 0x2b3d47e50>: 6345.0,
#  <Reaction CYTBD4cm at 0x2b3cf7dd0>: 2702.0,
#  <Reaction PPNCL3 at 0x2b3d4a350>: 3941.0,
#  <Reaction CS at 0x2b3d4b8d0>: 7200.0,
#  <Reaction PPCDC at 0x2b3d505d0>: 3941.0,
#  <Reaction LDH_D at 0x2b3d51350>: 1524.0,
#  <Reaction HPYRRy at 0x2b3cf7f50>: 2230.0,
#  <Reaction ADMDC at 0x2b3d58a10>: 27350.0,
#  <Reaction PRE3BS at 0x2b3d59d90>: 6659.0,
#  <Reaction PPPGO2_1 at 0x2b3d471d0>: 9661.0,
#  <Reaction BIOMASS_DNA at 0x2b3d640d0>: 604.0,
#  <Reaction DMATT at 0x2b3d64fd0>: 5828.0,
#  <Reaction DNAMTn2r at 0x2b3d67b50>: 10726.0,
#  <Reaction G3PD2 at 0x2b3d66dd0>: 2148.0,
#  <Reaction BIOMASS_CELL_WALL at 0x2b3d67a10>: 0.0,
#  <Reaction PHYTES at 0x2b3d67a90>: 10931.0,
#  <Reaction RB15BPtcx at 0x2b3d77790>: 0.0,
#  <Reaction MI3PP at 0x2b3d76710>: 1868.0,
#  <Reaction MOHMT at 0x2b3ce0190>: 2387.0,
#  <Reaction GLXO3r at 0x2b3d0e850>: 0.0,
#  <Reaction FBA at 0x2b3d747d0>: 230649.0,
#  <Reaction RZ5PP at 0x2b3d7f610>: 0.0,
#  <Reaction PROAKGOX1 at 0x2b3c37790>: 9771.0,
#  <Reaction ASAD at 0x2b3d4a490>: 22929.0,
#  <Reaction CYSS_2 at 0x2b3d8d790>: 18375.0,
#  <Reaction LYCOPC at 0x2b3d8d8d0>: 4539.0,
#  <Reaction ACOTA at 0x2b3d74550>: 22054.0,
#  <Reaction 3HAD180 at 0x2b3d8fad0>: 1476.0,
#  <Reaction FTHFD at 0x2b3d95f10>: 1088.0,
#  <Reaction ALDD2y at 0x2b3d96d50>: 11507.0,
#  <Reaction 3OAS80 at 0x2b3d2c8d0>: 31799.0,
#  <Reaction PSCVT at 0x2b3d7cb50>: 1930.0,
#  <Reaction CBPS at 0x2b3d77850>: 9475.0,
#  <Reaction NTPP8 at 0x2b3cbca50>: 1490.0,
#  <Reaction MEPCT at 0x2b3d11950>: 2308.0,
#  <Reaction PDX5POi at 0x2b3dacc10>: 416.0,
#  <Reaction DHAD2 at 0x2b3daee50>: 11545.0,
#  <Reaction DHFS at 0x2b3dacc50>: 2171.0,
#  <Reaction PGCD at 0x2b3d11f50>: 21799.0,
#  <Reaction SPMDabcpp at 0x2b3db6450>: 1746.0,
#  <Reaction NTD6 at 0x2b3db7010>: 10830.0,
#  <Reaction NNDMBRT at 0x2b3d67e10>: 3678.0,
#  <Reaction PRATPP at 0x2b3daefd0>: 2906.0,
#  <Reaction ASNN at 0x2b3dbf1d0>: 6717.0,
#  <Reaction SERAT at 0x2b3d96450>: 10831.0,
#  <Reaction PRAIS at 0x2b3dbf250>: 7447.0,
#  <Reaction PRAMPC at 0x2b3daf410>: 2906.0,
#  <Reaction AMPMS3 at 0x2b3dc7a50>: 118919.0,
#  <Reaction G1PCTYT at 0x2b3dd0b10>: 2234.0,
#  <Reaction ACBIPGT at 0x2b3db7090>: 822.0,
#  <Reaction SEPHCHCS at 0x2b3dd2cd0>: 3541.0,
#  <Reaction NMNDA at 0x2b3d46d50>: 2502.0,
#  <Reaction CA2abcpp at 0x2b3d01210>: 7178.0,
#  <Reaction ORNTAC at 0x2b3dddd50>: 3794.0,
#  <Reaction SUCBZS at 0x2b3ddee90>: 1252.0,
#  <Reaction UHGADA2 at 0x2b3dbc750>: 5321.0,
#  <Reaction DHNANT at 0x2b3de5850>: 2934.0,
#  <Reaction ASPO6 at 0x2b3d44750>: 2576.0,
#  <Reaction HGYDAS at 0x2b3dbc650>: 680.0,
#  <Reaction GGDPR at 0x2b3dc7b10>: 35786.0,
#  <Reaction ASP1DC at 0x2b3df5010>: 4849.0,
#  <Reaction PPNDH at 0x2b3df6190>: 1038.0,
#  <Reaction ASPK at 0x2b3df7850>: 4291.0,
#  <Reaction DXPS at 0x2b3d58b50>: 40893.0,
#  <Reaction ME2 at 0x2b3df97d0>: 14399.0,
#  <Reaction 3PGtcx at 0x2b3dd0bd0>: 0.0,
#  <Reaction DDPGA at 0x2b3dbda90>: 1732.0,
#  <Reaction PAPSR at 0x2b3e05a50>: 15844.0,
#  <Reaction SADT at 0x2b3e048d0>: 7520.0,
#  <Reaction BIOMASS_COFACTORS at 0x2b3e06cd0>: 0.0,
#  <Reaction DPCOAK at 0x2b3e06c90>: 478.0,
#  <Reaction NH4tpp at 0x2b3e0d350>: 136989.0,
#  <Reaction DM_h2_c at 0x2b3e07dd0>: 0.0,
#  <Reaction PC11M at 0x2b3cf5fd0>: 678.0,
#  <Reaction DPOR at 0x2b3e12a10>: 17487.0,
#  <Reaction ARGSL at 0x2b3ddffd0>: 4356.0,
#  <Reaction HSK at 0x2b3dc6310>: 1308.0,
#  <Reaction MTHFD at 0x2b3dfab90>: 6340.0,
#  <Reaction PMDPHT at 0x2b3e21610>: 430.0,
#  <Reaction ARGabcpp at 0x2b3e22a90>: 1602.0,
#  <Reaction 3HAD140 at 0x2b3d65110>: 1476.0,
#  <Reaction ARGOXRum at 0x2b3e31490>: 14814.0,
#  <Reaction DAPE at 0x2b3df5390>: 880.0,
#  <Reaction BCAROHX2 at 0x2b3e32d50>: 14028.0,
#  <Reaction HPPK at 0x2b3e20210>: 830.0,
#  <Reaction PANTS at 0x2b3d8fdd0>: 2570.0,
#  <Reaction AHCi at 0x2b3e3d8d0>: 26347.0,
#  <Reaction G6PDH2r at 0x2b3de6810>: 62341.0,
#  <Reaction ALAD_L at 0x2b3d7e790>: 5378.0,
#  <Reaction GTPCII at 0x2b3df8810>: 20673.0,
#  <Reaction GLCBRAN3 at 0x2b3e49e10>: 30153.0,
#  <Reaction DB4PS at 0x2b3e3ea50>: 20673.0,
#  <Reaction DXPRIi at 0x2b3e3ead0>: 8734.0,
#  <Reaction FBA3 at 0x2b3e51ad0>: 230649.0,
#  <Reaction RBFSa at 0x2b3e52490>: 20216.0,
#  <Reaction GLUTRS at 0x2b3e53690>: 8294.0,
#  <Reaction MPOMMM at 0x2b3e58590>: 71270.0,
#  <Reaction METAT at 0x2b3e528d0>: 16679.0,
#  <Reaction EAR160y at 0x2b3e48a90>: 3064.0,
#  <Reaction DHORTS at 0x2b3e5b8d0>: 12025.0,
#  <Reaction PDX5PS2 at 0x2b3e64c50>: 3994.0,
#  <Reaction KARI_23dhmp_1 at 0x2b3e66990>: 15033.0,
#  <Reaction ARGDC at 0x2b3e3d9d0>: 7920.0,
#  <Reaction GAPDi_nadp at 0x2b3dd2010>: 62378.0,
#  <Reaction NTD7 at 0x2b3e71750>: 10830.0,
#  <Reaction AIRC3 at 0x2b3e72250>: 1434.0,
#  <Reaction UMPK at 0x2b3e73590>: 4438.0,
#  <Reaction ASPOb at 0x2b3e33010>: 2576.0,
#  <Reaction RBFSb_1 at 0x2b3e75f10>: 2542.0,
#  <Reaction SUCDum at 0x2b3e769d0>: 876.0,
#  <Reaction FBP at 0x2b3e77b10>: 70035.0,
#  <Reaction CITCIb at 0x2b3e84990>: 5953.0,
#  <Reaction MNabc_1 at 0x2b3e74ad0>: 1276.0,
#  <Reaction TMPK at 0x2b3dd2050>: 858.0,
#  <Reaction AGPR at 0x2b3e33390>: 6513.0,
#  <Reaction IPMD at 0x2b3e853d0>: 12058.0,
#  <Reaction CDPMEK at 0x2b3e89c10>: 1317.0,
#  <Reaction DVOCHR_1 at 0x2b3e8b950>: 10057.0,
#  <Reaction H2CO3_NAt_syn at 0x2b3e908d0>: 1760.0,
#  <Reaction HEMEOS at 0x2b3e4b190>: 3319.0,
#  <Reaction PMANM at 0x2b3e92610>: 6739.0,
#  <Reaction RPE at 0x2b3e8a510>: 15281.0,
#  <Reaction MPOMT_1 at 0x2b3e93d50>: 4742.0,
#  <Reaction CPPPGO2 at 0x2b3e8a7d0>: 888.0,
#  <Reaction PC17M_1 at 0x2b3e52650>: 1548.0,
#  <Reaction UAMAS at 0x2b3d4b950>: 11920.0,
#  <Reaction GLUCYS at 0x2b3de75d0>: 16204.0,
#  <Reaction NDHPQRum at 0x2b3e70890>: 39218.0,
#  <Reaction CYNL at 0x2b3eadc90>: 1446.0,
#  <Reaction DCTPD2 at 0x2b3d038d0>: 2913.0,
#  <Reaction CYOOum at 0x2b3ebca90>: 7377.0,
#  <Reaction BPNT2 at 0x2b3ebd350>: 8711.0,
#  <Reaction METS_1 at 0x2b3e04a10>: 14314.0,
#  <Reaction PRUK at 0x2b3ebf590>: 120815.0,
#  <Reaction FNOR_1 at 0x2b3ec4390>: 63404.0,
#  <Reaction GART at 0x2b3e669d0>: 2318.0,
#  <Reaction IPPMIb at 0x2b3ec6b90>: 5953.0,
#  <Reaction DMTPHT at 0x2b3ec7a50>: 900.0,
#  <Reaction PC6YM_1 at 0x2b3ec6c50>: 1431.0,
#  <Reaction PGL at 0x2b3e88410>: 6378.0,
#  <Reaction DDPA at 0x2b3ed2910>: 67975.0,
#  <Reaction ASPCT at 0x2b3d9b150>: 2392.0,
#  <Reaction HSERTA at 0x2b3e4b1d0>: 5884.0,
#  <Reaction OMCDC at 0x2b3e88290>: 0.0,
#  <Reaction CYRDAAT at 0x2b3ed6fd0>: 10802.0,
#  <Reaction MECDPDHf at 0x2b3ee5590>: 13724.0,
#  <Reaction Htcx at 0x2b3ee6ed0>: 0.0,
#  <Reaction H2Otpp at 0x2b3ee6e50>: 0.0,
#  <Reaction HISTP at 0x2b3eec250>: 0.0,
#  <Reaction MTHFR3_1 at 0x2b3e332d0>: 2227.0,
#  <Reaction EX_ca2_e at 0x2b3eefdd0>: 0.0,
#  <Reaction 3HAD40_2 at 0x2b3e33590>: 1476.0,
#  <Reaction ZCAROTDH1 at 0x2b3ef0ad0>: 7304.0,
#  <Reaction CYRDAR at 0x2b3d960d0>: 0.0,
#  <Reaction BIOMASS_MEM_LIPIDS at 0x2b3ef4310>: 0.0,
#  <Reaction HCO3tcx at 0x2b3ee4650>: 0.0,
#  <Reaction GLYALDDy at 0x2b3ef7010>: 11507.0,
#  <Reaction IMPC at 0x2b3ef74d0>: 8959.0,
#  <Reaction BIOMASS_PROTEIN at 0x2b3f09710>: 0.0,
#  <Reaction LDAPAT at 0x2b3f08350>: 4265.0,
#  <Reaction EX_nh4_e at 0x2b3e90910>: 0.0,
#  <Reaction 3OAR40_2 at 0x2b3f08310>: 1828.0,
#  <Reaction RNDR2 at 0x2b3f18450>: 17817.0,
#  <Reaction GRTT at 0x2b3f18490>: 5828.0,
#  <Reaction NPDPS at 0x2b3ed2a50>: 5912.0,
#  <Reaction 3OAS100 at 0x2b3f19c50>: 31799.0,
#  <Reaction ADSL2r at 0x2b3f1abd0>: 18748.0,
#  <Reaction MAN6PI at 0x2b3f1bfd0>: 9560.0,
#  <Reaction HPROb at 0x2b3f20b90>: 1498.0,
#  <Reaction 3OAS120 at 0x2b3f21910>: 31799.0,
#  <Reaction NTPP2 at 0x2b3ef0cd0>: 1490.0,
#  <Reaction EAR180y at 0x2b3f23150>: 3064.0,
#  <Reaction DHQTi at 0x2b3eadcd0>: 1448.0,
#  <Reaction 3OAS60 at 0x2b3f34e50>: 31799.0,
#  <Reaction EAR40y at 0x2b3ec7bd0>: 3064.0,
#  <Reaction MG2uabcpp at 0x2b3f36c90>: 8127.0,
#  <Reaction KARA1 at 0x2b3f37a90>: 15033.0,
#  <Reaction TKT1 at 0x2b3f38850>: 87361.0,
#  <Reaction PTRCabcpp at 0x2b3f392d0>: 1746.0,
#  <Reaction IPDDI at 0x2b3f3ab50>: 5522.0,
#  <Reaction PKETF at 0x2b3f3ba10>: 45241.0,
#  <Reaction ACODA at 0x2b3f444d0>: inf,
#  <Reaction ENO at 0x2b3f45dd0>: 8153.0,
#  <Reaction NDHPQRcm at 0x2b3f46c10>: 39218.0,
#  <Reaction NI2uabcpp at 0x2b3f47a50>: 30831.0,
#  <Reaction Kabcpp at 0x2b3f53290>: 2014.0,
#  <Reaction TDPDRR at 0x2b3e8ab10>: 706.0,
#  <Reaction UAGCVT at 0x2b3f53250>: 10818.0,
#  <Reaction TDPGDH at 0x2b3f60c10>: 4184.0,
#  <Reaction PRASCSi at 0x2b3f62610>: 3890.0,
#  <Reaction PRFGS at 0x2b3f18690>: 1642.0,
#  <Reaction MG2tex at 0x2b3f688d0>: 2180.0,
#  <Reaction GLU5K at 0x2b3e58710>: 2983.0,
#  <Reaction TRDR at 0x2b3f53850>: 16744.0,
#  <Reaction GLUPRT at 0x2b3f70d10>: 34175.0,
#  <Reaction PSERT at 0x2b3f72a90>: 13415.0,
#  <Reaction PC8XM at 0x2b3f62bd0>: 2752.0,
#  <Reaction GMPS2 at 0x2b3e74c10>: 44123.0,
#  <Reaction RBFK at 0x2b3ed2ad0>: 3423.0,
#  <Reaction NTRIRfx at 0x2b3f83610>: 16512.0,
#  <Reaction UPP3MT at 0x2b3f6af10>: 972.0,
#  <Reaction ACS at 0x2b3e12c50>: 9030.0,
#  <Reaction DHNCOAS at 0x2b3f87050>: 1356.0,
#  <Reaction MCOATA at 0x2b3f87f90>: 1990.0,
#  <Reaction GTHPi at 0x2b3f8ce50>: 4059.0,
#  <Reaction ARGSS at 0x2b3f19e50>: 8065.0,
#  <Reaction PKETX at 0x2b3f8f750>: 45241.0,
#  <Reaction PMPK at 0x2b3e89e50>: 1179.0,
#  <Reaction HMBS at 0x2b3f9a550>: 8998.0,
#  <Reaction PTPATi at 0x2b3f9bcd0>: 5261.0,
#  <Reaction PGLYCP at 0x2b3f9cb90>: 2150.0,
#  <Reaction HTHRPDH at 0x2b3f9d5d0>: 7327.0,
#  <Reaction UAGAAT2 at 0x2b3f82350>: 5210.0,
#  <Reaction SPTc at 0x2b3fa8210>: 9779.0,
#  <Reaction GTHOr at 0x2b3f39390>: 8926.0,
#  <Reaction TDPDRE at 0x2b3f39310>: 2242.0,
#  <Reaction SHK3Dr at 0x2b3faa790>: 1612.0,
#  <Reaction ORPT at 0x2b3fabb50>: 1942.0,
#  <Reaction PRPPS at 0x2b3fa9550>: 77580.0,
#  <Reaction CITMS at 0x2b3fb1d50>: 136934.0,
#  <Reaction BCT1_syn at 0x2b3f39450>: 660.0,
#  <Reaction SPODM at 0x2b3f83710>: 22195.0,
#  <Reaction TRDRf at 0x2b3f09690>: 1570.0,
#  <Reaction AMPTASECG at 0x2b3fbe150>: 24086.0,
#  <Reaction SPRMS at 0x2b3faaad0>: 3334.0,
#  <Reaction PGAMT at 0x2b3f44590>: 8704.0,
#  <Reaction NNDPR at 0x2b3fc9610>: 2824.0,
#  <Reaction ADSK at 0x2b3fcb0d0>: 1930.0,
#  <Reaction MECDPS at 0x2b3fd04d0>: 2986.0,
#  <Reaction FCLT at 0x2b3fd0d10>: 27047.0,
#  <Reaction SHCHCS3 at 0x2b3fd2390>: 7599.0,
#  <Reaction PPA at 0x2b3fd3710>: 5946.0,
#  <Reaction ADCYRS at 0x2b3f986d0>: 3689.0,
#  <Reaction ATPPRT at 0x2b3fbfe50>: 2174.0,
#  <Reaction CUabcpp at 0x2b3f85e90>: 30831.0,
#  <Reaction DHQS at 0x2b3f8ed10>: 5414.0,
#  <Reaction GTHRDH_syn at 0x2b3fc8090>: 2762.0,
#  <Reaction ANPRT at 0x2b3fe2150>: 2750.0,
#  <Reaction PC6AR_1 at 0x2b3f8efd0>: 466.0,
#  <Reaction ADK1 at 0x2b3fec990>: 9155.0,
#  <Reaction PRAIi at 0x2b3fdfdd0>: 1366.0,
#  <Reaction TRSARyr at 0x2b3fef210>: 2230.0,
#  <Reaction CYNTtabcpp at 0x2b3fefc50>: 812.0,
#  <Reaction RBPCcx at 0x2b3fdd110>: 1757.0,
#  <Reaction UPP3S at 0x2b3f23290>: 1896.0,
#  <Reaction DHNPA_1 at 0x2b3f45f50>: 2731.0,
#  <Reaction MOBDabcpp at 0x2b3ff7bd0>: 520.0,
#  <Reaction NADK at 0x2b3fbe310>: 10094.0,
#  <Reaction BIOMASS_RNA at 0x2b4002cd0>: 0.0,
#  <Reaction NADTRHD at 0x2b3fbe610>: 6449.0,
#  <Reaction PGM at 0x2b400de90>: 33250.0,
#  <Reaction FE3abcpp at 0x2b400c850>: 58828.0,
#  <Reaction DM_dialurate_c at 0x2b4017c90>: 0.0,
#  <Reaction CO2tex at 0x2b3f9d690>: 0.0,
#  <Reaction USHD2 at 0x2b3fbe690>: 0.0,
#  <Reaction DHNCOAT at 0x2b401d150>: 942.0,
#  <Reaction NPHBDC at 0x2b401da90>: 640.0,
#  <Reaction DM_co_c at 0x2b40152d0>: 0.0,
#  <Reaction HCO3E_1_cx at 0x2b400e250>: 4125.0,
#  <Reaction DESAT16a at 0x2b401f910>: 43013.0,
#  <Reaction UAGDP at 0x2b3fbfb90>: 3010.0,
#  <Reaction BIOMASS_CARB at 0x2b40178d0>: 0.0,
#  <Reaction EX_fe2_e at 0x2b4017a50>: 0.0,
#  <Reaction PQH2tcm at 0x2b4032cd0>: 0.0,
#  <Reaction 2PGLYCtcx at 0x2b4033950>: 0.0,
#  <Reaction PDS1_1 at 0x2b4033c90>: 14073.0,
#  <Reaction EX_cu2_e at 0x2b40381d0>: 0.0,
#  <Reaction FRTT at 0x2b4030b50>: 5828.0,
#  <Reaction 3OAS180 at 0x2b3f50f10>: 31799.0,
#  <Reaction EAR80y at 0x2b4038ad0>: 3064.0,
#  <Reaction DM_5drib_c at 0x2b403a2d0>: 0.0,
#  <Reaction SK_amylose_c at 0x2b403a290>: 0.0,
#  <Reaction EAR140y at 0x2b403bb50>: 3064.0,
#  <Reaction EX_k_e at 0x2b3f60c90>: 0.0,
#  <Reaction ACGS at 0x2b403b090>: 3794.0,
#  <Reaction CYTBD4um at 0x2b4040c10>: 2702.0,
#  <Reaction DHPPDA at 0x2b4040c50>: 1680.0,
#  <Reaction DHFR at 0x2b4017810>: 354.0,
#  <Reaction BCAROHX at 0x2b404e610>: 14028.0,
#  <Reaction SK_14glucan_c at 0x2b404f390>: 0.0,
#  <Reaction SK_glycogen_c at 0x2b3fdc350>: 0.0,
#  <Reaction EX_h2o_e at 0x2b405a510>: 0.0,
#  <Reaction EX_o2_e at 0x2b405aa90>: 0.0,
#  <Reaction EX_co2_e at 0x2b3faa110>: 0.0,
#  <Reaction EX_leu__L_e at 0x2b405d650>: 0.0,
#  <Reaction MPOMC1_1 at 0x2b405eb10>: 71270.0,
#  <Reaction ERTHMMOR at 0x2b405f250>: 12058.0,
#  <Reaction EX_cobalt2_e at 0x2b4058410>: 0.0,
#  <Reaction EX_no3_e at 0x2b4060190>: 0.0,
#  <Reaction EX_zn2_e at 0x2b4060dd0>: 0.0,
#  <Reaction EX_fe3_e at 0x2b404f4d0>: 0.0,
#  <Reaction EX_so4_e at 0x2b4064590>: 0.0,
#  <Reaction AFAT at 0x2b4017750>: 3423.0,
#  <Reaction EX_spmd_e at 0x2b4065c50>: 0.0,
#  <Reaction EX_mobd_e at 0x2b404f810>: 0.0,
#  <Reaction DADK at 0x2b4066fd0>: 9155.0,
#  <Reaction G1SAT at 0x2b4067d90>: 36669.0,
#  <Reaction EX_ni2_e at 0x2b4067010>: 0.0,
#  <Reaction UAAGDS at 0x2b403a5d0>: 12497.0,
#  <Reaction HEX1 at 0x2b4075d90>: 4544.0,
#  <Reaction URIDK2r at 0x2b4075310>: 1758.0,
#  <Reaction CHPHYS at 0x2b40773d0>: 4779.0,
#  <Reaction EX_na1_e at 0x2b4077390>: 0.0,
#  <Reaction PIuabcpp at 0x2b404e810>: 1218.0,
#  <Reaction ARGDHpp at 0x2b407a5d0>: 2140.0,
#  <Reaction PHETA1 at 0x2b4081390>: 14256.0,
#  <Reaction PFK at 0x2b4081210>: 2502.0,
#  <Reaction DMPPS_syn at 0x2b40811d0>: 13647.0,
#  <Reaction ANS2 at 0x2b40812d0>: 9684.0,
#  <Reaction 3OAS160 at 0x2b408c090>: 31799.0,
#  <Reaction ACHBSb at 0x2b408f390>: 10752.0,
#  <Reaction PC20M at 0x2b408df90>: 1678.0,
#  <Reaction ADSS at 0x2b408f310>: 17047.0,
#  <Reaction THRPDC at 0x2b4081cd0>: 1337.0,
#  <Reaction MPOMOR_1 at 0x2b4098c50>: 71270.0,
#  <Reaction EX_cynt_e at 0x2b408c1d0>: 0.0,
#  <Reaction IPPMIa at 0x2b409b5d0>: 5953.0,
#  <Reaction SPMS at 0x2b40a1290>: 3334.0,
#  <Reaction EX_h_e at 0x2b40a2310>: 0.0,
#  <Reaction BPNT at 0x2b40a22d0>: 8711.0,
#  <Reaction ICDHyr at 0x2b40a38d0>: 19268.0,
#  <Reaction TMDS3 at 0x2b40ae110>: 7543.0,
#  <Reaction GLYOX_1 at 0x2b40671d0>: 9311.0,
#  <Reaction MTRI at 0x2b40ae090>: 1946.0,
#  <Reaction CTPS2 at 0x2b40af7d0>: 9466.0,
#  <Reaction FE3tex at 0x2b4077490>: 0.0,
#  <Reaction GTHS at 0x2b3fdc490>: 6654.0,
#  <Reaction AHSERL2_1 at 0x2b4079790>: 21718.0,
#  <Reaction PEPC at 0x2b408f8d0>: 66024.0,
#  <Reaction CHORM at 0x2b4077510>: 6717.0,
#  <Reaction NTRARf2 at 0x2b40c7510>: 3051.0,
#  <Reaction FE2tex at 0x2b40775d0>: 0.0,
#  <Reaction G6PDA at 0x2b4077590>: 1186.0,
#  <Reaction MPML at 0x2b40d2610>: 5829.0,
#  <Reaction Nat_Kpp at 0x2b40d1710>: 2325.0,
#  <Reaction PDH at 0x2b40af850>: 11500.0,
#  <Reaction TPI at 0x2b40d3ad0>: 2850.0,
#  <Reaction E4PD at 0x2b40e14d0>: 73850.0,
#  <Reaction GAPD at 0x2b40e2310>: 73850.0,
#  <Reaction CPPPGO at 0x2b40b8850>: 12315.0,
#  <Reaction PRMICI at 0x2b40ddcd0>: 8270.0,
#  <Reaction CAT at 0x2b40deed0>: 21336.0,
#  <Reaction GLUR at 0x2b4060e90>: 2968.0,
#  <Reaction OCBT at 0x2b40ee550>: 3678.0,
#  <Reaction NI2tex at 0x2b3fddc50>: 0.0,
#  <Reaction GLGC at 0x2b40ae710>: 43986.0,
#  <Reaction PYK at 0x2b40bad10>: 23945.0,
#  <Reaction CA2t2pp at 0x2b40fcd90>: 4359.0,
#  <Reaction ALAR at 0x2b40ffd50>: 7231.0,
#  <Reaction SULR_2 at 0x2b40eed50>: 11904.0,
#  <Reaction ADCS at 0x2b40fff50>: 2522.0,
#  <Reaction UGMDDS at 0x2b4101b90>: 4885.0,
#  <Reaction GLCDBRAN3 at 0x2b4102710>: 7427.0,
#  <Reaction IG3PS at 0x2b4103690>: 2697.0,
#  <Reaction RPI at 0x2b40dc110>: 1443.0,
#  <Reaction NAt3pp at 0x2b410f850>: 53731.0,
#  <Reaction MNtex at 0x2b4098410>: 0.0,
#  <Reaction GLYCLTDx at 0x2b40d01d0>: 8902.0,
#  <Reaction FMNRy_1 at 0x2b40ae610>: 2615.0,
#  <Reaction GHMT2r at 0x2b4120690>: 42308.0,
#  <Reaction COBALT2tex at 0x2b41205d0>: 0.0,
#  <Reaction PGPP_OLE_PALM at 0x2b4078750>: 0.0,
#  <Reaction CU2tex at 0x2b4122a90>: 0.0,
#  <Reaction MEOHtrpp at 0x2b4123d90>: 0.0,
#  <Reaction MEOHtex at 0x2b412c910>: 0.0,
#  <Reaction H2Otcx at 0x2b412d1d0>: 0.0,
#  <Reaction Zn2tex at 0x2b412db10>: 0.0,
#  <Reaction EX_photon410_e at 0x2b412e390>: 0.0,
#  <Reaction EX_photon430_e at 0x2b4131010>: 0.0,
#  <Reaction EX_photon450_e at 0x2b4130fd0>: 0.0,
#  <Reaction EX_photon470_e at 0x2b41316d0>: 0.0,
#  <Reaction EX_photon490_e at 0x2b4131a10>: 0.0,
#  <Reaction EX_photon510_e at 0x2b4131d90>: 0.0,
#  <Reaction DM_amob_c at 0x2b4131d50>: 0.0,
#  <Reaction ADNK1 at 0x2b4132090>: 0.0,
#  <Reaction OPMEACPD at 0x2b41323d0>: 1476.0,
#  <Reaction OPMEACPR at 0x2b4133350>: 1828.0,
#  <Reaction EX_photon530_e at 0x2b413ca90>: 0.0,
#  <Reaction EX_photon550_e at 0x2b410f950>: 0.0,
#  <Reaction SPP at 0x2b413c890>: 20297.0,
#  <Reaction SPMDtex at 0x2b413cf50>: 0.0,
#  <Reaction AGPAT160 at 0x2b4133bd0>: 1558.0,
#  <Reaction EX_photon570_e at 0x2b413f550>: 0.0,
#  <Reaction EX_photon590_e at 0x2b413f7d0>: 0.0,
#  <Reaction EX_photon610_e at 0x2b413fa50>: 0.0,
#  <Reaction AGPATACP_HDE_PALM at 0x2b413fa10>: 1558.0,
#  <Reaction LEUtex at 0x2b413fd10>: 0.0,
#  <Reaction BTS6 at 0x2b413f2d0>: 15669.0,
#  <Reaction QUERT at 0x2b4148490>: 1996.0,
#  <Reaction EX_photon630_e at 0x2b414b7d0>: 0.0,
#  <Reaction EX_photon650_e at 0x2b414a350>: 0.0,
#  <Reaction EX_photon670_e at 0x2b414bb90>: 0.0,
#  <Reaction EX_photon690_e at 0x2b414be50>: 0.0,
#  <Reaction PMEACPE at 0x2b414be10>: 330.0,
#  <Reaction G3PAT160 at 0x2b41541d0>: 2976.0,
#  <Reaction GLUDGE_HDE_HDE at 0x2b4155b10>: 18879.0,
#  <Reaction G3PAT161 at 0x2b40df350>: 2976.0,
#  <Reaction HCO3tex at 0x2b4154d10>: 0.0,
#  <Reaction G3PAT1819Z_1 at 0x2b40e23d0>: 2976.0,
#  <Reaction EPMEACPR at 0x2b4156950>: 3064.0,
#  <Reaction GLUDGE_OLE_HDE at 0x2b41591d0>: 18879.0,
#  <Reaction GLUDGE_OLE_PALM at 0x2b41596d0>: 18879.0,
#  <Reaction GLUDGE_HDE_PALM at 0x2b4159d90>: 18879.0,
#  <Reaction GLNtex at 0x2b4159650>: 0.0,
#  <Reaction AGPAT161 at 0x2b41594d0>: 1558.0,
#  <Reaction AGPATACP_OLE_HDE at 0x2b4155810>: 1558.0,
#  <Reaction AGPATACP_OLE_PALM at 0x2b4148590>: 1558.0,
#  <Reaction GLUDGS_OLE_HDE at 0x2b4168450>: 10972.0,
#  <Reaction CYNTtex at 0x2b40e2650>: 0.0,
#  <Reaction GLUDGS_OLE_PALM at 0x2b41692d0>: 10972.0,
#  <Reaction GLUDGS_HDE_PALM at 0x2b4169d10>: 10972.0,
#  <Reaction ARGtex at 0x2b40a3990>: 0.0,
#  <Reaction GLUDGS_HDE_HDE at 0x2b416b250>: 10972.0,
#  <Reaction TYRTRS at 0x2b416a690>: 3975.0,
#  <Reaction DAGK160 at 0x2b4169c10>: 6601.0,
#  <Reaction MOBDtex at 0x2b4156a90>: 0.0,
#  <Reaction DAGK_HDE_PALM at 0x2b416bb90>: 6601.0,
#  <Reaction DAGK161 at 0x2b4179a50>: 6601.0,
#  <Reaction NH4tex at 0x2b4178e90>: 0.0,
#  <Reaction SQDGS_PALM_PALM at 0x2b411e990>: 42614.0,
#  <Reaction SO4tex at 0x2b417b590>: 0.0,
#  <Reaction SQDGS_HDE_PALM at 0x2b4181f90>: 42614.0,
#  <Reaction PGPS_OLE_PALM at 0x2b41810d0>: 899.0,
#  <Reaction DGDGS_HDE_PALM at 0x2b4183490>: 11037.0,
#  <Reaction PTRCtex at 0x2b4178fd0>: 0.0,
#  <Reaction DGDGS_HDE_HDE at 0x2b4182850>: 11037.0,
#  <Reaction NO3tex at 0x2b4183d90>: 0.0,
#  <Reaction DGDGS_OLE_HDE at 0x2b4183310>: 11037.0,
#  <Reaction DGDGS_OLE_PALM at 0x2b41926d0>: 11037.0,
#  <Reaction CDPDAGS_OLE_PALM at 0x2b4017010>: 6743.0,
#  <Reaction GLNTRS at 0x2b4120d90>: 4335.0,
#  <Reaction METTRS at 0x2b4192450>: 16698.0,
#  <Reaction SERTRS at 0x2b4198d10>: 6950.0,
#  <Reaction NAtex at 0x2b41911d0>: 0.0,
#  <Reaction PROTRS at 0x2b4191150>: 5904.0,
#  <Reaction GLYTRS at 0x2b419b450>: 2395.0,
#  <Reaction CYSTRS at 0x2b4198fd0>: 7621.0,
#  <Reaction CA2tex at 0x2b414afd0>: 0.0,
#  <Reaction ARGTRS at 0x2b41a9a10>: 4809.0,
#  <Reaction Ktex at 0x2b41ac150>: 0.0,
#  <Reaction TRPTRS at 0x2b415b450>: 3588.0,
#  <Reaction HISTRS at 0x2b419b4d0>: 6268.0,
#  <Reaction CO2tpp at 0x2b4103750>: 0.0,
#  <Reaction PHETRS at 0x2b41b9b50>: 7978.0,
#  <Reaction EX_pi_e at 0x2b41bad10>: 0.0,
#  <Reaction ASNTRS at 0x2b4155c10>: 5580.0,
#  <Reaction ASPTRS at 0x2b41bd610>: 7274.0,
#  <Reaction UDPGLDC at 0x2b41bd650>: 7531.0,
#  <Reaction PItex at 0x2b41bf550>: 0.0,
#  <Reaction AGTi at 0x2b41bf510>: 9779.0,
#  <Reaction DBTS at 0x2b41d1650>: 1194.0,
#  <Reaction THRTRS at 0x2b41d09d0>: 17198.0,
#  <Reaction LEUTRS at 0x2b41d3bd0>: 22277.0,
#  <Reaction ILETRS at 0x2b41d3b90>: 37952.0,
#  <Reaction CHLADMT_1 at 0x2b41d9210>: 0.0,
#  <Reaction LYSTRS at 0x2b41da310>: 7308.0,
#  <Reaction AOXSr2 at 0x2b41e8790>: 1294.0,
#  <Reaction AMAOTr at 0x2b4198e10>: 2894.0,
#  <Reaction LIPOS2 at 0x2b41ea1d0>: 4802.0,
#  <Reaction ALATRS at 0x2b41ea190>: 23324.0,
#  <Reaction TRNFE at 0x2b41d1750>: 0.0,
#  <Reaction VALTRS at 0x2b41aaed0>: 9998.0,
#  <Reaction FMETTRS at 0x2b41ebe50>: 1870.0,
#  <Reaction BACCL at 0x2b41ed2d0>: 1304.0,
#  <Reaction BTNPL2 at 0x2b41ebd50>: 1304.0,
#  <Reaction LIPAMPL_1 at 0x2b41fc4d0>: 9382.0,
#  <Reaction LIPOCT at 0x2b41fd190>: 9128.0,
#  <Reaction LIPATPT_1 at 0x2b41fdf90>: 9382.0,
#  <Reaction ZXANHX at 0x2b414af90>: 7052.0,
#  <Reaction PHOA410um at 0x2b41eb010>: 0.0,
#  <Reaction PHOA430um at 0x2b414ac90>: 0.0,
#  <Reaction CPH4S at 0x2b4201990>: 1518.0,
#  <Reaction OGMEACPR at 0x2b4202f90>: 1828.0,
#  <Reaction CDGS at 0x2b41585d0>: 5421.0,
#  <Reaction PHOA450um at 0x2b420c1d0>: 0.0,
#  <Reaction PHOA470um at 0x2b41bd750>: 0.0,
#  <Reaction PHOA490um at 0x2b420da90>: 0.0,
#  <Reaction CCGS at 0x2b420edd0>: 2996.0,
#  <Reaction CDGR at 0x2b420f5d0>: 3637.0,
#  <Reaction PHOA510um at 0x2b420cd50>: 0.0,
#  <Reaction PHOA530um at 0x2b4218d10>: 0.0,
#  <Reaction PLYCOI at 0x2b4219c50>: 21488.0,
#  <Reaction PHOA550um at 0x2b4182a10>: 0.0,
#  <Reaction SAMTRI at 0x2b421af50>: 3881.0,
#  <Reaction EPXQR at 0x2b421aed0>: 1566.0,
#  <Reaction UPPRT at 0x2b421af10>: 2012.0,
#  <Reaction PHOA570um at 0x2b4228850>: 0.0,
#  <Reaction PHOA590um at 0x2b4081b90>: 0.0,
#  <Reaction PHOA610um at 0x2b422a690>: 0.0,
#  <Reaction ZCARDS at 0x2b422b110>: 7304.0,
#  <Reaction PHOA630um at 0x2b4201b10>: 0.0,
#  <Reaction PHOA650um at 0x2b4229710>: 0.0,
#  <Reaction PHOA670um at 0x2b422be10>: 0.0,
#  <Reaction UDPGD at 0x2b42309d0>: inf,
#  <Reaction GMAND at 0x2b4230ed0>: 1708.0,
#  <Reaction GFUCS at 0x2b41aafd0>: 617.0,
#  <Reaction PHOA690um at 0x2b4232410>: 0.0,
#  <Reaction NADDP at 0x2b422bf10>: 2382.0,
#  <Reaction DM_pho_loss_c at 0x2b4234350>: 0.0,
#  <Reaction ETCHLAS at 0x2b4233250>: 0.0,
#  <Reaction ETBCARO at 0x2b4235e10>: 0.0,
#  <Reaction COLIPAabcex at 0x2b4236ad0>: 0.0,
#  <Reaction MLDCP1App at 0x2b4237310>: 0.0,
#  <Reaction CDPGLC46DH at 0x2b424c2d0>: 1800.0,
#  <Reaction AACPS6 at 0x2b41b4350>: 12377.0,
#  <Reaction ALDR18 at 0x2b421b190>: 17118.0,
#  <Reaction ALDDC17 at 0x2b424d590>: 29297.0,
#  <Reaction ALCD19 at 0x2b424d550>: 22042.0,
#  <Reaction THZT at 0x2b421b250>: 14474.0,
#  <Reaction MLDCP1Bpp at 0x2b41fe110>: 0.0,
#  <Reaction PHYPQOX at 0x2b42502d0>: 14073.0,
#  <Reaction MLDCP2App at 0x2b4251a50>: 0.0,
#  <Reaction MLDCP2Bpp at 0x2b4251210>: 0.0,
#  <Reaction LALGP at 0x2b4252bd0>: inf,
#  <Reaction AGM4Pt2pp at 0x2b425c0d0>: 0.0,
#  <Reaction AGMt2pp at 0x2b425d0d0>: 0.0,
#  <Reaction CXANHX at 0x2b425d050>: 7052.0,
#  <Reaction OGMEACPS at 0x2b425e1d0>: 31799.0,
#  <Reaction A5PISO at 0x2b424f190>: 4271.0,
#  <Reaction KDOPS at 0x2b41ed990>: 9274.0,
#  <Reaction KDOPP at 0x2b425f010>: 4289.0,
#  <Reaction EX_meoh_e at 0x2b425fd10>: 0.0,
#  <Reaction NO2tex at 0x2b41feb50>: 0.0,
#  <Reaction KDOCT2 at 0x2b41ed910>: 1224.0,
#  <Reaction EGMEACPR at 0x2b411eb50>: 3064.0,
#  <Reaction DXYTST at 0x2b4265ad0>: 3142.0,
#  <Reaction UAG2E at 0x2b4274690>: 3498.0,
#  <Reaction OANTS at 0x2b4274650>: 1272.0,
#  <Reaction ACGAMT at 0x2b4275310>: 10565.0,
#  <Reaction Htabcpp at 0x2b4277d90>: 0.0,
#  <Reaction ETAPCPSII at 0x2b425d210>: 0.0,
#  <Reaction STCHLPSIum at 0x2b4235ed0>: 0.0,
#  <Reaction DEXZEAX at 0x2b4276d10>: 0.0,
#  <Reaction PFOR at 0x2b4282e10>: 31790.0,
#  <Reaction ACMAMT at 0x2b4283250>: 4450.0,
#  <Reaction ICLIPAabcpp at 0x2b4277cd0>: 12423.0,
#  <Reaction ICLIPAS at 0x2b4288490>: 1180.0,
#  <Reaction MOAT_1 at 0x2b4288450>: 1028.0,
#  <Reaction MPTG at 0x2b421b510>: 3396.0,
#  <Reaction MPTG2 at 0x2b425d250>: 3396.0,
#  <Reaction UAGPT3 at 0x2b428ae10>: 1332.0,
#  <Reaction GLYCOX1 at 0x2b4233290>: 12373.0,
#  <Reaction UM4PL at 0x2b4290a90>: 11920.0,
#  <Reaction UM3PL at 0x2b42917d0>: 11920.0,
#  <Reaction PAPPT3 at 0x2b4292b10>: 8998.0,
#  <Reaction OANTIabcpp at 0x2b4293350>: 2412.0,
#  <Reaction OANTILpp at 0x2b42a4390>: 2412.0,
#  <Reaction MDDCP1pp at 0x2b42a4450>: 14074.0,
#  <Reaction MDDCP2pp at 0x2b424d790>: 14074.0,
#  <Reaction STACPSI at 0x2b42a6fd0>: 25989.0,
#  <Reaction UDCPDP at 0x2b424e650>: 2464.0,
#  <Reaction MLTGY1pp at 0x2b428b550>: 2672.0,
#  <Reaction ETCPC at 0x2b420db10>: 716.0,
#  <Reaction GLYCOX2 at 0x2b42ae290>: 12373.0,
#  <Reaction NO2tabcpp at 0x2b42ace50>: 812.0,
#  <Reaction MLTGY2pp at 0x2b42af7d0>: 2672.0,
#  <Reaction MLTGY3pp at 0x2b42a44d0>: 2672.0,
#  <Reaction MLTGY4pp at 0x2b42a7b90>: 2672.0,
#  <Reaction AGM4PA at 0x2b41eda90>: 4840.0,
#  <Reaction FALGTHLs at 0x2b42b7850>: 0.0,
#  <Reaction CLtex at 0x2b42b7dd0>: 0.0,
#  <Reaction EX_cl_e at 0x2b42c4fd0>: 0.0,
#  <Reaction AM3PA at 0x2b42cc690>: 4840.0,
#  <Reaction AM4PA at 0x2b42ceb50>: 4840.0,
#  <Reaction SK_fum_c at 0x2b42c45d0>: 0.0,
#  <Reaction MALCOAMT at 0x2b42b7e10>: 400.0,
#  <Reaction DM_succ_c at 0x2b42d0050>: 0.0,
#  <Reaction AGM3PApp at 0x2b42a7f90>: 3974.0,
#  <Reaction AGM4PApp at 0x2b42d1110>: 3974.0,
#  <Reaction UM4PCP at 0x2b41aad10>: 3352.0,
#  <Reaction SK_akg_c at 0x2b42d2090>: 0.0,
#  <Reaction MDRPD at 0x2b42d2050>: 1230.0,
#  <Reaction NGAM_D1um at 0x2b425f190>: 0.0,
#  <Reaction PSICRum at 0x2b42b7ed0>: 0.0,
#  <Reaction AM4PCP at 0x2b42dcb10>: 3352.0,
#  <Reaction 4PCP at 0x2b42de850>: 3352.0,
#  <Reaction AGM4PCP at 0x2b42a72d0>: 3352.0,
#  <Reaction AGMH at 0x2b41ea290>: 3618.0,
#  <Reaction PSIICRum at 0x2b42a73d0>: 0.0,
#  <Reaction DM_ac_c at 0x2b4250350>: 0.0,
#  <Reaction AGM3PH at 0x2b42e52d0>: 3618.0,
#  <Reaction DM_lac__D_c at 0x2b4290190>: 0.0,
#  <Reaction ENOPH at 0x2b42900d0>: 2155.0,
#  <Reaction NGAM at 0x2b42e6710>: 0.0,
#  <Reaction QULNS at 0x2b42c4690>: 15911.0,
#  <Reaction AGM4PH at 0x2b42fc050>: 3618.0,
#  <Reaction LADGMDH at 0x2b42fc090>: 3466.0,
#  <Reaction ILETA at 0x2b42cf7d0>: 8845.0,
#  <Reaction ALAGLUE at 0x2b42fdb50>: 828.0,
#  <Reaction CELLSYN at 0x2b42fe790>: 9874.0,
#  <Reaction ALAALAabcpp at 0x2b42ff290>: 2750.0,
#  <Reaction LEUTA at 0x2b4308250>: 8845.0,
#  <Reaction ARD at 0x2b430b650>: 9319.0,
#  <Reaction VALTA at 0x2b4192610>: 8845.0,
#  <Reaction NDPK3 at 0x2b430b5d0>: 15072.0,
#  <Reaction NDPK6 at 0x2b42b78d0>: 15072.0,
#  <Reaction NDPK1 at 0x2b4316610>: 15072.0,
#  <Reaction 4PEPTabcpp at 0x2b4317850>: 2750.0,
#  <Reaction ALAALAD at 0x2b43186d0>: 3224.0,
#  <Reaction ADPGLC at 0x2b42b4dd0>: 3879.0,
#  <Reaction NDPK8 at 0x2b431a2d0>: 15072.0,
#  <Reaction UNK3 at 0x2b431b4d0>: 3996.0,
#  <Reaction NDPK5 at 0x2b42b6dd0>: 15072.0,
#  <Reaction DALAabcpp at 0x2b4329ad0>: 2750.0,
#  <Reaction NDPK4 at 0x2b432a850>: 15072.0,
#  <Reaction ZISO at 0x2b432db50>: 1832.0,
#  <Reaction NDPK2 at 0x2b431bd10>: 15072.0,
#  <Reaction 3OAR180 at 0x2b4309dd0>: 1828.0,
#  <Reaction 3OAR140 at 0x2b42fc210>: 1828.0,
#  <Reaction PAPA160 at 0x2b432f850>: 1492.0,
#  <Reaction PHEOASE at 0x2a62155d0>: 6449.0,
#  <Reaction PAPA_HDE_PALM at 0x2a68351d0>: 1492.0,
#  <Reaction PAPA161 at 0x2a6857f10>: 1492.0,
#  <Reaction PAPA_OLE_HDE at 0x2b42fc250>: 1492.0,
#  <Reaction ACGK at 0x2b42890d0>: 10530.0,
#  <Reaction MCTP2App at 0x2b42b6d90>: 36293.0,
#  <Reaction MCTP1App at 0x2b433a950>: 36293.0,
#  <Reaction MCTP1Bpp at 0x2b42a5ed0>: 36293.0,
#  <Reaction LEUabcpp at 0x2b432e450>: 556.0,
#  <Reaction ACLSa at 0x2b432e5d0>: 10752.0,
#  <Reaction SULabcpp at 0x2b4274750>: 1845.0,
#  <Reaction PAPA_OLE_PALM at 0x2b42e6910>: 1492.0,
#  <Reaction TYRTA at 0x2b433b510>: 4668.0,
#  <Reaction ACLSb at 0x2b432e590>: 10752.0,
#  <Reaction PHEOX_1 at 0x2b435a510>: 1942.0,
#  <Reaction OPMEACPS at 0x2b4328ad0>: 31799.0,
#  <Reaction EAR100y at 0x2b4200bd0>: 3064.0,
#  <Reaction EHGLAT at 0x2b4361f10>: 4668.0,
#  <Reaction KAS15 at 0x2b42e6850>: 4716.0,
#  <Reaction FALDH2 at 0x2b4363710>: 4403.0,
#  <Reaction PHYTK at 0x2b42dfbd0>: 2336.0,
#  <Reaction NDH_1_4_um_copy2 at 0x2b4370d90>: 1732.0,
#  <Reaction KARI_1 at 0x2b4371ed0>: 15033.0,
#  <Reaction 3HAD120 at 0x2b4379a10>: 1476.0,
#  <Reaction OGMEACPD at 0x2b42fdc50>: 1476.0,
#  <Reaction ACCOAC at 0x2b43796d0>: 4304.0,
#  <Reaction ASPO5 at 0x2b4308c50>: 2576.0,
#  <Reaction PTHPS at 0x2b4382b90>: 21412.0,
#  <Reaction CITCIa at 0x2b4380710>: 5953.0,
#  <Reaction DAGK_OLE_HDE at 0x2b4382b10>: 6601.0,
#  <Reaction DAGK_OLE_PALM at 0x2b432e290>: 6601.0,
#  <Reaction 3HAD100 at 0x2b432e3d0>: 1476.0,
#  <Reaction PNTK at 0x2b438d490>: 514.0,
#  <Reaction 3OAR120 at 0x2b42e5390>: 1828.0,
#  <Reaction 3OAR60 at 0x2b4250410>: 1828.0,
#  <Reaction 3OAR100 at 0x2b438f850>: 1828.0,
#  <Reaction 3OAR80 at 0x2b4394f50>: 1828.0,
#  <Reaction ALCD1 at 0x2b4395a50>: 22042.0,
#  <Reaction NDH_1_1_um_copy1 at 0x2b4396750>: 1732.0,
#  <Reaction NDH_1_4_um_copy1 at 0x2b42e5450>: 1317.0,
#  <Reaction PCHLDA430 at 0x2b4397590>: 10733.0,
#  <Reaction SFGTHi at 0x2b4378490>: 3584.0,
#  <Reaction PCHLDA650 at 0x2b439de50>: 10733.0,
#  <Reaction GGCLUT2 at 0x2b430bed0>: 542.0,
#  <Reaction SPR at 0x2b43aac50>: 1180.0,
#  <Reaction OPAH at 0x2b435a890>: 4198.0,
#  <Reaction ACGAMK at 0x2b4395a90>: 1124.0,
#  <Reaction AMANAPEr at 0x2b4382c10>: 4477.0,
#  <Reaction AGDC at 0x2b43ba090>: 5216.0,
#  <Reaction ANHMK at 0x2b43bbb10>: 1810.0,
#  <Reaction RNDR4 at 0x2b43aad50>: 17817.0,
#  <Reaction TRPS2 at 0x2b438f950>: 3584.0,
#  <Reaction PSICSum at 0x2b4309e50>: 4361.0,
#  <Reaction NAD_H2 at 0x2b43a9090>: 1426.0,
#  <Reaction PPND at 0x2b43d2050>: 2448.0,
#  <Reaction CBFCum at 0x2b43a9c50>: 158.0,
#  <Reaction ACM6PH at 0x2b43a9010>: 2578.0,
#  <Reaction SUCR at 0x2b435b250>: 3114.0,
#  <Reaction CLt3_1pp at 0x2b4362050>: 2936.0,
#  <Reaction Ktu at 0x2b43ba0d0>: 704.0,
#  <Reaction THBTGT at 0x2b42ff2d0>: 3567.0,
#  <Reaction FDH6 at 0x2b43dd250>: 8849.0,
#  <Reaction PCXHtpp at 0x2b439f4d0>: 9199.0,
#  <Reaction THISAT at 0x2b43d2290>: 1052.0,
#  <Reaction PSIIum at 0x2b430a310>: 1172.0,
#  <Reaction ATPSum at 0x2b43a9150>: 6335.0,
#  <Reaction CYSDES at 0x2b43ead50>: 20966.0,
#  <Reaction NO3abcpp at 0x2b4397490>: 10245.0,
#  <Reaction GLNabcpp at 0x2b43d1550>: 1602.0,
#  <Reaction GLNS at 0x2b4363850>: 117646.0,
#  <Reaction MDDEP1pp at 0x2b43b8c10>: 30503.0,
#  <Reaction THII at 0x2b43bbb90>: 1052.0,
#  <Reaction SHS1 at 0x2b43f54d0>: 2566.0,
#  <Reaction PSIICSum at 0x2b43bbc10>: 1172.0,
#  <Reaction NDH_1_1_um_copy2 at 0x2b4406910>: 1732.0,
#  <Reaction ASNS1 at 0x2b43f7450>: 4335.0,
#  <Reaction MDDCP3pp at 0x2b440f6d0>: 14074.0,
#  <Reaction MDDCP4pp at 0x2b43eb190>: 14074.0,
#  <Reaction MDDCP5pp at 0x2b43e9110>: 14074.0,
#  <Reaction MDDEP2pp at 0x2b442b090>: 30503.0,
#  <Reaction MDDEP3pp at 0x2b441cd50>: 30503.0,
#  <Reaction MDDEP4pp at 0x2b4428390>: 30503.0,
#  <Reaction MNHNAtpp at 0x2b43eb390>: 272.0,
#  <Reaction EX_sucr_e at 0x2b438f890>: 0.0,
#  <Reaction SUCRt2 at 0x2b44327d0>: inf}

# %% [markdown]
#  ### 3. For each condition, normalize enzyme data with respect to the reference strain

# %% [markdown]
# ### 4. For each condition, multiply the reference bounds by the normalized enzyme data.

# %% [markdown]
# ### 5. Run FBA using the condition-specific bounds to compute the condition-specific fluxes
