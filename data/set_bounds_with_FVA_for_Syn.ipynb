# %% [markdown]
# ## This notebook handles the pre-processing needed to modify thereaction bounds in a cobra model to facilitate running Eflux2

# %%
import sys
sys.path.append('../src')
sys.path.append('/Users/mahs128/Repos/CONCERTO')
from concerto.helpers.load_model_from_git import load_model_from_git
from eflux2 import EFlux2
import cobra
import pandas as pd
import numpy as np
import gurobipy

# %% [markdown]
# ### 1. Run flux variability analysis on the reference strain to get (reasonably) tight bounds on the fluxes.

# %%
# Load SBML model
syn_model = cobra.io.read_sbml_model('../models/iJB785_w_sucrose_transport.xml')
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"

# %%
print(syn_model.objective)
# Out:
# Maximize
# 1.0*BIOMASS__1 - 1.0*BIOMASS__1_reverse_063c7

# %%
# Incorporate reference strain information into the model

# Get metabolic rates
rates_fname = "processed_data/cleaned_metabolomic_abundance_rates.csv"
rates_df = pd.read_csv(rates_fname, index_col="Sample")

# Get transcriptomics
transcriptomics_fname = "processed_data/cleaned_transcriptomics.csv"
transcriptomics_df = pd.read_csv(transcriptomics_fname, index_col="Label")

# Define reference strain
ref_rep = transcriptomics_df.columns[4] # 'Se_axen_d6_2'
ref_rep
# Out:
# 'Se_axen_d6_2'

# %%
# Run optimization on cobra model to get fluxes for reactions of interest
# sucrose production ('EX_sucr_e') and CO2 uptake ('EX_co2_e') and biomass ('BIOMASS__1')
opt_df = syn_model.optimize().to_frame()
display(opt_df)
display(opt_df.loc['EX_sucr_e'])
display(opt_df.loc['EX_co2_e'])
display(opt_df.loc['BIOMASS__1'])
# Out:
#               fluxes  reduced_costs
# EX_gln__L_e  0.00000   0.000000e+00
# EX_hco3_e   -1.99000   0.000000e+00
# EX_mn2_e     0.00000   0.000000e+00
# EX_arg__L_e  0.00000   0.000000e+00
# ADPT         0.00001  -3.108624e-14
# ...              ...            ...
# MDDEP3pp     0.00000   0.000000e+00
# MDDEP4pp     0.00000   0.000000e+00
# MNHNAtpp     0.00000   0.000000e+00
# EX_sucr_e    0.01100   0.000000e+00
# SUCRt2      -0.01100   0.000000e+00
#
# [851 rows x 2 columns]
# fluxes           0.011
# reduced_costs    0.000
# Name: EX_sucr_e, dtype: float64
# fluxes          -0.316958
# reduced_costs    0.000000
# Name: EX_co2_e, dtype: float64
# fluxes           5.390187e-02
# reduced_costs   -8.526513e-14
# Name: BIOMASS__1, dtype: float64

# %%
# Specify upper/lower bounds of model for excluded reactions
for rxn in ['EX_sucr_e', 'EX_co2_e', 'BIOMASS__1']:
   syn_model.reactions.get_by_id(rxn).lower_bound = opt_df.loc[rxn, 'fluxes']

   print(rxn, ": ", syn_model.reactions.get_by_id(rxn).lower_bound, ";  ", syn_model.reactions.get_by_id(rxn).upper_bound)
# Out:
# EX_sucr_e :  0.011 ;   1000.0
# EX_co2_e :  -0.3169581181768563 ;   1000.0
# BIOMASS__1 :  0.05390186774577897 ;   2.0

# %%
# Create reactions list exclude reactions of interest: sucrose production ('EX_sucr_e') and CO2 uptake ('EX_co2_e') and biomass ('BIOMASS__1') 
rxn_list = [r.id for r in syn_model.reactions if (r.id not in ['EX_sucr_e', 'EX_co2_e', 'BIOMASS__1'])]

# %%
# Compared optimized fluxes to calculated rates of observed metabolic abundances
rates_df.loc['sucr'][ref_rep]
# Out:
# 1327111.5

# %%
# Run FVA (~30-40 seconds)
FVA_object = cobra.flux_analysis.flux_variability_analysis(model=syn_model, reaction_list=rxn_list, 
                                                           fraction_of_optimum=0.85, processes=8)
# Out:
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpctk6kr8w.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpab5y08um.lp
# Reading time = 0.01 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpvhar3_rq.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpk8vd2p_0.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp12zbxi4u.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp9dlxjr51.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmphhh1ch26.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp55rdos6b.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp1yjdwv_3.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmprft4ommw.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp0prgjain.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp0i6vwtum.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmp_th61qao.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpdqa8ab03.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpgb2qyua5.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros
# Set parameter TokenServer to value "leghorn.emsl.pnl.gov"
# Read LP format model from file /var/folders/k9/b8pxky2572sdtgy2vnxhcljw0000gn/T/tmpqe5qw1qx.lp
# Reading time = 0.00 seconds
# : 770 rows, 1703 columns, 7655 nonzeros

# %%
FVA_object
# Out:
#              minimum     maximum
# EX_gln__L_e  0.00000    0.000000
# EX_hco3_e   -1.99000   -1.989283
# EX_mn2_e     0.00000    0.000000
# EX_arg__L_e  0.00000    0.000000
# ADPT         0.00001    0.000010
# ...              ...         ...
# MDDEP2pp     0.00000    0.000000
# MDDEP3pp     0.00000   71.169417
# MDDEP4pp     0.00000   47.446278
# MNHNAtpp     0.00000  388.340298
# SUCRt2      -0.01106   -0.011000
#
# [848 rows x 2 columns]

# %% [markdown]
#  ### 2. Next, convert the transcriptomics data to enzyme data (Take the min of subunits, take the sum of isozymes)

# %%
# Load transciptomics data
transcriptomics_fname = "processed_data/cleaned_transcriptomics.csv"
transcriptomics_df = pd.read_csv(transcriptomics_fname, index_col="Label")
transcriptomics_df.head()
# Out:
#                     Se_axen_d4_1  Se_axen_d4_2  Se_axen_d4_3  Se_axen_d6_1  \
# Label
# SYNPCC7942_RS00005         16290         17761         15101         14567
# SYNPCC7942_RS00010          7185          7502          6565         10086
# SYNPCC7942_RS00015         24176         26304         22781         23926
# SYNPCC7942_RS00020         35119         35145         25895         37701
# SYNPCC7942_RS00025          6891          7803          6607          6347
#
#                     Se_axen_d6_2  Se_axen_d6_3  Se_axen_d8_1  Se_axen_d8_2  \
# Label
# SYNPCC7942_RS00005         13967         12653          7016          8855
# SYNPCC7942_RS00010          7546          7705          3747          6670
# SYNPCC7942_RS00015         21306         20412         13440         17253
# SYNPCC7942_RS00020         34175         30569         24835         39769
# SYNPCC7942_RS00025          6284          6844          3326          4146
#
#                     Se_axen_d8_3
# Label
# SYNPCC7942_RS00005          8689
# SYNPCC7942_RS00010          6960
# SYNPCC7942_RS00015         17053
# SYNPCC7942_RS00020         30280
# SYNPCC7942_RS00025          3180

# %%
# Set reference strain
ref_rep = transcriptomics_df.columns[4] # 'Se_axen_d6_2'
ref_rep
# Out:
# 'Se_axen_d6_2'

# %%
# Snippet of code borrowed from eflux2.py to populate the first inpur argument of the gene_expression_to_enzyme_activity() function

# TODO: make this into a function

def get_gpr_dict(model):
    """ Returns the gene reaction rule (GPR) for each reaction in the model."""
    # Parse GPR into a dict containing isozymes (separated by 'or')
    # Each isozyme has a set of subunits (separated by 'and')
    gpr_dict = dict()
    for r in model.reactions:
        if r.gene_reaction_rule:
            isozymes = set()
            for isozyme in [isozyme.strip('() ') for isozyme in r.gene_reaction_rule.split(' or ')]:
                isozymes.add(frozenset(gene.strip('() ') for gene in isozyme.split(' and ')))
            gpr_dict[r] = isozymes
    
    return gpr_dict

gpr_dict = get_gpr_dict(syn_model)
display(gpr_dict)
# Out:
# {<Reaction ADPT at 0x2bdd9a690>: {frozenset({'Synpcc7942_2454'})},
#  <Reaction DTMPK at 0x2bdda3990>: {frozenset({'SYNPCC7942_RS00470'})},
#  <Reaction ORNTA at 0x2bdc6d0d0>: {frozenset({'Synpcc7942_0034'})},
#  <Reaction ACOATA at 0x2bddae250>: {frozenset({'SYNPCC7942_RS07445'})},
#  <Reaction 3HAD160 at 0x2bddae210>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction RNDR3 at 0x2bddb5710>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction G5SD at 0x2bddb7250>: {frozenset({'SYNPCC7942_RS11385'}),
#   frozenset({'SYNPCC7942_RS11510'})},
#  <Reaction HISTDa at 0x2bddc4410>: {frozenset({'SYNPCC7942_RS07765'})},
#  <Reaction TRPS3 at 0x2bddc6cd0>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction DMBZIDS2 at 0x2bddc6c90>: {frozenset({'SYNPCC7942_RS10185'}),
#   frozenset({'SYNPCC7942_RS08460'})},
#  <Reaction HSTPT at 0x2bddc6c50>: {frozenset({'SYNPCC7942_RS05290'})},
#  <Reaction ZCAROTDH2 at 0x2bddae390>: {frozenset({'SYNPCC7942_RS06385',
#              'SYNPCC7942_RS07730'})},
#  <Reaction ORNDC at 0x2bddc8b10>: {frozenset({'SYNPCC7942_RS03625'})},
#  <Reaction GND at 0x2bddca610>: {frozenset({'SYNPCC7942_RS00195'})},
#  <Reaction CMPA_1 at 0x2bddcb8d0>: {frozenset({'SYNPCC7942_RS10895'})},
#  <Reaction U23GAAT2 at 0x2bdddca50>: {frozenset({'SYNPCC7942_RS07415'})},
#  <Reaction HOXGfx at 0x2bddde3d0>: {frozenset({'SYNPCC7942_RS09425'})},
#  <Reaction PGK at 0x2bdddf9d0>: {frozenset({'SYNPCC7942_RS05720'})},
#  <Reaction IMPD at 0x2bdde8c90>: {frozenset({'SYNPCC7942_RS09290'})},
#  <Reaction LPOR at 0x2bdc6ec90>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction CHRPL at 0x2bddeac90>: {frozenset({'SYNPCC7942_RS00460'})},
#  <Reaction GCALDDy at 0x2bddf0450>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction MSBENZMT at 0x2bddf1e10>: {frozenset({'SYNPCC7942_RS03055'})},
#  <Reaction DESAT18a at 0x2bddf2a10>: {frozenset({'SYNPCC7942_RS13015'})},
#  <Reaction FUM at 0x2bddf3790>: {frozenset({'SYNPCC7942_RS05170'})},
#  <Reaction PHYFXOR at 0x2bddf04d0>: {frozenset({'SYNPCC7942_RS06275'})},
#  <Reaction TMPPP_1 at 0x2bddca690>: {frozenset({'SYNPCC7942_RS05420'})},
#  <Reaction VPAMTr at 0x2bddf6550>: {frozenset({'SYNPCC7942_RS11475'})},
#  <Reaction RNDR1 at 0x2bddf7c50>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction TALA at 0x2bde04710>: {frozenset({'SYNPCC7942_RS11675'})},
#  <Reaction GLYCL at 0x2bde05550>: {frozenset({'SYNPCC7942_RS10380',
#              'SYNPCC7942_RS10385',
#              'SYNPCC7942_RS11730'})},
#  <Reaction ACONT at 0x2bde066d0>: {frozenset({'SYNPCC7942_RS04655'})},
#  <Reaction NDPK7 at 0x2bddcb9d0>: {frozenset({'SYNPCC7942_RS12670'})},
#  <Reaction GTPCI at 0x2bddcb910>: {frozenset({'SYNPCC7942_RS08155'})},
#  <Reaction AIRC2 at 0x2bde0da50>: {frozenset({'SYNPCC7942_RS07305'})},
#  <Reaction IGPS at 0x2bde0ea10>: {frozenset({'SYNPCC7942_RS06130'})},
#  <Reaction MTAP at 0x2bddf4910>: {frozenset({'SYNPCC7942_RS04750'})},
#  <Reaction HEMEAS_1 at 0x2bde1d1d0>: {frozenset({'SYNPCC7942_RS13250'})},
#  <Reaction DHORD3um at 0x2bde1e750>: {frozenset({'SYNPCC7942_RS01475'})},
#  <Reaction MTHFC at 0x2bde1f790>: {frozenset({'SYNPCC7942_RS04030'})},
#  <Reaction HBZNPT at 0x2bde28bd0>: {frozenset({'SYNPCC7942_RS09965'})},
#  <Reaction GCATENEC at 0x2bde2a290>: {frozenset({'SYNPCC7942_RS10460'})},
#  <Reaction COCHL_1 at 0x2bde28cd0>: {frozenset({'SYNPCC7942_RS00495',
#              'SYNPCC7942_RS04275'})},
#  <Reaction HSDy at 0x2bde30150>: {frozenset({'SYNPCC7942_RS10595'})},
#  <Reaction TRPS1 at 0x2bddc8cd0>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction HISTDb at 0x2bde30c50>: {frozenset({'SYNPCC7942_RS07765'})},
#  <Reaction UPPDC1 at 0x2bde32b10>: {frozenset({'SYNPCC7942_RS05575'})},
#  <Reaction GARFT at 0x2bde33d90>: {frozenset({'SYNPCC7942_RS04925'})},
#  <Reaction H4THDPR at 0x2bde3d090>: {frozenset({'SYNPCC7942_RS10835'})},
#  <Reaction UDPG4E at 0x2bdc6cd50>: {frozenset({'SYNPCC7942_RS01630'})},
#  <Reaction GLCS3 at 0x2bde3f650>: {frozenset({'SYNPCC7942_RS12785'})},
#  <Reaction AICART at 0x2bde48610>: {frozenset({'SYNPCC7942_RS02020'})},
#  <Reaction ASPTA at 0x2bde49510>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction GLYOX at 0x2bde4a590>: {frozenset({'SYNPCC7942_RS04820'}),
#   frozenset({'SYNPCC7942_RS07180'})},
#  <Reaction PRAGSr at 0x2bde4b1d0>: {frozenset({'SYNPCC7942_RS04760'})},
#  <Reaction SQD1 at 0x2bde4b310>: {frozenset({'SYNPCC7942_RS02940'})},
#  <Reaction ACKr at 0x2bddc9110>: {frozenset({'SYNPCC7942_RS10540'})},
#  <Reaction UDCPDPS at 0x2bde57c90>: {frozenset({'SYNPCC7942_RS01345'})},
#  <Reaction GK1 at 0x2bddf0590>: {frozenset({'SYNPCC7942_RS06100'})},
#  <Reaction SHKK at 0x2bddca990>: {frozenset({'SYNPCC7942_RS04605'})},
#  <Reaction OXADC at 0x2bde5b410>: {frozenset({'SYNPCC7942_RS12135'})},
#  <Reaction G1PACT at 0x2bde31690>: {frozenset({'SYNPCC7942_RS01465'})},
#  <Reaction 3HAD60 at 0x2bde65050>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction PGI at 0x2bde66110>: {frozenset({'SYNPCC7942_RS10295'})},
#  <Reaction KAS14 at 0x2bde05590>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction OHPBAT at 0x2bde495d0>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction 3HAD80 at 0x2bde7b950>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction 3OAR160 at 0x2bde7d390>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction NMNS at 0x2bde763d0>: {frozenset({'SYNPCC7942_RS01045'})},
#  <Reaction PPK at 0x2bddf4990>: {frozenset({'SYNPCC7942_RS08000'})},
#  <Reaction GALUi at 0x2bde7dfd0>: {frozenset({'SYNPCC7942_RS10005'})},
#  <Reaction PHYTES2_1 at 0x2bde7eed0>: {frozenset({'SYNPCC7942_RS10060'})},
#  <Reaction IGPDH at 0x2bde0db90>: {frozenset({'SYNPCC7942_RS00635'})},
#  <Reaction OMPDC at 0x2bde84bd0>: {frozenset({'SYNPCC7942_RS13055'})},
#  <Reaction DCTPD at 0x2bde86390>: {frozenset({'SYNPCC7942_RS03695'})},
#  <Reaction GLUSfx at 0x2bde86bd0>: {frozenset({'SYNPCC7942_RS04585'})},
#  <Reaction NADS2 at 0x2bde879d0>: {frozenset({'SYNPCC7942_RS00535'})},
#  <Reaction GLUTRR at 0x2bde94e10>: {frozenset({'SYNPCC7942_RS02560'})},
#  <Reaction G1PTT at 0x2bde96150>: {frozenset({'SYNPCC7942_RS10650'})},
#  <Reaction UAMAGS at 0x2bde97150>: {frozenset({'SYNPCC7942_RS08500'})},
#  <Reaction SPS at 0x2bdea1210>: {frozenset({'SYNPCC7942_RS04180'})},
#  <Reaction ADCL at 0x2bdea2150>: {frozenset({'SYNPCC7942_RS06825'})},
#  <Reaction CYTK1 at 0x2bdea3210>: {frozenset({'SYNPCC7942_RS05900'})},
#  <Reaction DAPDC at 0x2bdea8950>: {frozenset({'SYNPCC7942_RS01335'})},
#  <Reaction PSIum at 0x2bdea9850>: {frozenset({'SYNPCC7942_RS02075',
#              'SYNPCC7942_RS02720',
#              'SYNPCC7942_RS03350',
#              'SYNPCC7942_RS04735',
#              'SYNPCC7942_RS05140',
#              'SYNPCC7942_RS06400',
#              'SYNPCC7942_RS06405',
#              'SYNPCC7942_RS06760',
#              'SYNPCC7942_RS09705',
#              'SYNPCC7942_RS10390',
#              'SYNPCC7942_RS10395',
#              'SYNPCC7942_RS11800',
#              'SYNPCC7942_RS11900',
#              'SYNPCC7942_RS11905',
#              'SYNPCC7942_RS12755'})},
#  <Reaction R05219 at 0x2bde593d0>: {frozenset({'SYNPCC7942_RS00965'})},
#  <Reaction Cobalt2abcppI at 0x2bde66290>: {frozenset({'SYNPCC7942_RS02850',
#              'SYNPCC7942_RS08360',
#              'SYNPCC7942_RS11895'})},
#  <Reaction PFK_3 at 0x2bdea12d0>: {frozenset({'SYNPCC7942_RS03035'})},
#  <Reaction THRS at 0x2bdebd3d0>: {frozenset({'SYNPCC7942_RS09055'}),
#   frozenset({'SYNPCC7942_RS13305'})},
#  <Reaction NAMNPP at 0x2bdea2210>: {frozenset({'SYNPCC7942_RS01045'})},
#  <Reaction FOLD3 at 0x2bdea2290>: {frozenset({'SYNPCC7942_RS11705'})},
#  <Reaction P5CR at 0x2bdeca190>: {frozenset({'SYNPCC7942_RS10440'})},
#  <Reaction MEHLER_1 at 0x2bdecb1d0>: {frozenset({'SYNPCC7942_RS09190',
#              'SYNPCC7942_RS09195'})},
#  <Reaction ICHORS at 0x2bded0f50>: {frozenset({'SYNPCC7942_RS11120'})},
#  <Reaction 3OAS140 at 0x2bdebc5d0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction PPK2 at 0x2bded2fd0>: {frozenset({'SYNPCC7942_RS08000'})},
#  <Reaction IPDPS_syn at 0x2bded3d90>: {frozenset({'SYNPCC7942_RS00360'})},
#  <Reaction GLYDHDA at 0x2bde568d0>: {frozenset({'SYNPCC7942_RS08945'})},
#  <Reaction SBP at 0x2bde06850>: {frozenset({'SYNPCC7942_RS02565'})},
#  <Reaction H4THDPS at 0x2bdee2350>: {frozenset({'SYNPCC7942_RS09370'})},
#  <Reaction EAR60y at 0x2bdee3350>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction ZNabcpp at 0x2bde047d0>: {frozenset({'SYNPCC7942_RS13075',
#              'SYNPCC7942_RS13080',
#              'SYNPCC7942_RS13085'}),
#   frozenset({'SYNPCC7942_RS06730',
#              'SYNPCC7942_RS06735',
#              'SYNPCC7942_RS06740'})},
#  <Reaction UAPGR at 0x2bde1f850>: {frozenset({'SYNPCC7942_RS08855'})},
#  <Reaction DHAD1 at 0x2bdef47d0>: {frozenset({'SYNPCC7942_RS03210'})},
#  <Reaction IPPS at 0x2bdebd990>: {frozenset({'SYNPCC7942_RS02185'})},
#  <Reaction ANS at 0x2bde86c90>: {frozenset({'SYNPCC7942_RS02040',
#              'SYNPCC7942_RS05145'})},
#  <Reaction SUCBZL at 0x2bdef68d0>: {frozenset({'SYNPCC7942_RS05250'})},
#  <Reaction ADSL1r at 0x2bdef71d0>: {frozenset({'SYNPCC7942_RS01605'})},
#  <Reaction NNATr at 0x2bddc6f10>: {frozenset({'SYNPCC7942_RS00540'}),
#   frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction PERD at 0x2bdebfc90>: {frozenset({'SYNPCC7942_RS08150'})},
#  <Reaction PPBNGS at 0x2bdf02e90>: {frozenset({'SYNPCC7942_RS09105'})},
#  <Reaction ADOCBLS at 0x2bde1d210>: {frozenset({'SYNPCC7942_RS02320'})},
#  <Reaction LTHRK at 0x2bdf09a90>: {frozenset({'SYNPCC7942_RS05695'}),
#   frozenset({'SYNPCC7942_RS04045'}),
#   frozenset({'SYNPCC7942_RS05745'}),
#   frozenset({'SYNPCC7942_RS03080'}),
#   frozenset({'SYNPCC7942_RS06620'})},
#  <Reaction PPS at 0x2bdf0add0>: {frozenset({'SYNPCC7942_RS04050'})},
#  <Reaction PDS2_1 at 0x2bdf10bd0>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction ALAALAr at 0x2bdef57d0>: {frozenset({'SYNPCC7942_RS12070'})},
#  <Reaction ADCPS2 at 0x2bdddd050>: {frozenset({'SYNPCC7942_RS07370'})},
#  <Reaction GF6PTA at 0x2bde3f6d0>: {frozenset({'SYNPCC7942_RS02715'})},
#  <Reaction PGMT at 0x2bde076d0>: {frozenset({'SYNPCC7942_RS00790'})},
#  <Reaction GLCP2_1 at 0x2bddf5490>: {frozenset({'SYNPCC7942_RS01245'})},
#  <Reaction AGDI_1 at 0x2bde4a5d0>: {frozenset({'SYNPCC7942_RS12205'})},
#  <Reaction LPADSS2 at 0x2bdef5750>: {frozenset({'SYNPCC7942_RS04795'})},
#  <Reaction GLYCK at 0x2bdf2fa90>: {frozenset({'SYNPCC7942_RS05115'})},
#  <Reaction DPR at 0x2bdf2fa50>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction EAR120y at 0x2bdf22790>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction MAN1PT at 0x2bdf37550>: {frozenset({'SYNPCC7942_RS08205'})},
#  <Reaction NMNAT at 0x2bdf364d0>: {frozenset({'SYNPCC7942_RS00540'}),
#   frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction TKT2 at 0x2bdf44750>: {frozenset({'SYNPCC7942_RS02735'})},
#  <Reaction PSP_L at 0x2bdf46dd0>: {frozenset({'SYNPCC7942_RS02470'})},
#  <Reaction HEX7 at 0x2bdf458d0>: {frozenset({'SYNPCC7942_RS00585'})},
#  <Reaction PPNCL2 at 0x2bdf46d50>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction CHORS at 0x2bdf47f90>: {frozenset({'SYNPCC7942_RS01075'})},
#  <Reaction CYTBD4cm at 0x2bdf49710>: {frozenset({'SYNPCC7942_RS08975',
#              'SYNPCC7942_RS08980'})},
#  <Reaction PPNCL3 at 0x2bdf23b90>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction CS at 0x2bdf4bb10>: {frozenset({'SYNPCC7942_RS03140'})},
#  <Reaction PPCDC at 0x2bdf4bc90>: {frozenset({'SYNPCC7942_RS01490'})},
#  <Reaction LDH_D at 0x2bdf51650>: {frozenset({'SYNPCC7942_RS06885'})},
#  <Reaction HPYRRy at 0x2bdf53310>: {frozenset({'SYNPCC7942_RS09420'})},
#  <Reaction ADMDC at 0x2bdef4bd0>: {frozenset({'SYNPCC7942_RS10365'}),
#   frozenset({'SYNPCC7942_RS11425'})},
#  <Reaction PRE3BS at 0x2bdf59f90>: {frozenset({'SYNPCC7942_RS09390'})},
#  <Reaction PPPGO2_1 at 0x2bdf5b090>: {frozenset({'SYNPCC7942_RS04385'})},
#  <Reaction BIOMASS_DNA at 0x2bdf03f90>: {frozenset({'SYNPCC7942_RS00005',
#              'SYNPCC7942_RS00475',
#              'SYNPCC7942_RS00985',
#              'SYNPCC7942_RS02065',
#              'SYNPCC7942_RS02900',
#              'SYNPCC7942_RS04690',
#              'SYNPCC7942_RS11170'})},
#  <Reaction DMATT at 0x2bdf650d0>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction DNAMTn2r at 0x2bdf67fd0>: {frozenset({'SYNPCC7942_RS12505'})},
#  <Reaction G3PD2 at 0x2bdf66f90>: {frozenset({'SYNPCC7942_RS12805'})},
#  <Reaction PHYTES at 0x2bdf67050>: {frozenset({'SYNPCC7942_RS10060'})},
#  <Reaction MI3PP at 0x2bdf76890>: {frozenset({'SYNPCC7942_RS13150'})},
#  <Reaction MOHMT at 0x2bdf80b10>: {frozenset({'SYNPCC7942_RS12100'})},
#  <Reaction FBA at 0x2bddc4550>: {frozenset({'SYNPCC7942_RS07385'})},
#  <Reaction PROAKGOX1 at 0x2bde74290>: {frozenset({'SYNPCC7942_RS12600'})},
#  <Reaction ASAD at 0x2bdf64310>: {frozenset({'SYNPCC7942_RS09375'})},
#  <Reaction CYSS_2 at 0x2bdf64390>: {frozenset({'SYNPCC7942_RS13380'}),
#   frozenset({'SYNPCC7942_RS00870'}),
#   frozenset({'SYNPCC7942_RS07500'}),
#   frozenset({'SYNPCC7942_RS13425'})},
#  <Reaction LYCOPC at 0x2bde0f790>: {frozenset({'SYNPCC7942_RS10460'})},
#  <Reaction ACOTA at 0x2bdf37690>: {frozenset({'SYNPCC7942_RS04850'})},
#  <Reaction 3HAD180 at 0x2bdf94f90>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction FTHFD at 0x2bdf96050>: {frozenset({'SYNPCC7942_RS05175'})},
#  <Reaction ALDD2y at 0x2bdf97250>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction 3OAS80 at 0x2bdf01c10>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction PSCVT at 0x2bdf49890>: {frozenset({'SYNPCC7942_RS01180'})},
#  <Reaction CBPS at 0x2bdf9e010>: {frozenset({'SYNPCC7942_RS03645',
#              'SYNPCC7942_RS10760'})},
#  <Reaction NTPP8 at 0x2bdee1990>: {frozenset({'SYNPCC7942_RS07630'})},
#  <Reaction MEPCT at 0x2bdef59d0>: {frozenset({'SYNPCC7942_RS03490'})},
#  <Reaction PDX5POi at 0x2bdfad050>: {frozenset({'SYNPCC7942_RS00345'})},
#  <Reaction DHAD2 at 0x2bdfaf2d0>: {frozenset({'SYNPCC7942_RS03210'})},
#  <Reaction DHFS at 0x2bdf779d0>: {frozenset({'SYNPCC7942_RS04855'})},
#  <Reaction PGCD at 0x2bdfb5850>: {frozenset({'SYNPCC7942_RS07670'})},
#  <Reaction SPMDabcpp at 0x2bdf09c90>: {frozenset({'SYNPCC7942_RS11515'})},
#  <Reaction NTD6 at 0x2bdfb77d0>: {frozenset({'SYNPCC7942_RS10465'})},
#  <Reaction NNDMBRT at 0x2bdf9ced0>: {frozenset({'SYNPCC7942_RS11525'})},
#  <Reaction PRATPP at 0x2bdfbe250>: {frozenset({'SYNPCC7942_RS10115'})},
#  <Reaction ASNN at 0x2bdfbf990>: {frozenset({'SYNPCC7942_RS00840'})},
#  <Reaction SERAT at 0x2bdfc0ad0>: {frozenset({'SYNPCC7942_RS12295'}),
#   frozenset({'SYNPCC7942_RS13375'})},
#  <Reaction PRAIS at 0x2bdfc1990>: {frozenset({'SYNPCC7942_RS04395'})},
#  <Reaction PRAMPC at 0x2bdfc2a50>: {frozenset({'SYNPCC7942_RS10115'})},
#  <Reaction AMPMS3 at 0x2bdfd0250>: {frozenset({'SYNPCC7942_RS05625'})},
#  <Reaction G1PCTYT at 0x2bdf97290>: {frozenset({'SYNPCC7942_RS00310'})},
#  <Reaction ACBIPGT at 0x2bdfd2790>: {frozenset({'SYNPCC7942_RS13875'})},
#  <Reaction SEPHCHCS at 0x2bdfd3490>: {frozenset({'SYNPCC7942_RS07340'})},
#  <Reaction NMNDA at 0x2bdfaf3d0>: {frozenset({'SYNPCC7942_RS01425'})},
#  <Reaction CA2abcpp at 0x2bdfd9690>: {frozenset({'SYNPCC7942_RS05555'})},
#  <Reaction ORNTAC at 0x2bdfda550>: {frozenset({'SYNPCC7942_RS09615'})},
#  <Reaction SUCBZS at 0x2bdfdb490>: {frozenset({'SYNPCC7942_RS05245'})},
#  <Reaction UHGADA2 at 0x2bdfe44d0>: {frozenset({'SYNPCC7942_RS04780'})},
#  <Reaction DHNANT at 0x2bdfe5d10>: {frozenset({'SYNPCC7942_RS06990',
#              'SYNPCC7942_RS12725'})},
#  <Reaction ASPO6 at 0x2bdfe6c90>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction HGYDAS at 0x2bdf519d0>: {frozenset({'SYNPCC7942_RS09410'})},
#  <Reaction GGDPR at 0x2bdfe4650>: {frozenset({'SYNPCC7942_RS01965'})},
#  <Reaction ASP1DC at 0x2bdff5650>: {frozenset({'SYNPCC7942_RS11740'})},
#  <Reaction PPNDH at 0x2bdff6a50>: {frozenset({'SYNPCC7942_RS04540'})},
#  <Reaction ASPK at 0x2bdfe6dd0>: {frozenset({'SYNPCC7942_RS05135'})},
#  <Reaction DXPS at 0x2bdff8f90>: {frozenset({'SYNPCC7942_RS02195'})},
#  <Reaction ME2 at 0x2bdff9e90>: {frozenset({'SYNPCC7942_RS06635'})},
#  <Reaction DDPGA at 0x2bdffbe90>: {frozenset({'SYNPCC7942_RS00090'})},
#  <Reaction PAPSR at 0x2be001f90>: {frozenset({'SYNPCC7942_RS12715'})},
#  <Reaction SADT at 0x2be000f90>: {frozenset({'SYNPCC7942_RS01505'})},
#  <Reaction DPCOAK at 0x2be003190>: {frozenset({'SYNPCC7942_RS01390'})},
#  <Reaction NH4tpp at 0x2be00d9d0>: {frozenset({'SYNPCC7942_RS11585'}),
#   frozenset({'SYNPCC7942_RS02260'})},
#  <Reaction PC11M at 0x2bdff8fd0>: {frozenset({'SYNPCC7942_RS06300'})},
#  <Reaction DPOR at 0x2be013050>: {frozenset({'SYNPCC7942_RS07260',
#              'SYNPCC7942_RS07265',
#              'SYNPCC7942_RS09325'})},
#  <Reaction ARGSL at 0x2be011c10>: {frozenset({'SYNPCC7942_RS12575'})},
#  <Reaction HSK at 0x2bdf9e090>: {frozenset({'SYNPCC7942_RS07365'})},
#  <Reaction MTHFD at 0x2be020510>: {frozenset({'SYNPCC7942_RS04030'})},
#  <Reaction PMDPHT at 0x2be0219d0>: {frozenset({'SYNPCC7942_RS05155'})},
#  <Reaction ARGabcpp at 0x2be022d10>: {frozenset({'SYNPCC7942_RS01255',
#              'SYNPCC7942_RS01260',
#              'SYNPCC7942_RS01265',
#              'SYNPCC7942_RS01270'})},
#  <Reaction 3HAD140 at 0x2be023b50>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ARGOXRum at 0x2be033410>: {frozenset({'SYNPCC7942_RS01880'})},
#  <Reaction DAPE at 0x2be031a50>: {frozenset({'SYNPCC7942_RS09780'})},
#  <Reaction BCAROHX2 at 0x2bdf96810>: {frozenset({'SYNPCC7942_RS12395'})},
#  <Reaction HPPK at 0x2be038790>: {frozenset({'SYNPCC7942_RS11545'})},
#  <Reaction PANTS at 0x2bdf9e110>: {frozenset({'SYNPCC7942_RS05900'})},
#  <Reaction AHCi at 0x2be03a1d0>: {frozenset({'SYNPCC7942_RS03170'})},
#  <Reaction G6PDH2r at 0x2be03b350>: {frozenset({'SYNPCC7942_RS11865'})},
#  <Reaction ALAD_L at 0x2bdff5810>: {frozenset({'SYNPCC7942_RS08945'})},
#  <Reaction GTPCII at 0x2be049290>: {frozenset({'SYNPCC7942_RS07325'})},
#  <Reaction GLCBRAN3 at 0x2bdff5790>: {frozenset({'SYNPCC7942_RS09580'}),
#   frozenset({'SYNPCC7942_RS05570'})},
#  <Reaction DB4PS at 0x2be04ba90>: {frozenset({'SYNPCC7942_RS07325'})},
#  <Reaction DXPRIi at 0x2be04ed50>: {frozenset({'SYNPCC7942_RS07735'})},
#  <Reaction FBA3 at 0x2be011d10>: {frozenset({'SYNPCC7942_RS07385'})},
#  <Reaction RBFSa at 0x2bdf49750>: {frozenset({'SYNPCC7942_RS11395'})},
#  <Reaction GLUTRS at 0x2bdfd97d0>: {frozenset({'SYNPCC7942_RS12160'})},
#  <Reaction MPOMMM at 0x2be058c50>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction METAT at 0x2bdeaa850>: {frozenset({'SYNPCC7942_RS12520'})},
#  <Reaction EAR160y at 0x2bdfc2bd0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DHORTS at 0x2be05bb10>: {frozenset({'SYNPCC7942_RS02485'})},
#  <Reaction PDX5PS2 at 0x2bdf49850>: {frozenset({'SYNPCC7942_RS06115'})},
#  <Reaction KARI_23dhmp_1 at 0x2bdfd2a50>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction ARGDC at 0x2be022dd0>: {frozenset({'SYNPCC7942_RS05325'})},
#  <Reaction GAPDi_nadp at 0x2be022d50>: {frozenset({'SYNPCC7942_RS08865'})},
#  <Reaction NTD7 at 0x2bded3e50>: {frozenset({'SYNPCC7942_RS10465'})},
#  <Reaction AIRC3 at 0x2be072290>: {frozenset({'SYNPCC7942_RS02255'})},
#  <Reaction UMPK at 0x2be073650>: {frozenset({'SYNPCC7942_RS02570'})},
#  <Reaction ASPOb at 0x2bdff9ed0>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction RBFSb_1 at 0x2be075fd0>: {frozenset({'SYNPCC7942_RS08285'})},
#  <Reaction SUCDum at 0x2be0769d0>: {frozenset({'SYNPCC7942_RS01600',
#              'SYNPCC7942_RS03290',
#              'SYNPCC7942_RS07835'})},
#  <Reaction FBP at 0x2be0779d0>: {frozenset({'SYNPCC7942_RS11870'}),
#   frozenset({'SYNPCC7942_RS02565'})},
#  <Reaction CITCIb at 0x2be085cd0>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction MNabc_1 at 0x2be073690>: {frozenset({'SYNPCC7942_RS13075',
#              'SYNPCC7942_RS13080',
#              'SYNPCC7942_RS13085'}),
#   frozenset({'SYNPCC7942_RS06730',
#              'SYNPCC7942_RS06735',
#              'SYNPCC7942_RS06740'})},
#  <Reaction TMPK at 0x2be070c50>: {frozenset({'SYNPCC7942_RS13045'})},
#  <Reaction AGPR at 0x2be08a950>: {frozenset({'SYNPCC7942_RS07330'})},
#  <Reaction IPMD at 0x2be087190>: {frozenset({'SYNPCC7942_RS07690'})},
#  <Reaction CDPMEK at 0x2bdff9050>: {frozenset({'SYNPCC7942_RS01580'})},
#  <Reaction DVOCHR_1 at 0x2be04e310>: {frozenset({'SYNPCC7942_RS06950'})},
#  <Reaction H2CO3_NAt_syn at 0x2be090cd0>: {frozenset({'SYNPCC7942_RS07540'})},
#  <Reaction HEMEOS at 0x2bdfd3590>: {frozenset({'SYNPCC7942_RS13245'})},
#  <Reaction PMANM at 0x2be092990>: {frozenset({'SYNPCC7942_RS06495'})},
#  <Reaction RPE at 0x2be0677d0>: {frozenset({'SYNPCC7942_RS03100'})},
#  <Reaction MPOMT_1 at 0x2be093f90>: {frozenset({'SYNPCC7942_RS02245'})},
#  <Reaction CPPPGO2 at 0x2be087510>: {frozenset({'SYNPCC7942_RS12105'})},
#  <Reaction PC17M_1 at 0x2be0aa410>: {frozenset({'SYNPCC7942_RS09405'})},
#  <Reaction UAMAS at 0x2be059810>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction GLUCYS at 0x2bdf96710>: {frozenset({'SYNPCC7942_RS11455'})},
#  <Reaction NDHPQRum at 0x2be0ab8d0>: {frozenset({'SYNPCC7942_RS00515'}),
#   frozenset({'SYNPCC7942_RS01005'})},
#  <Reaction CYNL at 0x2be0b20d0>: {frozenset({'SYNPCC7942_RS10665'})},
#  <Reaction DCTPD2 at 0x2be030a10>: {frozenset({'SYNPCC7942_RS09635'})},
#  <Reaction CYOOum at 0x2be0bd0d0>: {frozenset({'SYNPCC7942_RS13255',
#              'SYNPCC7942_RS13260',
#              'SYNPCC7942_RS13265'})},
#  <Reaction BPNT2 at 0x2be08a8d0>: {frozenset({'SYNPCC7942_RS04960'}),
#   frozenset({'SYNPCC7942_RS00880'})},
#  <Reaction METS_1 at 0x2be05bb50>: {frozenset({'SYNPCC7942_RS07020'})},
#  <Reaction PRUK at 0x2be05a9d0>: {frozenset({'SYNPCC7942_RS05015'})},
#  <Reaction FNOR_1 at 0x2be0b16d0>: {frozenset({'SYNPCC7942_RS05020'})},
#  <Reaction GART at 0x2be0c5f10>: {frozenset({'SYNPCC7942_RS03015'})},
#  <Reaction IPPMIb at 0x2be090d90>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction DMTPHT at 0x2be0c7d10>: {frozenset({'SYNPCC7942_RS05635'})},
#  <Reaction PC6YM_1 at 0x2be076c90>: {frozenset({'SYNPCC7942_RS09385'})},
#  <Reaction PGL at 0x2be08af50>: {frozenset({'SYNPCC7942_RS02690'})},
#  <Reaction DDPA at 0x2be0d2a10>: {frozenset({'SYNPCC7942_RS12690'})},
#  <Reaction ASPCT at 0x2be0c6e10>: {frozenset({'SYNPCC7942_RS02475',
#              'SYNPCC7942_RS03430'})},
#  <Reaction HSERTA at 0x2be0d49d0>: {frozenset({'SYNPCC7942_RS08720'}),
#   frozenset({'SYNPCC7942_RS01890'})},
#  <Reaction CYRDAAT at 0x2be0d70d0>: {frozenset({'SYNPCC7942_RS04920'}),
#   frozenset({'SYNPCC7942_RS07095'}),
#   frozenset({'SYNPCC7942_RS05500'})},
#  <Reaction MECDPDHf at 0x2be088650>: {frozenset({'SYNPCC7942_RS03655'})},
#  <Reaction MTHFR3_1 at 0x2be0d07d0>: {frozenset({'SYNPCC7942_RS06695'})},
#  <Reaction 3HAD40_2 at 0x2be0e3610>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ZCAROTDH1 at 0x2bdfaf490>: {frozenset({'SYNPCC7942_RS07730'})},
#  <Reaction GLYALDDy at 0x2be0f6e90>: {frozenset({'SYNPCC7942_RS02490'})},
#  <Reaction IMPC at 0x2be0f7310>: {frozenset({'SYNPCC7942_RS02020'})},
#  <Reaction LDAPAT at 0x2be0e0910>: {frozenset({'SYNPCC7942_RS04400'})},
#  <Reaction 3OAR40_2 at 0x2be108190>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction RNDR2 at 0x2be0f0b50>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction GRTT at 0x2be118290>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction NPDPS at 0x2be0d2bd0>: {frozenset({'SYNPCC7942_RS12000'})},
#  <Reaction 3OAS100 at 0x2be0c4a90>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction ADSL2r at 0x2be11aa50>: {frozenset({'SYNPCC7942_RS01605'})},
#  <Reaction MAN6PI at 0x2be0bde50>: {frozenset({'SYNPCC7942_RS08205'})},
#  <Reaction HPROb at 0x2be124a10>: {frozenset({'SYNPCC7942_RS10440'})},
#  <Reaction 3OAS120 at 0x2be125710>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction NTPP2 at 0x2be0be010>: {frozenset({'SYNPCC7942_RS07630'})},
#  <Reaction EAR180y at 0x2be11bfd0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DHQTi at 0x2be127e90>: {frozenset({'SYNPCC7942_RS04705'})},
#  <Reaction 3OAS60 at 0x2be085d90>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR40y at 0x2be135d10>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction MG2uabcpp at 0x2be136750>: {frozenset({'SYNPCC7942_RS06500'})},
#  <Reaction KARA1 at 0x2be137450>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction TKT1 at 0x2be138250>: {frozenset({'SYNPCC7942_RS02735'})},
#  <Reaction PTRCabcpp at 0x2be138d90>: {frozenset({'SYNPCC7942_RS11515'})},
#  <Reaction IPDDI at 0x2be0e31d0>: {frozenset({'SYNPCC7942_RS09810'})},
#  <Reaction PKETF at 0x2be13b590>: {frozenset({'SYNPCC7942_RS10545'})},
#  <Reaction ACODA at 0x2be088410>: {frozenset({'Synpcc7942_1971'}),
#   frozenset({'SYNPCC7942_RS01305'})},
#  <Reaction ENO at 0x2be138290>: {frozenset({'SYNPCC7942_RS03280'})},
#  <Reaction NDHPQRcm at 0x2be142810>: {frozenset({'SYNPCC7942_RS00515'}),
#   frozenset({'SYNPCC7942_RS01005'})},
#  <Reaction NI2uabcpp at 0x2be143690>: {frozenset({'SYNPCC7942_RS08020'}),
#   frozenset({'SYNPCC7942_RS11780'})},
#  <Reaction Kabcpp at 0x2be152f50>: {frozenset({'SYNPCC7942_RS08505',
#              'SYNPCC7942_RS08510',
#              'SYNPCC7942_RS08515',
#              'SYNPCC7942_RS08800'})},
#  <Reaction TDPDRR at 0x2be152450>: {frozenset({'SYNPCC7942_RS10640'})},
#  <Reaction UAGCVT at 0x2be152ed0>: {frozenset({'SYNPCC7942_RS03670'})},
#  <Reaction TDPGDH at 0x2be1094d0>: {frozenset({'SYNPCC7942_RS10645'})},
#  <Reaction PRASCSi at 0x2be162310>: {frozenset({'SYNPCC7942_RS04770'})},
#  <Reaction PRFGS at 0x2be13b710>: {frozenset({'SYNPCC7942_RS00015',
#              'SYNPCC7942_RS04230',
#              'SYNPCC7942_RS04235'})},
#  <Reaction MG2tex at 0x2be1685d0>: {frozenset({'SYNPCC7942_RS07015'})},
#  <Reaction GLU5K at 0x2be169390>: {frozenset({'SYNPCC7942_RS11160'})},
#  <Reaction TRDR at 0x2be16aad0>: {frozenset({'SYNPCC7942_RS03195'})},
#  <Reaction GLUPRT at 0x2be1437d0>: {frozenset({'SYNPCC7942_RS00020'})},
#  <Reaction PSERT at 0x2be172890>: {frozenset({'SYNPCC7942_RS00970'})},
#  <Reaction PC8XM at 0x2be173710>: {frozenset({'SYNPCC7942_RS09395'})},
#  <Reaction GMPS2 at 0x2be1804d0>: {frozenset({'SYNPCC7942_RS00960'})},
#  <Reaction RBFK at 0x2be141a90>: {frozenset({'SYNPCC7942_RS02505'})},
#  <Reaction NTRIRfx at 0x2be183410>: {frozenset({'SYNPCC7942_RS06355'})},
#  <Reaction UPP3MT at 0x2be183f50>: {frozenset({'SYNPCC7942_RS01380'})},
#  <Reaction ACS at 0x2be185bd0>: {frozenset({'SYNPCC7942_RS06910'})},
#  <Reaction DHNCOAS at 0x2be186e50>: {frozenset({'SYNPCC7942_RS03060'})},
#  <Reaction MCOATA at 0x2be187d50>: {frozenset({'SYNPCC7942_RS07450'})},
#  <Reaction GTHPi at 0x2be067810>: {frozenset({'SYNPCC7942_RS06220'})},
#  <Reaction ARGSS at 0x2be18ecd0>: {frozenset({'SYNPCC7942_RS00045'})},
#  <Reaction PKETX at 0x2be18f690>: {frozenset({'SYNPCC7942_RS10545'})},
#  <Reaction PMPK at 0x2be0d2e50>: {frozenset({'SYNPCC7942_RS12090'})},
#  <Reaction HMBS at 0x2be19a4d0>: {frozenset({'SYNPCC7942_RS04970'})},
#  <Reaction PTPATi at 0x2be19bc50>: {frozenset({'SYNPCC7942_RS10180'})},
#  <Reaction PGLYCP at 0x2be18ee10>: {frozenset({'SYNPCC7942_RS13310'})},
#  <Reaction HTHRPDH at 0x2be19d4d0>: {frozenset({'SYNPCC7942_RS04160'})},
#  <Reaction UAGAAT2 at 0x2be19ec90>: {frozenset({'SYNPCC7942_RS12050'}),
#   frozenset({'SYNPCC7942_RS04790'})},
#  <Reaction SPTc at 0x2be1a82d0>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction GTHOr at 0x2be183f90>: {frozenset({'SYNPCC7942_RS04355'})},
#  <Reaction TDPDRE at 0x2be162390>: {frozenset({'SYNPCC7942_RS00290'}),
#   frozenset({'SYNPCC7942_RS10635'})},
#  <Reaction SHK3Dr at 0x2be1aa9d0>: {frozenset({'SYNPCC7942_RS12540'})},
#  <Reaction ORPT at 0x2be1abed0>: {frozenset({'SYNPCC7942_RS13200'})},
#  <Reaction PRPPS at 0x2be0f5350>: {frozenset({'SYNPCC7942_RS10710'})},
#  <Reaction CITMS at 0x2be1986d0>: {frozenset({'SYNPCC7942_RS02185'}),
#   frozenset({'SYNPCC7942_RS07215'})},
#  <Reaction BCT1_syn at 0x2be19a610>: {frozenset({'SYNPCC7942_RS07605',
#              'SYNPCC7942_RS07610',
#              'SYNPCC7942_RS07615',
#              'SYNPCC7942_RS07620'})},
#  <Reaction SPODM at 0x2be1b3690>: {frozenset({'SYNPCC7942_RS04145'})},
#  <Reaction TRDRf at 0x2be1b26d0>: {frozenset({'SYNPCC7942_RS05790',
#              'SYNPCC7942_RS08825'})},
#  <Reaction AMPTASECG at 0x2be1bd610>: {frozenset({'SYNPCC7942_RS05815'}),
#   frozenset({'SYNPCC7942_RS06095'})},
#  <Reaction SPRMS at 0x2be1b2690>: {frozenset({'SYNPCC7942_RS03225'})},
#  <Reaction PGAMT at 0x2be168610>: {frozenset({'SYNPCC7942_RS10815'})},
#  <Reaction NNDPR at 0x2be1c99d0>: {frozenset({'SYNPCC7942_RS04890'})},
#  <Reaction ADSK at 0x2be085e10>: {frozenset({'SYNPCC7942_RS04830'})},
#  <Reaction MECDPS at 0x2be172910>: {frozenset({'SYNPCC7942_RS06000'})},
#  <Reaction FCLT at 0x2be1d1150>: {frozenset({'SYNPCC7942_RS00695'})},
#  <Reaction SHCHCS3 at 0x2be1bead0>: {frozenset({'SYNPCC7942_RS12830'}),
#   frozenset({'SYNPCC7942_RS04015'})},
#  <Reaction PPA at 0x2be1bea50>: {frozenset({'SYNPCC7942_RS07080'})},
#  <Reaction ADCYRS at 0x2be1d3a10>: {frozenset({'SYNPCC7942_RS01070'})},
#  <Reaction ATPPRT at 0x2be1d9450>: {frozenset({'SYNPCC7942_RS04060',
#              'SYNPCC7942_RS04205'})},
#  <Reaction CUabcpp at 0x2be135d50>: {frozenset({'SYNPCC7942_RS08020'}),
#   frozenset({'SYNPCC7942_RS11780'})},
#  <Reaction DHQS at 0x2be1abf90>: {frozenset({'SYNPCC7942_RS02670'})},
#  <Reaction GTHRDH_syn at 0x2be1e3d10>: {frozenset({'SYNPCC7942_RS00940'}),
#   frozenset({'SYNPCC7942_RS13430'})},
#  <Reaction ANPRT at 0x2be1aad10>: {frozenset({'SYNPCC7942_RS10765'})},
#  <Reaction PC6AR_1 at 0x2be1e3c90>: {frozenset({'SYNPCC7942_RS00110'})},
#  <Reaction ADK1 at 0x2be18f810>: {frozenset({'SYNPCC7942_RS11240'})},
#  <Reaction PRAIi at 0x2be18ee50>: {frozenset({'SYNPCC7942_RS02080'})},
#  <Reaction TRSARyr at 0x2be1ef710>: {frozenset({'SYNPCC7942_RS09420'})},
#  <Reaction CYNTtabcpp at 0x2be1f40d0>: {frozenset({'SYNPCC7942_RS10670',
#              'SYNPCC7942_RS10675',
#              'Synpcc7942_2107'})},
#  <Reaction RBPCcx at 0x2be1f6190>: {frozenset({'SYNPCC7942_RS01445',
#              'SYNPCC7942_RS01450',
#              'SYNPCC7942_RS07270',
#              'SYNPCC7942_RS07275',
#              'SYNPCC7942_RS07280',
#              'SYNPCC7942_RS07285',
#              'SYNPCC7942_RS07290',
#              'SYNPCC7942_RS07295',
#              'SYNPCC7942_RS07300'})},
#  <Reaction UPP3S at 0x2be1bffd0>: {frozenset({'SYNPCC7942_RS01385'})},
#  <Reaction DHNPA_1 at 0x2be1c9e50>: {frozenset({'SYNPCC7942_RS00200'})},
#  <Reaction MOBDabcpp at 0x2be1820d0>: {frozenset({'SYNPCC7942_RS07820',
#              'SYNPCC7942_RS07825',
#              'SYNPCC7942_RS07830'})},
#  <Reaction NADK at 0x2be201490>: {frozenset({'SYNPCC7942_RS11710'}),
#   frozenset({'SYNPCC7942_RS09465'})},
#  <Reaction NADTRHD at 0x2be0f5450>: {frozenset({'SYNPCC7942_RS08215',
#              'SYNPCC7942_RS08220',
#              'SYNPCC7942_RS08225'})},
#  <Reaction PGM at 0x2be20e490>: {frozenset({'SYNPCC7942_RS02390'}),
#   frozenset({'SYNPCC7942_RS10535'})},
#  <Reaction FE3abcpp at 0x2be20cd10>: {frozenset({'SYNPCC7942_RS07195',
#              'SYNPCC7942_RS07200',
#              'SYNPCC7942_RS11055'}),
#   frozenset({'SYNPCC7942_RS07195',
#              'SYNPCC7942_RS07200',
#              'SYNPCC7942_RS07210'})},
#  <Reaction DHNCOAT at 0x2be21d5d0>: {frozenset({'SYNPCC7942_RS08875'})},
#  <Reaction NPHBDC at 0x2be21e010>: {frozenset({'SYNPCC7942_RS00685',
#              'SYNPCC7942_RS10425',
#              'SYNPCC7942_RS13180'})},
#  <Reaction HCO3E_1_cx at 0x2be1d8750>: {frozenset({'SYNPCC7942_RS07280',
#              'SYNPCC7942_RS07405'})},
#  <Reaction DESAT16a at 0x2be230090>: {frozenset({'SYNPCC7942_RS13015'})},
#  <Reaction UAGDP at 0x2be2017d0>: {frozenset({'SYNPCC7942_RS01465'})},
#  <Reaction PDS1_1 at 0x2be21bb50>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction FRTT at 0x2be2327d0>: {frozenset({'SYNPCC7942_RS04025'})},
#  <Reaction 3OAS180 at 0x2be235750>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR80y at 0x2be235790>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction EAR140y at 0x2be240ad0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction ACGS at 0x2be20d350>: {frozenset({'SYNPCC7942_RS09615'})},
#  <Reaction CYTBD4um at 0x2be241a10>: {frozenset({'SYNPCC7942_RS08975',
#              'SYNPCC7942_RS08980'})},
#  <Reaction DHPPDA at 0x2be241a50>: {frozenset({'SYNPCC7942_RS01030'})},
#  <Reaction DHFR at 0x2be24f450>: {frozenset({'SYNPCC7942_RS06075'})},
#  <Reaction BCAROHX at 0x2be24f410>: {frozenset({'SYNPCC7942_RS12395'})},
#  <Reaction MPOMC1_1 at 0x2be25ff50>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction ERTHMMOR at 0x2be2606d0>: {frozenset({'SYNPCC7942_RS07690'})},
#  <Reaction AFAT at 0x2be2663d0>: {frozenset({'SYNPCC7942_RS02505'})},
#  <Reaction DADK at 0x2be270490>: {frozenset({'SYNPCC7942_RS11240'})},
#  <Reaction G1SAT at 0x2be2712d0>: {frozenset({'SYNPCC7942_RS03310'})},
#  <Reaction UAAGDS at 0x2be272850>: {frozenset({'SYNPCC7942_RS07585'})},
#  <Reaction HEX1 at 0x2be273250>: {frozenset({'SYNPCC7942_RS01125'})},
#  <Reaction URIDK2r at 0x2be1cb790>: {frozenset({'SYNPCC7942_RS00470'})},
#  <Reaction CHPHYS at 0x2be278ad0>: {frozenset({'SYNPCC7942_RS10565'})},
#  <Reaction PIuabcpp at 0x2be1b1890>: {frozenset({'SYNPCC7942_RS12405',
#              'SYNPCC7942_RS12410',
#              'SYNPCC7942_RS12415',
#              'SYNPCC7942_RS12420',
#              'SYNPCC7942_RS12425'})},
#  <Reaction ARGDHpp at 0x2be27bc50>: {frozenset({'SYNPCC7942_RS04865'})},
#  <Reaction PHETA1 at 0x2be153150>: {frozenset({'SYNPCC7942_RS05290'})},
#  <Reaction PFK at 0x2be18cdd0>: {frozenset({'SYNPCC7942_RS03035'})},
#  <Reaction DMPPS_syn at 0x2be0d4a50>: {frozenset({'SYNPCC7942_RS00360'})},
#  <Reaction ANS2 at 0x2be2828d0>: {frozenset({'SYNPCC7942_RS02040',
#              'SYNPCC7942_RS05145'})},
#  <Reaction 3OAS160 at 0x2be2893d0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction ACHBSb at 0x2be0c4fd0>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction PC20M at 0x2be28b150>: {frozenset({'SYNPCC7942_RS09400'})},
#  <Reaction ADSS at 0x2be257a90>: {frozenset({'SYNPCC7942_RS12245'})},
#  <Reaction THRPDC at 0x2be282f90>: {frozenset({'SYNPCC7942_RS05685'})},
#  <Reaction MPOMOR_1 at 0x2be1c9e10>: {frozenset({'SYNPCC7942_RS09670'})},
#  <Reaction IPPMIa at 0x2be2a0910>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction SPMS at 0x2be1c8090>: {frozenset({'SYNPCC7942_RS03225'})},
#  <Reaction BPNT at 0x2be2a3510>: {frozenset({'SYNPCC7942_RS04960'}),
#   frozenset({'SYNPCC7942_RS00880'})},
#  <Reaction ICDHyr at 0x2be2a4bd0>: {frozenset({'SYNPCC7942_RS08745'})},
#  <Reaction TMDS3 at 0x2be254850>: {frozenset({'SYNPCC7942_RS05355'})},
#  <Reaction GLYOX_1 at 0x2be2a7490>: {frozenset({'SYNPCC7942_RS03275'})},
#  <Reaction MTRI at 0x2be2a7450>: {frozenset({'SYNPCC7942_RS10100'})},
#  <Reaction CTPS2 at 0x2be2a75d0>: {frozenset({'SYNPCC7942_RS09920'})},
#  <Reaction GTHS at 0x2be2b6c90>: {frozenset({'SYNPCC7942_RS11815'})},
#  <Reaction AHSERL2_1 at 0x2be2c6610>: {frozenset({'SYNPCC7942_RS01885'})},
#  <Reaction PEPC at 0x2be254490>: {frozenset({'SYNPCC7942_RS11450'})},
#  <Reaction CHORM at 0x2be169450>: {frozenset({'SYNPCC7942_RS09720'})},
#  <Reaction NTRARf2 at 0x2be2cc950>: {frozenset({'SYNPCC7942_RS06330'})},
#  <Reaction G6PDA at 0x2be298650>: {frozenset({'SYNPCC7942_RS05655'})},
#  <Reaction MPML at 0x2be1d8790>: {frozenset({'SYNPCC7942_RS02965',
#              'SYNPCC7942_RS10840',
#              'SYNPCC7942_RS11555'})},
#  <Reaction Nat_Kpp at 0x2be2cec50>: {frozenset({'SYNPCC7942_RS05545',
#              'SYNPCC7942_RS05550'})},
#  <Reaction PDH at 0x2be2ccb10>: {frozenset({'SYNPCC7942_RS00725',
#              'SYNPCC7942_RS05480',
#              'SYNPCC7942_RS06135',
#              'SYNPCC7942_RS09865'})},
#  <Reaction TPI at 0x2be2d7a50>: {frozenset({'SYNPCC7942_RS06460'})},
#  <Reaction E4PD at 0x2be2d6b10>: {frozenset({'SYNPCC7942_RS01250'}),
#   frozenset({'SYNPCC7942_RS09840'})},
#  <Reaction GAPD at 0x2be2b5bd0>: {frozenset({'SYNPCC7942_RS01250'}),
#   frozenset({'SYNPCC7942_RS09840'})},
#  <Reaction CPPPGO at 0x2be2e1890>: {frozenset({'SYNPCC7942_RS03450'})},
#  <Reaction PRMICI at 0x2be2e3110>: {frozenset({'SYNPCC7942_RS09280'})},
#  <Reaction CAT at 0x2be2d6c90>: {frozenset({'SYNPCC7942_RS08445'})},
#  <Reaction GLUR at 0x2be2ea590>: {frozenset({'SYNPCC7942_RS11995'})},
#  <Reaction OCBT at 0x2be2eb9d0>: {frozenset({'SYNPCC7942_RS12760'})},
#  <Reaction GLGC at 0x2be2f9590>: {frozenset({'SYNPCC7942_RS03095'})},
#  <Reaction PYK at 0x2be2fb810>: {frozenset({'SYNPCC7942_RS00500'})},
#  <Reaction CA2t2pp at 0x2be2fa050>: {frozenset({'SYNPCC7942_RS00120'})},
#  <Reaction ALAR at 0x2be300fd0>: {frozenset({'SYNPCC7942_RS11185'})},
#  <Reaction SULR_2 at 0x2be27ae10>: {frozenset({'SYNPCC7942_RS00100'})},
#  <Reaction ADCS at 0x2be1cb8d0>: {frozenset({'SYNPCC7942_RS06820'})},
#  <Reaction UGMDDS at 0x2be302d50>: {frozenset({'SYNPCC7942_RS09340'})},
#  <Reaction GLCDBRAN3 at 0x2be303810>: {frozenset({'SYNPCC7942_RS00425',
#              'SYNPCC7942_RS05240'})},
#  <Reaction IG3PS at 0x2be30c890>: {frozenset({'SYNPCC7942_RS07570',
#              'SYNPCC7942_RS10580'})},
#  <Reaction RPI at 0x2be2c66d0>: {frozenset({'SYNPCC7942_RS02970'})},
#  <Reaction NAt3pp at 0x2be30ea50>: {frozenset({'SYNPCC7942_RS02780'}),
#   frozenset({'SYNPCC7942_RS01565'}),
#   frozenset({'SYNPCC7942_RS06475'}),
#   frozenset({'SYNPCC7942_RS11110'}),
#   frozenset({'SYNPCC7942_RS11985'}),
#   frozenset({'SYNPCC7942_RS04195'}),
#   frozenset({'SYNPCC7942_RS12165'})},
#  <Reaction GLYCLTDx at 0x2be31f790>: {frozenset({'SYNPCC7942_RS01405',
#              'SYNPCC7942_RS08735',
#              'SYNPCC7942_RS08740'}),
#   frozenset({'SYNPCC7942_RS02885'})},
#  <Reaction FMNRy_1 at 0x2be31f6d0>: {frozenset({'SYNPCC7942_RS02765'})},
#  <Reaction GHMT2r at 0x2be1b2210>: {frozenset({'SYNPCC7942_RS01435'})},
#  <Reaction OPMEACPD at 0x2be333210>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction OPMEACPR at 0x2be338090>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction SPP at 0x2be272a50>: {frozenset({'SYNPCC7942_RS04180'})},
#  <Reaction AGPAT160 at 0x2be302e10>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_HDE_PALM at 0x2be3480d0>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction BTS6 at 0x2be33ba10>: {frozenset({'SYNPCC7942_RS02140',
#              'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS08825',
#              'SYNPCC7942_RS08830',
#              'SYNPCC7942_RS08835',
#              'SYNPCC7942_RS08840',
#              'SYNPCC7942_RS08845'})},
#  <Reaction QUERT at 0x2be348a10>: {frozenset({'SYNPCC7942_RS02325'})},
#  <Reaction PMEACPE at 0x2be34be10>: {frozenset({'SYNPCC7942_RS00145'})},
#  <Reaction G3PAT160 at 0x2be354190>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction GLUDGE_HDE_HDE at 0x2be355b10>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction G3PAT161 at 0x2be29a050>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction G3PAT1819Z_1 at 0x2be21b350>: {frozenset({'SYNPCC7942_RS07440',
#              'SYNPCC7942_RS10435'})},
#  <Reaction EPMEACPR at 0x2be356790>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction GLUDGE_OLE_HDE at 0x2be35d310>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction GLUDGE_OLE_PALM at 0x2be35d750>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction GLUDGE_HDE_PALM at 0x2be35ddd0>: {frozenset({'SYNPCC7942_RS04440'})},
#  <Reaction AGPAT161 at 0x2be2ce390>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_OLE_HDE at 0x2be35e210>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction AGPATACP_OLE_PALM at 0x2be35dbd0>: {frozenset({'SYNPCC7942_RS07455'})},
#  <Reaction GLUDGS_OLE_HDE at 0x2be368490>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_OLE_PALM at 0x2be369510>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_HDE_PALM at 0x2be36a110>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction GLUDGS_HDE_HDE at 0x2be36b5d0>: {frozenset({'SYNPCC7942_RS05560'})},
#  <Reaction TYRTRS at 0x2be36aad0>: {frozenset({'SYNPCC7942_RS13060'})},
#  <Reaction DAGK160 at 0x2be2e88d0>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK_HDE_PALM at 0x2be36bf10>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK161 at 0x2be30fa10>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction SQDGS_PALM_PALM at 0x2be3809d0>: {frozenset({'SYNPCC7942_RS02945'})},
#  <Reaction SQDGS_HDE_PALM at 0x2be382350>: {frozenset({'SYNPCC7942_RS02945'})},
#  <Reaction PGPS_OLE_PALM at 0x2be3812d0>: {frozenset({'SYNPCC7942_RS09260'})},
#  <Reaction DGDGS_HDE_PALM at 0x2be3838d0>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_HDE_HDE at 0x2be37ae90>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_OLE_HDE at 0x2be356d10>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction DGDGS_OLE_PALM at 0x2be38a950>: {frozenset({'SYNPCC7942_RS05065'})},
#  <Reaction CDPDAGS_OLE_PALM at 0x2be389410>: {frozenset({'SYNPCC7942_RS02010'})},
#  <Reaction GLNTRS at 0x2be38a6d0>: {frozenset({'SYNPCC7942_RS00590',
#              'SYNPCC7942_RS10735',
#              'SYNPCC7942_RS11805',
#              'SYNPCC7942_RS12160'})},
#  <Reaction METTRS at 0x2be382e10>: {frozenset({'SYNPCC7942_RS05845'})},
#  <Reaction SERTRS at 0x2be398fd0>: {frozenset({'SYNPCC7942_RS02295'})},
#  <Reaction PROTRS at 0x2be398f90>: {frozenset({'SYNPCC7942_RS09940'})},
#  <Reaction GLYTRS at 0x2be39b790>: {frozenset({'SYNPCC7942_RS00095',
#              'SYNPCC7942_RS12485'})},
#  <Reaction CYSTRS at 0x2be38b390>: {frozenset({'SYNPCC7942_RS08475'})},
#  <Reaction ARGTRS at 0x2be3a5dd0>: {frozenset({'SYNPCC7942_RS08055'})},
#  <Reaction TRPTRS at 0x2be1e0150>: {frozenset({'SYNPCC7942_RS06690'})},
#  <Reaction HISTRS at 0x2be1e01d0>: {frozenset({'SYNPCC7942_RS11500'})},
#  <Reaction PHETRS at 0x2be383810>: {frozenset({'SYNPCC7942_RS06615',
#              'SYNPCC7942_RS10470'})},
#  <Reaction ASNTRS at 0x2be356810>: {frozenset({'SYNPCC7942_RS04290'})},
#  <Reaction ASPTRS at 0x2be3bdcd0>: {frozenset({'SYNPCC7942_RS06715'})},
#  <Reaction UDPGLDC at 0x2be383790>: {frozenset({'SYNPCC7942_RS05885'})},
#  <Reaction AGTi at 0x2be3bfbd0>: {frozenset({'SYNPCC7942_RS10975'})},
#  <Reaction DBTS at 0x2be3d1e10>: {frozenset({'SYNPCC7942_RS00155'})},
#  <Reaction THRTRS at 0x2be3d0e10>: {frozenset({'SYNPCC7942_RS13275'})},
#  <Reaction LEUTRS at 0x2be3d8450>: {frozenset({'SYNPCC7942_RS09745'})},
#  <Reaction ILETRS at 0x2be3d8410>: {frozenset({'SYNPCC7942_RS12380'})},
#  <Reaction LYSTRS at 0x2be3dac90>: {frozenset({'SYNPCC7942_RS12270'})},
#  <Reaction AOXSr2 at 0x2be3e51d0>: {frozenset({'SYNPCC7942_RS00140'})},
#  <Reaction AMAOTr at 0x2be3dbf50>: {frozenset({'SYNPCC7942_RS00160'})},
#  <Reaction LIPOS2 at 0x2be3e6c10>: {frozenset({'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS09790',
#              'SYNPCC7942_RS11955'})},
#  <Reaction ALATRS at 0x2be3e6bd0>: {frozenset({'SYNPCC7942_RS04515'})},
#  <Reaction VALTRS at 0x2be3d0f90>: {frozenset({'SYNPCC7942_RS03010'})},
#  <Reaction FMETTRS at 0x2be3ef250>: {frozenset({'SYNPCC7942_RS10695'})},
#  <Reaction BACCL at 0x2be3eddd0>: {frozenset({'SYNPCC7942_RS01760'})},
#  <Reaction BTNPL2 at 0x2be3f8c90>: {frozenset({'SYNPCC7942_RS01760'})},
#  <Reaction LIPAMPL_1 at 0x2be399310>: {frozenset({'SYNPCC7942_RS07220'})},
#  <Reaction LIPOCT at 0x2be3f9850>: {frozenset({'SYNPCC7942_RS02760'}),
#   frozenset({'SYNPCC7942_RS07705'})},
#  <Reaction LIPATPT_1 at 0x2be3fa690>: {frozenset({'SYNPCC7942_RS07220'})},
#  <Reaction ZXANHX at 0x2be35c710>: {frozenset({'SYNPCC7942_RS03485'})},
#  <Reaction CPH4S at 0x2be402190>: {frozenset({'SYNPCC7942_RS09915'})},
#  <Reaction OGMEACPR at 0x2be403810>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction CDGS at 0x2be35d690>: {frozenset({'SYNPCC7942_RS06810'})},
#  <Reaction CCGS at 0x2be40f590>: {frozenset({'SYNPCC7942_RS06815'})},
#  <Reaction CDGR at 0x2be40fd10>: {frozenset({'SYNPCC7942_RS09355'})},
#  <Reaction PLYCOI at 0x2be3f99d0>: {frozenset({'SYNPCC7942_RS08770'}),
#   frozenset({'SYNPCC7942_RS06385'}),
#   frozenset({'SYNPCC7942_RS04985'})},
#  <Reaction SAMTRI at 0x2be4173d0>: {frozenset({'SYNPCC7942_RS11930'})},
#  <Reaction EPXQR at 0x2be417310>: {frozenset({'SYNPCC7942_RS02695'})},
#  <Reaction UPPRT at 0x2be417350>: {frozenset({'SYNPCC7942_RS08725'})},
#  <Reaction ZCARDS at 0x2be42b310>: {frozenset({'SYNPCC7942_RS07730'})},
#  <Reaction UDPGD at 0x2be430a50>: {frozenset({'SYNPCC7942_RS05000'})},
#  <Reaction GMAND at 0x2be430f50>: {frozenset({'SYNPCC7942_RS06860'})},
#  <Reaction GFUCS at 0x2be42be50>: {frozenset({'SYNPCC7942_RS08655'})},
#  <Reaction NADDP at 0x2be4324d0>: {frozenset({'SYNPCC7942_RS01040'})},
#  <Reaction CDPGLC46DH at 0x2be448490>: {frozenset({'SYNPCC7942_RS00305'})},
#  <Reaction AACPS6 at 0x2be448ed0>: {frozenset({'SYNPCC7942_RS04725'})},
#  <Reaction ALDR18 at 0x2be435f50>: {frozenset({'SYNPCC7942_RS08140'})},
#  <Reaction ALDDC17 at 0x2be39aa10>: {frozenset({'SYNPCC7942_RS08135'})},
#  <Reaction ALCD19 at 0x2be449850>: {frozenset({'SYNPCC7942_RS11615'}),
#   frozenset({'SYNPCC7942_RS08430'})},
#  <Reaction THZT at 0x2be44a8d0>: {frozenset({'SYNPCC7942_RS05420'})},
#  <Reaction PHYPQOX at 0x2be450790>: {frozenset({'SYNPCC7942_RS10055'})},
#  <Reaction LALGP at 0x2be4532d0>: {frozenset({'Synpcc7942_1971'})},
#  <Reaction CXANHX at 0x2be4597d0>: {frozenset({'SYNPCC7942_RS03485'})},
#  <Reaction OGMEACPS at 0x2be45a990>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction A5PISO at 0x2be3fba50>: {frozenset({'SYNPCC7942_RS11645'})},
#  <Reaction KDOPS at 0x2be45b850>: {frozenset({'SYNPCC7942_RS11635'})},
#  <Reaction KDOPP at 0x2be45b810>: {frozenset({'SYNPCC7942_RS11630'})},
#  <Reaction KDOCT2 at 0x2be44a910>: {frozenset({'SYNPCC7942_RS11640'})},
#  <Reaction EGMEACPR at 0x2be474290>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction DXYTST at 0x2be462410>: {frozenset({'SYNPCC7942_RS02935'})},
#  <Reaction UAG2E at 0x2be474e50>: {frozenset({'SYNPCC7942_RS02810'})},
#  <Reaction OANTS at 0x2be3e79d0>: {frozenset({'SYNPCC7942_RS01430',
#              'SYNPCC7942_RS09570',
#              'SYNPCC7942_RS09640',
#              'SYNPCC7942_RS09645',
#              'SYNPCC7942_RS09650'})},
#  <Reaction ACGAMT at 0x2be475b50>: {frozenset({'SYNPCC7942_RS01430'})},
#  <Reaction PFOR at 0x2be483290>: {frozenset({'SYNPCC7942_RS12115'})},
#  <Reaction ACMAMT at 0x2be4837d0>: {frozenset({'SYNPCC7942_RS08420'})},
#  <Reaction ICLIPAabcpp at 0x2be480350>: {frozenset({'SYNPCC7942_RS00405'})},
#  <Reaction ICLIPAS at 0x2be4889d0>: {frozenset({'SYNPCC7942_RS09555',
#              'SYNPCC7942_RS10275',
#              'SYNPCC7942_RS10280',
#              'SYNPCC7942_RS10285',
#              'SYNPCC7942_RS10290',
#              'SYNPCC7942_RS11885'})},
#  <Reaction MOAT_1 at 0x2be488990>: {frozenset({'SYNPCC7942_RS11620',
#              'SYNPCC7942_RS11625'})},
#  <Reaction MPTG at 0x2be489510>: {frozenset({'SYNPCC7942_RS10140',
#              'SYNPCC7942_RS10355'})},
#  <Reaction MPTG2 at 0x2be3ee190>: {frozenset({'SYNPCC7942_RS10140',
#              'SYNPCC7942_RS10355'})},
#  <Reaction UAGPT3 at 0x2be3ee110>: {frozenset({'SYNPCC7942_RS11755'})},
#  <Reaction GLYCOX1 at 0x2be48a6d0>: {frozenset({'SYNPCC7942_RS12230'})},
#  <Reaction UM4PL at 0x2be3be090>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction UM3PL at 0x2be491c10>: {frozenset({'SYNPCC7942_RS08860'})},
#  <Reaction PAPPT3 at 0x2be492e90>: {frozenset({'SYNPCC7942_RS00770'})},
#  <Reaction OANTIabcpp at 0x2be4936d0>: {frozenset({'SYNPCC7942_RS05765',
#              'SYNPCC7942_RS06375'})},
#  <Reaction OANTILpp at 0x2be4a47d0>: {frozenset({'SYNPCC7942_RS05765',
#              'SYNPCC7942_RS06375'})},
#  <Reaction MDDCP1pp at 0x2be4a7310>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP2pp at 0x2be417710>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction STACPSI at 0x2be44b490>: {frozenset({'SYNPCC7942_RS01220'})},
#  <Reaction UDCPDP at 0x2be4a7f90>: {frozenset({'SYNPCC7942_RS09980'})},
#  <Reaction MLTGY1pp at 0x2be4a8e90>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction ETCPC at 0x2be4a5810>: {frozenset({'SYNPCC7942_RS01655',
#              'SYNPCC7942_RS01660',
#              'SYNPCC7942_RS01665',
#              'SYNPCC7942_RS01670',
#              'SYNPCC7942_RS05370',
#              'SYNPCC7942_RS05375',
#              'SYNPCC7942_RS05380',
#              'SYNPCC7942_RS05385',
#              'SYNPCC7942_RS05390',
#              'SYNPCC7942_RS05395',
#              'SYNPCC7942_RS05400',
#              'SYNPCC7942_RS05410',
#              'SYNPCC7942_RS10300'})},
#  <Reaction GLYCOX2 at 0x2be35f5d0>: {frozenset({'SYNPCC7942_RS12230'})},
#  <Reaction NO2tabcpp at 0x2be4b4750>: {frozenset({'SYNPCC7942_RS10670',
#              'SYNPCC7942_RS10675',
#              'Synpcc7942_2107'})},
#  <Reaction MLTGY2pp at 0x2be4abc50>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction MLTGY3pp at 0x2be4b4510>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction MLTGY4pp at 0x2be4b4c10>: {frozenset({'SYNPCC7942_RS02000'})},
#  <Reaction AGM4PA at 0x2be4b7610>: {frozenset({'SYNPCC7942_RS11990'})},
#  <Reaction AM3PA at 0x2be4ccdd0>: {frozenset({'SYNPCC7942_RS11990'})},
#  <Reaction AM4PA at 0x2be4cf210>: {frozenset({'SYNPCC7942_RS11990'})},
# ...
#  <Reaction PAPA160 at 0x2be491010>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PHEOASE at 0x16a6974d0>: {frozenset({'SYNPCC7942_RS12855'})},
#  <Reaction PAPA_HDE_PALM at 0x16a8c5a90>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PAPA161 at 0x2be52fe10>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction PAPA_OLE_HDE at 0x2be4a8150>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction ACGK at 0x2be541790>: {frozenset({'SYNPCC7942_RS07645'})},
#  <Reaction MCTP2App at 0x2be542250>: {frozenset({'SYNPCC7942_RS02455'}),
#   frozenset({'SYNPCC7942_RS02950'})},
#  <Reaction MCTP1App at 0x2be52d1d0>: {frozenset({'SYNPCC7942_RS02455'}),
#   frozenset({'SYNPCC7942_RS02950'})},
#  <Reaction MCTP1Bpp at 0x2be5438d0>: {frozenset({'SYNPCC7942_RS02455'}),
#   frozenset({'SYNPCC7942_RS02950'})},
#  <Reaction LEUabcpp at 0x2be4b5710>: {frozenset({'SYNPCC7942_RS04215',
#              'SYNPCC7942_RS09440',
#              'SYNPCC7942_RS09600',
#              'SYNPCC7942_RS09605',
#              'SYNPCC7942_RS11065'})},
#  <Reaction ACLSa at 0x2be4b5690>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction SULabcpp at 0x2be4dd4d0>: {frozenset({'SYNPCC7942_RS08585',
#              'SYNPCC7942_RS08590',
#              'SYNPCC7942_RS08595',
#              'SYNPCC7942_RS08600'}),
#   frozenset({'SYNPCC7942_RS08560',
#              'SYNPCC7942_RS08565',
#              'SYNPCC7942_RS08570',
#              'SYNPCC7942_RS08765'})},
#  <Reaction PAPA_OLE_PALM at 0x2be54a210>: {frozenset({'SYNPCC7942_RS04020'})},
#  <Reaction TYRTA at 0x2be4b5550>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction ACLSb at 0x2be54bd50>: {frozenset({'SYNPCC7942_RS00705',
#              'SYNPCC7942_RS12365'})},
#  <Reaction PHEOX_1 at 0x2be52ed50>: {frozenset({'SYNPCC7942_RS11000'})},
#  <Reaction OPMEACPS at 0x2be55bfd0>: {frozenset({'SYNPCC7942_RS02730'})},
#  <Reaction EAR100y at 0x16a8c5bd0>: {frozenset({'SYNPCC7942_RS00640'})},
#  <Reaction EHGLAT at 0x2be549910>: {frozenset({'SYNPCC7942_RS12930'})},
#  <Reaction KAS15 at 0x2be563050>: {frozenset({'SYNPCC7942_RS07445'})},
#  <Reaction FALDH2 at 0x2be563a10>: {frozenset({'SYNPCC7942_RS02340'})},
#  <Reaction PHYTK at 0x2be570590>: {frozenset({'SYNPCC7942_RS05350'})},
#  <Reaction NDH_1_4_um_copy2 at 0x2be45ba10>: {frozenset({'SYNPCC7942_RS01570',
#              'SYNPCC7942_RS01575',
#              'SYNPCC7942_RS03125',
#              'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413'})},
#  <Reaction KARI_1 at 0x2be572390>: {frozenset({'SYNPCC7942_RS07915'})},
#  <Reaction 3HAD120 at 0x16a8c5fd0>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction OGMEACPD at 0x2be574850>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction ACCOAC at 0x2be575cd0>: {frozenset({'SYNPCC7942_RS07060',
#              'SYNPCC7942_RS08145',
#              'SYNPCC7942_RS09925',
#              'SYNPCC7942_RS13030'})},
#  <Reaction ASPO5 at 0x2be577c90>: {frozenset({'SYNPCC7942_RS09540'})},
#  <Reaction PTHPS at 0x2be4ab810>: {frozenset({'SYNPCC7942_RS06065'})},
#  <Reaction CITCIa at 0x2be5761d0>: {frozenset({'SYNPCC7942_RS09625',
#              'SYNPCC7942_RS12945'})},
#  <Reaction DAGK_OLE_HDE at 0x2be5832d0>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction DAGK_OLE_PALM at 0x2be558e90>: {frozenset({'SYNPCC7942_RS02045'})},
#  <Reaction 3HAD100 at 0x2be559090>: {frozenset({'SYNPCC7942_RS04785'})},
#  <Reaction PNTK at 0x2be58dcd0>: {frozenset({'SYNPCC7942_RS09185'})},
#  <Reaction 3OAR120 at 0x2be52e710>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR60 at 0x2be58f690>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR100 at 0x2be594290>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction 3OAR80 at 0x2be571250>: {frozenset({'SYNPCC7942_RS03505'})},
#  <Reaction ALCD1 at 0x2be596550>: {frozenset({'SYNPCC7942_RS11615'}),
#   frozenset({'SYNPCC7942_RS08430'})},
#  <Reaction NDH_1_1_um_copy1 at 0x2be597210>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS07360',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10025',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413',
#              'Synpcc7942_0491',
#              'Synpcc7942_0668'})},
#  <Reaction NDH_1_4_um_copy1 at 0x2be540bd0>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS10600',
#              'SYNPCC7942_RS10605',
#              'SYNPCC7942_RS10610',
#              'SYNPCC7942_RS10615',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413'})},
#  <Reaction PCHLDA430 at 0x2be59f0d0>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction SFGTHi at 0x2be52e750>: {frozenset({'SYNPCC7942_RS02335'})},
#  <Reaction PCHLDA650 at 0x2be59ee90>: {frozenset({'SYNPCC7942_RS12700'})},
#  <Reaction GGCLUT2 at 0x2be5a9a90>: {frozenset({'SYNPCC7942_RS05810'})},
#  <Reaction SPR at 0x2be5abb10>: {frozenset({'SYNPCC7942_RS09235'})},
#  <Reaction OPAH at 0x2be5a9e10>: {frozenset({'SYNPCC7942_RS12145'})},
#  <Reaction ACGAMK at 0x2be492f10>: {frozenset({'SYNPCC7942_RS10700'})},
#  <Reaction AMANAPEr at 0x2be5a9f10>: {frozenset({'SYNPCC7942_RS12525'})},
#  <Reaction AGDC at 0x2be5b2d90>: {frozenset({'SYNPCC7942_RS02250'})},
#  <Reaction ANHMK at 0x2be5aaa50>: {frozenset({'SYNPCC7942_RS05610'})},
#  <Reaction RNDR4 at 0x2be541850>: {frozenset({'SYNPCC7942_RS08210'})},
#  <Reaction TRPS2 at 0x2be55aa50>: {frozenset({'SYNPCC7942_RS02095',
#              'SYNPCC7942_RS10880'})},
#  <Reaction PSICSum at 0x2be509950>: {frozenset({'SYNPCC7942_RS02075',
#              'SYNPCC7942_RS02720',
#              'SYNPCC7942_RS03350',
#              'SYNPCC7942_RS04735',
#              'SYNPCC7942_RS05140',
#              'SYNPCC7942_RS06400',
#              'SYNPCC7942_RS06405',
#              'SYNPCC7942_RS06760',
#              'SYNPCC7942_RS09705',
#              'SYNPCC7942_RS10390',
#              'SYNPCC7942_RS10395',
#              'SYNPCC7942_RS11800',
#              'SYNPCC7942_RS11900',
#              'SYNPCC7942_RS11905',
#              'SYNPCC7942_RS12755'})},
#  <Reaction NAD_H2 at 0x2be5a9d90>: {frozenset({'SYNPCC7942_RS01415',
#              'SYNPCC7942_RS01420',
#              'SYNPCC7942_RS07025',
#              'SYNPCC7942_RS12970',
#              'SYNPCC7942_RS12975',
#              'SYNPCC7942_RS12980',
#              'SYNPCC7942_RS12985',
#              'SYNPCC7942_RS12990',
#              'SYNPCC7942_RS12995'})},
#  <Reaction PPND at 0x2be5c2f90>: {frozenset({'SYNPCC7942_RS03380'})},
#  <Reaction CBFCum at 0x16a697d10>: {frozenset({'SYNPCC7942_RS00575',
#              'SYNPCC7942_RS01640',
#              'SYNPCC7942_RS01645',
#              'SYNPCC7942_RS02420',
#              'SYNPCC7942_RS02595',
#              'SYNPCC7942_RS06310',
#              'SYNPCC7942_RS06315',
#              'SYNPCC7942_RS07560',
#              'SYNPCC7942_RS11850',
#              'SYNPCC7942_RS11855',
#              'SYNPCC7942_RS12325',
#              'Synpcc7942_1478'})},
#  <Reaction ACM6PH at 0x2be5ce510>: {frozenset({'SYNPCC7942_RS13120'})},
#  <Reaction SUCR at 0x2be5da010>: {frozenset({'SYNPCC7942_RS02025'})},
#  <Reaction CLt3_1pp at 0x2be5d9f50>: {frozenset({'SYNPCC7942_RS06440',
#              'SYNPCC7942_RS08050',
#              'SYNPCC7942_RS08110'})},
#  <Reaction Ktu at 0x2be5da050>: {frozenset({'SYNPCC7942_RS06320'})},
#  <Reaction THBTGT at 0x2be4d3350>: {frozenset({'SYNPCC7942_RS09735'})},
#  <Reaction FDH6 at 0x2be5dd190>: {frozenset({'SYNPCC7942_RS12130'})},
#  <Reaction PCXHtpp at 0x2be5ddd50>: {frozenset({'SYNPCC7942_RS05090'})},
#  <Reaction THISAT at 0x2be5de650>: {frozenset({'SYNPCC7942_RS00800',
#              'SYNPCC7942_RS05425'})},
#  <Reaction PSIIum at 0x2be5df0d0>: {frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS07110',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'}),
#   frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS04600',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'})},
#  <Reaction ATPSum at 0x2be542290>: {frozenset({'SYNPCC7942_RS01680',
#              'SYNPCC7942_RS01685',
#              'SYNPCC7942_RS01690',
#              'SYNPCC7942_RS01695',
#              'SYNPCC7942_RS01700',
#              'SYNPCC7942_RS01705',
#              'SYNPCC7942_RS01710',
#              'SYNPCC7942_RS01715',
#              'SYNPCC7942_RS11770',
#              'SYNPCC7942_RS11775'})},
#  <Reaction CYSDES at 0x2be5eefd0>: {frozenset({'SYNPCC7942_RS02300',
#              'SYNPCC7942_RS09790'})},
#  <Reaction NO3abcpp at 0x2be5616d0>: {frozenset({'SYNPCC7942_RS06335',
#              'SYNPCC7942_RS06340',
#              'SYNPCC7942_RS06345',
#              'SYNPCC7942_RS06350'})},
#  <Reaction GLNabcpp at 0x2be583490>: {frozenset({'SYNPCC7942_RS01255',
#              'SYNPCC7942_RS01260',
#              'SYNPCC7942_RS01265',
#              'SYNPCC7942_RS01270'})},
#  <Reaction GLNS at 0x2be5c0890>: {frozenset({'SYNPCC7942_RS11670'}),
#   frozenset({'SYNPCC7942_RS10955'}),
#   frozenset({'SYNPCC7942_RS00860'})},
#  <Reaction MDDEP1pp at 0x2be5ceb90>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction THII at 0x2be604510>: {frozenset({'SYNPCC7942_RS00800',
#              'SYNPCC7942_RS05425'})},
#  <Reaction SHS1 at 0x2be606390>: {frozenset({'SYNPCC7942_RS13295',
#              'SYNPCC7942_RS13300'})},
#  <Reaction PSIICSum at 0x2be5d8ad0>: {frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS07110',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'}),
#   frozenset({'SYNPCC7942_RS01140',
#              'SYNPCC7942_RS01145',
#              'SYNPCC7942_RS01500',
#              'SYNPCC7942_RS01750',
#              'SYNPCC7942_RS02165',
#              'SYNPCC7942_RS03355',
#              'SYNPCC7942_RS03360',
#              'SYNPCC7942_RS03570',
#              'SYNPCC7942_RS03575',
#              'SYNPCC7942_RS03585',
#              'SYNPCC7942_RS04600',
#              'SYNPCC7942_RS05330',
#              'SYNPCC7942_RS06020',
#              'SYNPCC7942_RS06025',
#              'SYNPCC7942_RS06030',
#              'SYNPCC7942_RS08350',
#              'SYNPCC7942_RS08550',
#              'SYNPCC7942_RS08555',
#              'SYNPCC7942_RS09545',
#              'SYNPCC7942_RS09955',
#              'SYNPCC7942_RS10225',
#              'SYNPCC7942_RS11400',
#              'SYNPCC7942_RS12590',
#              'SYNPCC7942_RS13675',
#              'SYNPCC7942_RS13745',
#              'SYNPCC7942_RS13795',
#              'Synpcc7942_2010'})},
#  <Reaction NDH_1_1_um_copy2 at 0x2be5da890>: {frozenset({'SYNPCC7942_RS05670',
#              'SYNPCC7942_RS06045',
#              'SYNPCC7942_RS06050',
#              'SYNPCC7942_RS06055',
#              'SYNPCC7942_RS06865',
#              'SYNPCC7942_RS06870',
#              'SYNPCC7942_RS06875',
#              'SYNPCC7942_RS06880',
#              'SYNPCC7942_RS07240',
#              'SYNPCC7942_RS08870',
#              'SYNPCC7942_RS09675',
#              'SYNPCC7942_RS10020',
#              'SYNPCC7942_RS10025',
#              'SYNPCC7942_RS10050',
#              'SYNPCC7942_RS11345',
#              'SYNPCC7942_RS12620',
#              'SYNPCC7942_RS13830',
#              'Synpcc7942_0413',
#              'Synpcc7942_0491',
#              'Synpcc7942_0668'})},
#  <Reaction ASNS1 at 0x2be577050>: {frozenset({'SYNPCC7942_RS00590',
#              'SYNPCC7942_RS06715',
#              'SYNPCC7942_RS10735',
#              'SYNPCC7942_RS11805'})},
#  <Reaction MDDCP3pp at 0x2be613710>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP4pp at 0x2be610490>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDCP5pp at 0x2be61ff50>: {frozenset({'SYNPCC7942_RS08520'}),
#   frozenset({'SYNPCC7942_RS09815'})},
#  <Reaction MDDEP2pp at 0x2be5762d0>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MDDEP3pp at 0x2be62b7d0>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MDDEP4pp at 0x2be50b090>: {frozenset({'SYNPCC7942_RS00700'}),
#   frozenset({'SYNPCC7942_RS09815'}),
#   frozenset({'SYNPCC7942_RS01755'})},
#  <Reaction MNHNAtpp at 0x2be558250>: {frozenset({'SYNPCC7942_RS07510',
#              'SYNPCC7942_RS07515',
#              'SYNPCC7942_RS07520',
#              'SYNPCC7942_RS07525',
#              'SYNPCC7942_RS07530',
#              'SYNPCC7942_RS07535',
#              'SYNPCC7942_RS13760'})},
#  <Reaction SUCRt2 at 0x2be632a10>: {frozenset({'ATCC_700927'})}}

# %%
# Check which genes (listed in observed transcriptomics data) are missing from the cobra model
# list_of_gprs_in_model = [str(syn_model.reactions.get_by_id(r.id).gpr).split(" and ") for r in syn_model.reactions]
list_of_gprs_in_model = [g.id for g in syn_model.genes]

genes_not_in_model = [g for g in transcriptomics_df.index if g not in list_of_gprs_in_model]
genes_not_in_data = [g for g in list_of_gprs_in_model if g not in transcriptomics_df.index]
genes_in_model_and_data = [g for g in list_of_gprs_in_model if g in transcriptomics_df.index]


print('# of genes in model:', len(list_of_gprs_in_model))
print('# of genes in data:', len(transcriptomics_df.index))
print('# of genes_not_in_model:', len(genes_not_in_model))
print('# of genes_not_in_data:', len(genes_not_in_data))
print('# of genes_in_model_and_data:', len(genes_in_model_and_data))

print('# of reactions in model:', len([r.id for r in syn_model.reactions]))

genes_not_in_data
# Out:
# # of genes in model: 786
# # of genes in data: 2761
# # of genes_not_in_model: 1986
# # of genes_not_in_data: 11
# # of genes_in_model_and_data: 775
# # of reactions in model: 851
# ['Synpcc7942_2454',
#  'Synpcc7942_0034',
#  'Synpcc7942_0413',
#  'Synpcc7942_1971',
#  'Synpcc7942_2107',
#  'Synpcc7942_2010',
#  'SYNPCC7942_RS05000',
#  'Synpcc7942_1478',
#  'Synpcc7942_0491',
#  'Synpcc7942_0668',
#  'ATCC_700927']

# %%
# Code shared by Jeremy in Teams chat...
from cobra import Reaction, Gene

def gene_expression_to_enzyme_activity(gpr: dict[Reaction, list[list[Gene]]], expression: dict[Gene, float]):
    """Map gene expression to enzyme activity
    inputs:
        gpr: dictionary of reactions (keys) to list of list of genes (values) for the correpsonding gene reaction rule
        expression: dictionary of gene names (keys) to values from [likely] observed transcriptomics data
    outputs:
        enzyme_activity: dictionary of reactions (keys) to corresponding isozyme activity from observed data (value)
    """
    
    enzyme_activity = {}
    for rxn in syn_model.reactions:
      enzyme_activity[rxn] = 0.0

      if rxn in gpr: # temporary fix: ensure rxn has a gene_reaction_rule defined

        for isozyme in gpr[rxn]:
          isozyme_activity = np.inf
          for gene in isozyme:

            if gene in expression: # temporary fix: ensure gene is included in observed data

              # Old code
              # isozyme_activity = np.min([enzyme_activity, expression[gene]])
              # enzyme_activity[rxn] += isozyme_activity

              # Correction to old code
              isozyme_activity = np.min([isozyme_activity, expression[gene]])
          enzyme_activity[rxn] += isozyme_activity
    return enzyme_activity

# %%
# Convert transciptomics data to enzyme activity

# TODO: make this a function
# def convert_transcriptomics_to_enzyme_activity(gpr: dict[Reaction, list[list[Gene]]], expression: dict[Gene, float]) -> dict[Reaction, float]:
#     """Convert transcriptomics data to enzyme activity
#     inputs:
#         gpr: dictionary of reactions (keys) to list of list of genes (values) for the correpsonding gene reaction rule
#         expression: dictionary of gene names (keys) to values from [likely] observed transcriptomics data
#     outputs:
#         enzyme_activity: dictionary of reactions (keys) to corresponding isozyme activity from observed data (value)
#     """

# Initialize empty dataframe
enzymze_activity_df = pd.DataFrame()

# Loop through each strain to convert each column of transcriptomics data
for this_strain in transcriptomics_df.columns:
    # Create dict of genes and corresponding float values using trancsciptomics data
    expression_dict = {g: transcriptomics_df.loc[g][this_strain] for g in transcriptomics_df.index}
    expr_dict_keys = [kz for kz in expression_dict.keys()]

    # Run the gene expression to enzyme activity converter for this_strain
    enzymze_activity_dict = gene_expression_to_enzyme_activity(gpr_dict, expression_dict)

    # Initialize empty dataframe 
    if this_strain == transcriptomics_df.columns[0]:
        # Use enzymze_activity_dict keys as the index
        enzymze_activity_df = enzymze_activity_df.reindex(enzymze_activity_dict.keys())
        # Add reaction ID column
        enzymze_activity_df['Reaction_ID'] = [k.id for k in enzymze_activity_dict.keys()]

    # Add enzymze_activity to dataframe
    enzymze_activity_df[this_strain] = enzymze_activity_dict

enzymze_activity_df.iloc[0:25]
# Out:
#                                                          Reaction_ID  \
# EX_gln__L_e: gln__L_e -->                                EX_gln__L_e
# EX_hco3_e: hco3_e <=>                                      EX_hco3_e
# EX_mn2_e: mn2_e <=>                                         EX_mn2_e
# EX_arg__L_e: arg__L_e -->                                EX_arg__L_e
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                          ADPT
# O2tcx: o2_c --> o2_cx                                          O2tcx
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 AOXPBDC
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c              DNTPPA
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                         CBMD
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...  BIOMASS_PIGMENTS
# H2Otu_syn: h2o_u <=> h2o_c                                 H2Otu_syn
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                       DTMPK
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....        BIOMASS__1
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                   ORNTA
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                      ATPM
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c                   ACOATA
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                     5DOAN
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c                3HAD160
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...             RNDR3
# Htex: h_e <=> h_p                                               Htex
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...              G5SD
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...            HISTDa
# TRPS3: 3ig3p_c --> g3p_c + indole_c                            TRPS3
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...          DMBZIDS2
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c                   HSTPT
#
#                                                     Se_axen_d4_1  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  1810.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               4691.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1636.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       28195.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       20578.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       22946.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       3922.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...       11214.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             17080.0
#
#                                                     Se_axen_d4_2  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  2030.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               5294.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1826.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       26841.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       23123.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       25799.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       4500.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...       12125.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             17425.0
#
#                                                     Se_axen_d4_3  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  1568.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               3826.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1332.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       22287.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       19829.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       22763.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       3382.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...       10260.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             15619.0
#
#                                                     Se_axen_d6_1  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  2020.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               4813.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1591.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       19726.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       25519.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       29749.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       4196.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...       11519.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             17314.0
#
#                                                     Se_axen_d6_2  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  1758.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               4716.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1476.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       17817.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       20047.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       24686.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       3584.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...       10167.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             14256.0
#
#                                                     Se_axen_d6_3  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  1736.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               4054.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c              999.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       15050.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       20535.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       26093.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       3638.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...        9387.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             13424.0
#
#                                                     Se_axen_d8_1  \
# EX_gln__L_e: gln__L_e -->                                    0.0
# EX_hco3_e: hco3_e <=>                                        0.0
# EX_mn2_e: mn2_e <=>                                          0.0
# EX_arg__L_e: arg__L_e -->                                    0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf
# O2tcx: o2_c --> o2_cx                                        0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                   946.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               1790.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c              711.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       12523.0
# Htex: h_e <=> h_p                                            0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       12402.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       15009.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       2308.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...        5912.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c              8566.0
#
#                                                     Se_axen_d8_2  Se_axen_d8_3
# EX_gln__L_e: gln__L_e -->                                    0.0           0.0
# EX_hco3_e: hco3_e <=>                                        0.0           0.0
# EX_mn2_e: mn2_e <=>                                          0.0           0.0
# EX_arg__L_e: arg__L_e -->                                    0.0           0.0
# ADPT: ade_c + prpp_c <=> amp_c + ppi_c                       inf           inf
# O2tcx: o2_c --> o2_cx                                        0.0           0.0
# AOXPBDC: 2a3pp_c + h_c --> 3a2oxpp_c + co2_c                 0.0           0.0
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c             0.0           0.0
# CBMD: cbm_c + 2.0 h_c --> co2_c + nh4_c                      0.0           0.0
# BIOMASS_PIGMENTS: 0.1707 calxan_c + 0.1138 caro...           0.0           0.0
# H2Otu_syn: h2o_u <=> h2o_c                                   0.0           0.0
# DTMPK: atp_c + dtmp_c <=> adp_c + dtdp_c                  1376.0        1598.0
# BIOMASS__1: 30.0 atp_c + 0.0977 bm_carbs_c + 0....           0.0           0.0
# ORNTA: akg_c + orn_c <=> glu5sa_c + glu__L_c                 inf           inf
# ATPM: atp_c + h2o_c --> adp_c + h_c + pi_c                   0.0           0.0
# ACOATA: ACP_c + accoa_c --> acACP_c + coa_c               3524.0        3105.0
# 5DOAN: dad_5_c + h2o_c --> 5drib_c + ade_c                   0.0           0.0
# 3HAD160: 3hpalmACP_c <=> h2o_c + tpalm2eACP_c             1132.0        1436.0
# RNDR3: cdp_c + trdrd_c --> dcdp_c + h2o_c + trd...       10904.0        9458.0
# Htex: h_e <=> h_p                                            0.0           0.0
# G5SD: glu5p_c + h_c + nadph_c --> glu5sa_c + na...       16955.0       19772.0
# HISTDa: histd_c + nad_c --> h_c + histda_c + na...       23037.0       23684.0
# TRPS3: 3ig3p_c --> g3p_c + indole_c                       3407.0        3780.0
# DMBZIDS2: fmnh2_c + h_c + nadh_c + o2_c --> dia...        8199.0        7513.0
# HSTPT: glu__L_c + imacp_c <=> akg_c + hisp_c             11774.0       11645.0

# %% [markdown]
#  ### 3. For each condition, normalize enzyme data with respect to the reference strain

# %%
# Create dataframe of normalized enzyme activity by scaling realtive to reference strain
rep_names = transcriptomics_df.columns
normalized_enzyme_activity_df = enzymze_activity_df[rep_names].div(enzymze_activity_df[ref_rep], axis=0)


# TODO: should these replacements be the original values (0 and inf), or 1s (to indicate same as reference strain)?
# ==> NEITHER: drop rows with all 0 or inf or NaN entries

# Ensure 0-valued or inf entries in enzymze_activity_df are passed into normalized_enzyme_activity_df
# - OR - 
# Ensure 0-valued or inf entries in enzymze_activity_df are passed into normalized_enzyme_activity_df
for col in rep_names:
    for row in enzymze_activity_df.index:
        if (enzymze_activity_df[col][row] == 0.0) or (np.isinf(enzymze_activity_df[col][row])):
            # this_row = enzymze_activity_df['Reaction_ID'][row]
            # normalized_enzyme_activity_df.loc[this_row, col] = enzymze_activity_df[col][row]
            normalized_enzyme_activity_df.loc[row, col] = enzymze_activity_df[col][row]

# Re-index normalized_enzyme_activity_df using reaction-IDs
normalized_enzyme_activity_df['Reaction_ID'] = enzymze_activity_df['Reaction_ID']
normalized_enzyme_activity_df = normalized_enzyme_activity_df.set_index('Reaction_ID')

normalized_enzyme_activity_df.iloc[0:25]

# TODO: add "check_data" function to check validity before passing to pymc
# Out:
#                   Se_axen_d4_1  Se_axen_d4_2  Se_axen_d4_3  Se_axen_d6_1  \
# Reaction_ID
# EX_gln__L_e           0.000000      0.000000      0.000000      0.000000
# EX_hco3_e             0.000000      0.000000      0.000000      0.000000
# EX_mn2_e              0.000000      0.000000      0.000000      0.000000
# EX_arg__L_e           0.000000      0.000000      0.000000      0.000000
# ADPT                       inf           inf           inf           inf
# O2tcx                 0.000000      0.000000      0.000000      0.000000
# AOXPBDC               0.000000      0.000000      0.000000      0.000000
# DNTPPA                0.000000      0.000000      0.000000      0.000000
# CBMD                  0.000000      0.000000      0.000000      0.000000
# BIOMASS_PIGMENTS      0.000000      0.000000      0.000000      0.000000
# H2Otu_syn             0.000000      0.000000      0.000000      0.000000
# DTMPK                 1.029579      1.154721      0.891923      1.149033
# BIOMASS__1            0.000000      0.000000      0.000000      0.000000
# ORNTA                      inf           inf           inf           inf
# ATPM                  0.000000      0.000000      0.000000      0.000000
# ACOATA                0.994699      1.122561      0.811281      1.020568
# 5DOAN                 0.000000      0.000000      0.000000      0.000000
# 3HAD160               1.108401      1.237127      0.902439      1.077913
# RNDR3                 1.582477      1.506483      1.250884      1.107145
# Htex                  0.000000      0.000000      0.000000      0.000000
# G5SD                  1.026488      1.153439      0.989126      1.272959
# HISTDa                0.929515      1.045086      0.922102      1.205096
# TRPS3                 1.094308      1.255580      0.943638      1.170759
# DMBZIDS2              1.102980      1.192584      1.009147      1.132979
# HSTPT                 1.198092      1.222292      1.095609      1.214506
#
#                   Se_axen_d6_2  Se_axen_d6_3  Se_axen_d8_1  Se_axen_d8_2  \
# Reaction_ID
# EX_gln__L_e                0.0      0.000000      0.000000      0.000000
# EX_hco3_e                  0.0      0.000000      0.000000      0.000000
# EX_mn2_e                   0.0      0.000000      0.000000      0.000000
# EX_arg__L_e                0.0      0.000000      0.000000      0.000000
# ADPT                       inf           inf           inf           inf
# O2tcx                      0.0      0.000000      0.000000      0.000000
# AOXPBDC                    0.0      0.000000      0.000000      0.000000
# DNTPPA                     0.0      0.000000      0.000000      0.000000
# CBMD                       0.0      0.000000      0.000000      0.000000
# BIOMASS_PIGMENTS           0.0      0.000000      0.000000      0.000000
# H2Otu_syn                  0.0      0.000000      0.000000      0.000000
# DTMPK                      1.0      0.987486      0.538111      0.782708
# BIOMASS__1                 0.0      0.000000      0.000000      0.000000
# ORNTA                      inf           inf           inf           inf
# ATPM                       0.0      0.000000      0.000000      0.000000
# ACOATA                     1.0      0.859627      0.379559      0.747243
# 5DOAN                      0.0      0.000000      0.000000      0.000000
# 3HAD160                    1.0      0.676829      0.481707      0.766938
# RNDR3                      1.0      0.844699      0.702868      0.612000
# Htex                       0.0      0.000000      0.000000      0.000000
# G5SD                       1.0      1.024343      0.618646      0.845762
# HISTDa                     1.0      1.056996      0.607996      0.933201
# TRPS3                      1.0      1.015067      0.643973      0.950614
# DMBZIDS2                   1.0      0.923281      0.581489      0.806433
# HSTPT                      1.0      0.941639      0.600870      0.825898
#
#                   Se_axen_d8_3
# Reaction_ID
# EX_gln__L_e           0.000000
# EX_hco3_e             0.000000
# EX_mn2_e              0.000000
# EX_arg__L_e           0.000000
# ADPT                       inf
# O2tcx                 0.000000
# AOXPBDC               0.000000
# DNTPPA                0.000000
# CBMD                  0.000000
# BIOMASS_PIGMENTS      0.000000
# H2Otu_syn             0.000000
# DTMPK                 0.908987
# BIOMASS__1            0.000000
# ORNTA                      inf
# ATPM                  0.000000
# ACOATA                0.658397
# 5DOAN                 0.000000
# 3HAD160               0.972900
# RNDR3                 0.530841
# Htex                  0.000000
# G5SD                  0.986282
# HISTDa                0.959410
# TRPS3                 1.054688
# DMBZIDS2              0.738959
# HSTPT                 0.816849

# %%
missing_rxns = {r: (r in FVA_object.index) for r in normalized_enzyme_activity_df.index}
{k:v for k,v in missing_rxns.items() if not v}
# Out:
# {'BIOMASS__1': False, 'EX_co2_e': False, 'EX_sucr_e': False}

# %% [markdown]
# # ----- STOP HERE ..... for now

# %% [markdown]
# ### 4. For each condition, multiply the reference bounds by the normalized enzyme data.

# %%
# TODO: get relative scaled rates of change in metabolic abundance
# rates_df = ...
# normalized_rates_df = ...

# %%
# TODO: make this into a function
flux_bounds = {}
for this_strain in normalized_enzyme_activity_df.columns:
    flux_bounds[this_strain] = FVA_object
    for this_rxn in normalized_enzyme_activity_df.index:
        if this_rxn in FVA_object:
            this_factor = normalized_enzyme_activity_df[this_strain][this_rxn]
            flux_bounds[this_strain].loc[this_rxn] = this_factor*FVA_object[this_strain][this_rxn]
        elif this_rxn in missing_rxns:
            # TODO: for sucrose production ('EX_sucr_e'), use normalized calcualted rate from normalized_rates_df
            if rxn=='EX_sucr_e':
                # flux_bounds[this_strain].loc[this_rxn] = pd.Series({'minimum': ....,
                #                                                     'maximum': ....})
                

test_df = flux_bounds['Se_axen_d4_1'].iloc[0:35]
test_df.columns = ['d4_1_min', 'd4_1_max']
test_df.join(flux_bounds[ref_rep].iloc[0:35])
# Out:
#                       d4_1_min      d4_1_max       minimum       maximum
# EX_gln__L_e       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# EX_hco3_e        -1.990000e+00 -1.990000e+00 -1.990000e+00 -1.990000e+00
# EX_mn2_e          0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# EX_arg__L_e       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ADPT              1.032064e-05  1.032064e-05  1.032064e-05  1.032064e-05
# O2tcx             2.631984e-02  2.631984e-02  2.631984e-02  2.631984e-02
# AOXPBDC           1.411151e-06  1.411151e-06  1.411151e-06  1.411151e-06
# DNTPPA            4.111581e-06  4.111581e-06  4.111581e-06  4.111581e-06
# CBMD              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# BIOMASS_PIGMENTS  1.061867e-03  1.061867e-03  1.061867e-03  1.061867e-03
# H2Otu_syn        -7.837161e+00 -7.837161e+00 -7.837161e+00 -7.837161e+00
# DTMPK             2.847641e-04  2.847641e-04  2.847641e-04  2.847641e-04
# ORNTA             0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ATPM              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ACOATA            2.399223e-02  2.399223e-02  2.399223e-02  2.399223e-02
# 5DOAN             5.599703e-06  5.599703e-06  5.599703e-06  5.599703e-06
# 3HAD160           2.296164e-02  2.296164e-02  2.296164e-02  2.296164e-02
# RNDR3             6.388443e-04  6.388443e-04  6.388443e-04  6.388443e-04
# Htex              2.427223e+00  2.427223e+00  2.427223e+00  2.427223e+00
# G5SD              1.275780e-02  1.275780e-02  1.275780e-02  1.275780e-02
# HISTDa            4.626423e-03  4.626423e-03  4.626423e-03  4.626423e-03
# TRPS3             3.852138e-03  3.852138e-03  3.852138e-03  3.852138e-03
# DMBZIDS2          2.758159e-07  2.758159e-07  2.758159e-07  2.758159e-07
# HSTPT             4.626423e-03  4.626423e-03  4.626423e-03  4.626423e-03
# ZCAROTDH2         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ORNDC             6.927468e-06  6.927468e-06  6.927468e-06  6.927468e-06
# GND               0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# CMPA_1            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# U23GAAT2          5.145925e-04  5.145925e-04  5.145925e-04  5.145925e-04
# HOXGfx            5.564182e-05  5.564182e-05  5.564182e-05  5.564182e-05
# PGK               4.638910e+00  4.638910e+00  4.638910e+00  4.638910e+00
# IMPD              5.745098e-03  5.745098e-03  5.745098e-03  5.745098e-03
# LPOR              6.043084e-04  6.043084e-04  6.043084e-04  6.043084e-04
# CHRPL             9.621483e-07  9.621483e-07  9.621483e-07  9.621483e-07
# GCALDDy           4.111581e-06  4.111581e-06  4.111581e-06  4.111581e-06

# %%
FVA_object.iloc[0]
# Out:
# minimum    0.0
# maximum    0.0
# Name: EX_gln__L_e, dtype: float64

# %% [markdown]
# ### 5. Run FBA using the condition-specific bounds to compute the condition-specific fluxes
